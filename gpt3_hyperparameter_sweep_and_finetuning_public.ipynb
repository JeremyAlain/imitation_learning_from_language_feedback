# %% [markdown]
# <a href="https://colab.research.google.com/github/JeremyAlain/imitation_learning_from_language_feedback/blob/feature%2Fadd_all_relevant_files/gpt3_hyperparameter_sweep_and_finetuning_public.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai==0.25.0
# !pip install -Uqq ipdb
# !pip install wandb==0.13.5
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai==0.25.0
#   Downloading openai-0.25.0.tar.gz (44 kB)
#      |████████████████████████████████| 44 kB 1.8 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from openai==0.25.0) (1.21.6)
# Collecting pandas-stubs>=1.1.0.11
#   Downloading pandas_stubs-1.5.2.221213-py3-none-any.whl (147 kB)
#      |████████████████████████████████| 147 kB 12.3 MB/s
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.8/dist-packages (from openai==0.25.0) (2.23.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.8/dist-packages (from openai==0.25.0) (4.4.0)
# Requirement already satisfied: openpyxl>=3.0.7 in /usr/local/lib/python3.8/dist-packages (from openai==0.25.0) (3.0.10)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from openai==0.25.0) (4.64.1)
# Requirement already satisfied: pandas>=1.2.3 in /usr/local/lib/python3.8/dist-packages (from openai==0.25.0) (1.3.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.8/dist-packages (from openpyxl>=3.0.7->openai==0.25.0) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.2.3->openai==0.25.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.2.3->openai==0.25.0) (2022.6)
# Collecting types-pytz>=2022.1.1
#   Downloading types_pytz-2022.7.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas>=1.2.3->openai==0.25.0) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai==0.25.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai==0.25.0) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai==0.25.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.20->openai==0.25.0) (1.24.3)
# Building wheels for collected packages: openai
#   Building wheel for openai (PEP 517) ... done
#   Created wheel for openai: filename=openai-0.25.0-py3-none-any.whl size=55880 sha256=88b5685290401dd9d2a630e0874709fee1f127bd30d68881de1109d50c57c31c
#   Stored in directory: /root/.cache/pip/wheels/4b/92/33/6f57c7aae0b16875267999a50570e81f15eecec577ebe05a2e
# Successfully built openai
# Installing collected packages: types-pytz, pandas-stubs, openai
# Successfully installed openai-0.25.0 pandas-stubs-1.5.2.221213 types-pytz-2022.7.0.0
#      |████████████████████████████████| 761 kB 8.4 MB/s
#      |████████████████████████████████| 1.6 MB 49.0 MB/s
#      |████████████████████████████████| 386 kB 56.9 MB/s
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires ipython~=7.9.0, but you have ipython 8.7.0 which is incompatible.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wandb==0.13.5
#   Downloading wandb-0.13.5-py2.py3-none-any.whl (1.9 MB)
#      |████████████████████████████████| 1.9 MB 7.8 MB/s
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.8/dist-packages (from wandb==0.13.5) (2.3)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.3.2-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.8/dist-packages (from wandb==0.13.5) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from wandb==0.13.5) (57.4.0)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.29-py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 74.2 MB/s
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.12.1-py2.py3-none-any.whl (174 kB)
#      |████████████████████████████████| 174 kB 68.1 MB/s
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb==0.13.5) (2.23.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from wandb==0.13.5) (6.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.8/dist-packages (from wandb==0.13.5) (7.1.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.8/dist-packages (from wandb==0.13.5) (5.4.8)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.11-py3-none-any.whl (10 kB)
# Requirement already satisfied: protobuf!=4.0.*,!=4.21.0,<5,>=3.12.0 in /usr/local/lib/python3.8/dist-packages (from wandb==0.13.5) (3.19.6)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.10-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 631 kB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb==0.13.5) (2022.12.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb==0.13.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb==0.13.5) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.0.0->wandb==0.13.5) (1.24.3)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.12.0-py2.py3-none-any.whl (173 kB)
#      |████████████████████████████████| 173 kB 58.9 MB/s
#   Downloading sentry_sdk-1.11.1-py2.py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 57.0 MB/s
#   Downloading sentry_sdk-1.11.0-py2.py3-none-any.whl (168 kB)
#      |████████████████████████████████| 168 kB 59.4 MB/s
#   Downloading sentry_sdk-1.10.1-py2.py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 69.6 MB/s
#   Downloading sentry_sdk-1.10.0-py2.py3-none-any.whl (166 kB)
#      |████████████████████████████████| 166 kB 63.9 MB/s
#   Downloading sentry_sdk-1.9.10-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 59.5 MB/s
#   Downloading sentry_sdk-1.9.9-py2.py3-none-any.whl (162 kB)
#      |████████████████████████████████| 162 kB 60.6 MB/s
#   Downloading sentry_sdk-1.9.8-py2.py3-none-any.whl (158 kB)
#      |████████████████████████████████| 158 kB 75.4 MB/s
#   Downloading sentry_sdk-1.9.7-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 67.2 MB/s
#   Downloading sentry_sdk-1.9.6-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 57.5 MB/s
#   Downloading sentry_sdk-1.9.5-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 60.0 MB/s
#   Downloading sentry_sdk-1.9.4-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 58.1 MB/s
#   Downloading sentry_sdk-1.9.3-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 55.9 MB/s
#   Downloading sentry_sdk-1.9.2-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 58.7 MB/s
#   Downloading sentry_sdk-1.9.1-py2.py3-none-any.whl (157 kB)
#      |████████████████████████████████| 157 kB 59.7 MB/s
#   Downloading sentry_sdk-1.9.0-py2.py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 61.0 MB/s
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=71d7c3fa53bc9bd6c41f9d732a2cf0c121a94ad6f82ec5cce8afe157ae21ad3d
#   Stored in directory: /root/.cache/pip/wheels/4c/8e/7e/72fbc243e1aeecae64a96875432e70d4e92f3d2d18123be004
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.29 docker-pycreds-0.4.0 gitdb-4.0.10 pathtools-0.1.2 sentry-sdk-1.9.0 setproctitle-1.3.2 shortuuid-1.0.11 smmap-5.0.0 wandb-0.13.5

# %%
import wandb
import pandas as pd 
from google.colab import drive 
import openai 
from openai.wandb_logger import WandbLogger
from pathlib import Path
from typing import List, Union, Dict, Any
import os
import itertools
import numpy as np

import ipdb


root_path = "/content/drive/MyDrive/training_language_models_with_language_feedback_at_scale"
drive.mount('/content/drive', force_remount=False)
openai.api_key=""
# %env OPENAI_API_KEY=
# Out:
# Mounted at /content/drive
# env: OPENAI_API_KEY=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

# %%
def upload_dataset_to_openai(dataset_path: str) -> Dict[str, str]: 
  dataset_path = os.path.join(root_path, dataset_path)
  assert Path(dataset_path).exists(), dataset_path
  train_object = openai.File.create(
      file=open(dataset_path), 
      purpose="fine-tune"
  )
  return train_object["id"]

# %%
def kill_all_active_jobs():
  for ft in openai.FineTune.list()['data']:
    if ft['status'] == 'pending' or ft['status'] == 'running':
      print("Found", ft['id'], ft['status'], "... killing.")
      openai.FineTune.cancel(id=ft['id'])
  print("No more active jobs.")

# %%
def show_all_active_jobs():
  for ft in openai.FineTune.list()['data']:
    if ft['status'] == 'pending' or ft['status'] == 'running':
      print("Found", ft['id'], ft['status'])
  print("No more active jobs.")

# %%
def show_job_status_of_job_ids(job_ids: List[str]=None): 
  for finetuning_id in openai.FineTune.list()["data"]: 
    if job_ids and finetuning_id['id'] not in job_ids:
      continue
    print(finetuning_id['id'], finetuning_id['status'])

# %%
def build_parameter_sets(sweep_parameters: Dict[str, Any]): 
  list_of_parameters = []
  list_of_values = []
  for parameter, value_list in sweep_parameters.items():
    list_of_parameters.append(parameter)
    list_of_values.append(value_list)

  all_combinations_of_values = itertools.product(*list_of_values)

  parameter_sets = []
  for value_combinations in all_combinations_of_values:
    parameterset = {parameter_name: value for parameter_name, value in zip(list_of_parameters, value_combinations)}
    parameter_sets.append(parameterset)
  return parameter_sets

# %% [markdown]
# # Initialize finetuning runs with differen parameters, keep others at default

# %%
def initialize_gpt3_finetuning_job_with_n_epochs(n_epochs: int, train_dataset_id: str, validation_dataset_id: str, finetuning_summaries: List[str], finetuning_ids: List[str], suffix: str) -> None:
  finetuning_summary = openai.FineTune.create(
                        training_file=train_dataset_id, 
                        validation_file=validation_dataset_id,
                        model="davinci",
                        n_epochs=n_epochs, 
                        compute_classification_metrics=False,
                        suffix=suffix)
  finetuning_summaries.append(finetuning_summary)
  finetuning_ids.append(finetuning_summary["id"])
  print("Initialized job", finetuning_summary['id'])
  print("with n_epochs", n_epochs)
  print("\n\n")
  return finetuning_summaries, finetuning_ids

# %%
def initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight(n_epochs: int, prompt_loss_weight: float, train_dataset_id: str, validation_dataset_id: str, finetuning_summaries: List[str], finetuning_ids: List[str], suffix: str) -> None:
  finetuning_summary = openai.FineTune.create(
                        training_file=train_dataset_id, 
                        validation_file=validation_dataset_id,
                        model="davinci",
                        n_epochs=n_epochs, 
                        prompt_loss_weight=prompt_loss_weight,
                        compute_classification_metrics=False,
                        suffix=suffix)
  finetuning_summaries.append(finetuning_summary)
  finetuning_ids.append(finetuning_summary["id"])
  print("Initialized job", finetuning_summary['id'])
  print("with n_epochs", n_epochs)
  print("with prompt_loss_weight: ", prompt_loss_weight)
  print("\n\n")
  return finetuning_summaries, finetuning_ids

# %%
def initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight_and_lr(n_epochs: int, prompt_loss_weight: float, learning_rate_multiplier: float, train_dataset_id: str, validation_dataset_id: str, finetuning_summaries: List[str], finetuning_ids: List[str], suffix: str) -> None:
  finetuning_summary = openai.FineTune.create(
                        training_file=train_dataset_id, 
                        validation_file=validation_dataset_id,
                        model="davinci",
                        n_epochs=n_epochs, 
                        prompt_loss_weight=prompt_loss_weight,
                        learning_rate_multiplier=learning_rate_multiplier,
                        compute_classification_metrics=False,
                        suffix=suffix)
  finetuning_summaries.append(finetuning_summary)
  finetuning_ids.append(finetuning_summary["id"])
  print("Initialized job", finetuning_summary['id'])
  print("with n_epochs", n_epochs)
  print("with prompt_loss_weight: ", prompt_loss_weight)
  print("\n\n")
  return finetuning_summaries, finetuning_ids

# %% [markdown]
# # Perplexity for text-davinci-001
# Perplexity: 34.8

# %% [markdown]
# # Dataset Size - 100
#
# **Final Parameters**
# n_epochs=1
#
# prompt_loss_weight = 0
#
# learning_rate_multiplier = 0.05

# %% [markdown]
# ## Epochs
#
# n_epochs=1,2,3,4
#
# **Results**:
#
# *   Epoch 1: 6.66
# *   Epoch 2: 7.71
# *   Epoch 3: 10.35
# *   Epoch 4: 15.57
#
# **Best Epoch**: 1

# %%
final_tag = "hp_tuning_human_100_n_epochs"
parameter_combinations = {
                "n_epochs":[1,2,3,4], 
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/ideal_human_summary_finetuning_dataset_train_100.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
dev_data = "summarization_finetuning_datasets/ideal_human_summary_finetuning_dataset_development_200.jsonl"
dev_data_id = upload_dataset_to_openai(dev_data)
print("Train dataset id {}".format(train_data_id))
print("Validation dataset id {}".format(dev_data_id))
# Out:
# Train dataset id file-EmAzSAkmrINIyLAKarVjR61g
# Validation dataset id file-pu9igDtwPC2BUQSDsyMfRMFH

# %%
train_data_id = "file-EmAzSAkmrINIyLAKarVjR61g"
dev_data_id = "file-pu9igDtwPC2BUQSDsyMfRMFH"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs(n_epochs=n_epochs, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-4CL4UOqGuaV0az0X1rlklPmC
# with n_epochs 1
#
#
#
# ['ft-4CL4UOqGuaV0az0X1rlklPmC']
# Initialized job ft-Alt93HeCSUKPgsEM9aeqMwbX
# with n_epochs 2
#
#
#
# ['ft-4CL4UOqGuaV0az0X1rlklPmC', 'ft-Alt93HeCSUKPgsEM9aeqMwbX']
# Initialized job ft-kBPFkBpqBPKEc0MtPviRWiCf
# with n_epochs 3
#
#
#
# ['ft-4CL4UOqGuaV0az0X1rlklPmC', 'ft-Alt93HeCSUKPgsEM9aeqMwbX', 'ft-kBPFkBpqBPKEc0MtPviRWiCf']
# Initialized job ft-uFTbJCC3OeqrjrNd2NqUzHg0
# with n_epochs 4
#
#
#
# ['ft-4CL4UOqGuaV0az0X1rlklPmC', 'ft-Alt93HeCSUKPgsEM9aeqMwbX', 'ft-kBPFkBpqBPKEc0MtPviRWiCf', 'ft-uFTbJCC3OeqrjrNd2NqUzHg0']

# %%
# !openai api fine_tunes.get -i "ft-4CL4UOqGuaV0az0X1rlklPmC"
# Out:
# {
#   "created_at": 1670610750,
#   "events": [
#     {
#       "created_at": 1670610750,
#       "level": "info",
#       "message": "Created fine-tune: ft-4CL4UOqGuaV0az0X1rlklPmC",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670610752,
#       "level": "info",
#       "message": "Fine-tune costs $1.16",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670610753,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 2",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": 1,
#     "learning_rate_multiplier": 0.1,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.01
#   },
#   "id": "ft-4CL4UOqGuaV0az0X1rlklPmC",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 166940,
#       "created_at": 1670610732,
#       "filename": "file",
#       "id": "file-EmAzSAkmrINIyLAKarVjR61g",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670610753,
#   "validation_files": [
#     {
#       "bytes": 335949,
#       "created_at": 1670610733,
#       "filename": "file",
#       "id": "file-pu9igDtwPC2BUQSDsyMfRMFH",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-4CL4UOqGuaV0az0X1rlklPmC ...
# [2022-12-09 18:32:30] Created fine-tune: ft-4CL4UOqGuaV0az0X1rlklPmC
# [2022-12-09 18:32:32] Fine-tune costs $1.16
# [2022-12-09 18:32:33] Fine-tune enqueued. Queue number: 2
# [2022-12-09 18:34:31] Fine-tune is in the queue. Queue number: 1
# [2022-12-09 18:34:34] Fine-tune is in the queue. Queue number: 0
# [2022-12-09 18:37:12] Fine-tune started
# [2022-12-09 18:39:36] Completed epoch 1/1
# [2022-12-09 18:40:27] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-100-n-epochs-2022-12-09-18-40-26
# [2022-12-09 18:40:28] Uploaded result file: file-KibAaX1ikYF05hSAReE1yIKS
# [2022-12-09 18:40:28] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-100-n-epochs-2022-12-09-18-40-26 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-Alt93HeCSUKPgsEM9aeqMwbX ...
# [2022-12-09 18:32:30] Created fine-tune: ft-Alt93HeCSUKPgsEM9aeqMwbX
# [2022-12-09 18:40:31] Fine-tune costs $2.32
# [2022-12-09 18:40:32] Fine-tune enqueued. Queue number: 5
# [2022-12-09 18:40:32] Fine-tune is in the queue. Queue number: 4
# [2022-12-09 18:43:08] Fine-tune is in the queue. Queue number: 3
# [2022-12-09 18:44:01] Fine-tune is in the queue. Queue number: 2
# [2022-12-09 18:45:24] Fine-tune is in the queue. Queue number: 1
# [2022-12-09 18:46:18] Fine-tune is in the queue. Queue number: 0
# [2022-12-09 18:47:41] Fine-tune started
# [2022-12-09 18:50:08] Completed epoch 1/2
# [2022-12-09 18:51:07] Completed epoch 2/2
# [2022-12-09 18:51:46] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-100-n-epochs-2022-12-09-18-51-45
# [2022-12-09 18:51:47] Uploaded result file: file-X56o6Vedaw81Ux0sJuOtR8pO
# [2022-12-09 18:51:47] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-100-n-epochs-2022-12-09-18-51-45 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-kBPFkBpqBPKEc0MtPviRWiCf ...
# [2022-12-09 18:32:30] Created fine-tune: ft-kBPFkBpqBPKEc0MtPviRWiCf
# [2022-12-09 19:12:56] Fine-tune costs $3.48
# [2022-12-09 19:12:57] Fine-tune enqueued. Queue number: 3
# [2022-12-09 19:16:45] Fine-tune is in the queue. Queue number: 2
# [2022-12-09 19:18:04] Fine-tune is in the queue. Queue number: 1
# [2022-12-09 19:18:41] Fine-tune is in the queue. Queue number: 0
# [2022-12-09 19:34:58] Fine-tune started
# [2022-12-09 19:37:20] Completed epoch 1/3
# [2022-12-09 19:38:18] Completed epoch 2/3
# [2022-12-09 19:39:16] Completed epoch 3/3
# [2022-12-09 19:39:54] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-100-n-epochs-2022-12-09-19-39-53
# [2022-12-09 19:39:55] Uploaded result file: file-g5BrXZntKbroFV6OSutljEIM
# [2022-12-09 19:39:55] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-100-n-epochs-2022-12-09-19-39-53 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-uFTbJCC3OeqrjrNd2NqUzHg0 ...
# [2022-12-09 18:32:30] Created fine-tune: ft-uFTbJCC3OeqrjrNd2NqUzHg0
# [2022-12-09 18:51:47] Fine-tune costs $4.64
# [2022-12-09 18:51:48] Fine-tune enqueued. Queue number: 5
# [2022-12-09 18:51:49] Fine-tune is in the queue. Queue number: 4
# [2022-12-09 18:57:04] Fine-tune is in the queue. Queue number: 3
# [2022-12-09 19:02:24] Fine-tune is in the queue. Queue number: 2
# [2022-12-09 19:02:25] Fine-tune is in the queue. Queue number: 1
# [2022-12-09 19:04:51] Fine-tune is in the queue. Queue number: 0
# [2022-12-09 19:06:55] Fine-tune started
# [2022-12-09 19:09:16] Completed epoch 1/4
# [2022-12-09 19:10:15] Completed epoch 2/4
# [2022-12-09 19:11:12] Completed epoch 3/4
# [2022-12-09 19:12:10] Completed epoch 4/4
# [2022-12-09 19:12:51] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-100-n-epochs-2022-12-09-19-12-51
# [2022-12-09 19:12:52] Uploaded result file: file-tKxnNBgOED1VqUa788qxSKOy
# [2022-12-09 19:12:52] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-100-n-epochs-2022-12-09-19-12-51 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-4CL4UOqGuaV0az0X1rlklPmC', 'ft-Alt93HeCSUKPgsEM9aeqMwbX', 'ft-kBPFkBpqBPKEc0MtPviRWiCf', 'ft-uFTbJCC3OeqrjrNd2NqUzHg0']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: jerry_crea. Use `wandb login --relogin` to force relogin
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221209_195200-ft-4CL4UOqGuaV0az0X1rlklPmC</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-4CL4UOqGuaV0az0X1rlklPmC" target="_blank">ft-4CL4UOqGuaV0az0X1rlklPmC</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▂▅▆▄▃▃▃▄▅▃▂▂▃▄▃▂▁▃▂▆▂▂▁▄▃▃▂▂▄▁█▃▂▃▅▂▂▃▃▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▁▃▁▅▃▅▂▃▄▅▅▅▄▄▃▄▄▆▂▂▃▆▃▂▂▆▄▅█▃▁▆▆▁▃▄▂▄▆</td></tr><tr><td>validation_loss</td><td>▅▅▃▄▁▅█▃▃▃▃▄▆</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▁█▁▅▃▂▇▃▆▄▂▇▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>102.0</td></tr><tr><td>elapsed_tokens</td><td>39806.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.14964</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.6875</td></tr><tr><td>validation_loss</td><td>0.25489</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.55</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-4CL4UOqGuaV0az0X1rlklPmC</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-4CL4UOqGuaV0az0X1rlklPmC" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-4CL4UOqGuaV0az0X1rlklPmC</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221209_195200-ft-4CL4UOqGuaV0az0X1rlklPmC/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221209_195210-ft-Alt93HeCSUKPgsEM9aeqMwbX</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-Alt93HeCSUKPgsEM9aeqMwbX" target="_blank">ft-Alt93HeCSUKPgsEM9aeqMwbX</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▂▄▆▅▃▄▃▃▆▄▄▂▁▃█▅▃▄▂▅▂▂▄▂▂▃▂▁▃▂▁▄▃▃▂▂▂▂▂▁</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▄▃▃▁▄▃▄▁▄▅▃▆▃▃▄▃▂▅▅▄▄▅▅▅▅▃▇▆▄█▃▅▆▅▆▅▅▆▆</td></tr><tr><td>validation_loss</td><td>▇▂▇▃▄▃▆▂▃▃▄▂▆▅▃█▁▂▃▄▂▂▂▅▃▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▅▄▁▅▅▁▅▃▃▄▂▅▆▆▂▂█▆▂▂▁▅▅▃▄▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>202.0</td></tr><tr><td>elapsed_tokens</td><td>78610.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.10125</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.75862</td></tr><tr><td>validation_loss</td><td>0.23778</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.55556</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-Alt93HeCSUKPgsEM9aeqMwbX</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-Alt93HeCSUKPgsEM9aeqMwbX" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-Alt93HeCSUKPgsEM9aeqMwbX</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221209_195210-ft-Alt93HeCSUKPgsEM9aeqMwbX/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221209_195217-ft-kBPFkBpqBPKEc0MtPviRWiCf</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-kBPFkBpqBPKEc0MtPviRWiCf" target="_blank">ft-kBPFkBpqBPKEc0MtPviRWiCf</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>█▅▅▅▅▄▅▆▅▄▃▅▄▄▃█▂▃▃▅▃▄▁▃▃▃▂▂▁▂▃▂▃▁▂▃▂▃▃▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▁▁▃▂▄▅▁▃▃▂▅▂▁▃▃▄▇▄▃▃▄▄▇▃▄▃▅▄▇▆▄█▅█▅▄▄▅▄▇</td></tr><tr><td>validation_loss</td><td>▄▄▂▃▁▄▆▃▂▃▃▄▅▅▆▅▇▃▃▆▃▃▃▃▆▄▂▂▆▂▄▅▄▂▅▄▂█</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▂▆▂▅▄▃▆▃▆▄▄▆▅▆▄▄▄▅▅▅▇▄█▃▂▃▁▆▅▄▃▇▄▄▄▄▃▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>302.0</td></tr><tr><td>elapsed_tokens</td><td>117662.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.08704</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.79487</td></tr><tr><td>validation_loss</td><td>0.38818</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.61702</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-kBPFkBpqBPKEc0MtPviRWiCf</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-kBPFkBpqBPKEc0MtPviRWiCf" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-kBPFkBpqBPKEc0MtPviRWiCf</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221209_195217-ft-kBPFkBpqBPKEc0MtPviRWiCf/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221209_195223-ft-uFTbJCC3OeqrjrNd2NqUzHg0</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-uFTbJCC3OeqrjrNd2NqUzHg0" target="_blank">ft-uFTbJCC3OeqrjrNd2NqUzHg0</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>█▄▅▅▆▅▆▄▅▄▄▂▂▅▄▄▄▄▃▄▃▂▂▂▄▃▃▃▃▃▂▃▁▂▁▂▁▁▂▁</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█</td></tr><tr><td>training_token_accuracy</td><td>▂▁▃▄▄▂▃▂▂▂▂▆▆▄▃▄▄▃▃▁▆▆▆▇▅▆▄▄▅▆▇▄▇▇█▆██▆█</td></tr><tr><td>validation_loss</td><td>▃▃▁▂▃▆▁▁▂▃▄▆▄▇▂▆▂▂▂▆▄▂▆▁▃▄▁▄▃██▆▇▄▄▅▃▆▄▅</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▃▇▃▆▃▆▄▇▄▆▆▅▄▅▆▅█▄▄▃▄▁▄▄▃▃▃▅▃█▂▇▂▇▃▇▅▅▂▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>402.0</td></tr><tr><td>elapsed_tokens</td><td>156802.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.09034</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.72727</td></tr><tr><td>validation_loss</td><td>0.29236</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.5</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-uFTbJCC3OeqrjrNd2NqUzHg0</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-uFTbJCC3OeqrjrNd2NqUzHg0" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-uFTbJCC3OeqrjrNd2NqUzHg0</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221209_195223-ft-uFTbJCC3OeqrjrNd2NqUzHg0/logs</code>

# %% [markdown]
# ## Prompt Loss Weight
# **Sweep**:
#
# n_epochs=1
#
# prompt_loss_weight = 0, 0.01, 0.05, 0.1
#
# **Results:**
#
#
# *   prompt_loss_weight 0 = 6.48
# *   prompt_loss_weight 0.01 = 6.57
# *   prompt_loss_weight 0.05 = 6.54
# *   prompt_loss_weight 0.1 = 6.55

# %%
final_tag = "hp_tuning_human_100_prompt_loss_weight"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0, 0.01, 0.05, 0.1]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
train_data_id = "file-EmAzSAkmrINIyLAKarVjR61g"
dev_data_id = "file-pu9igDtwPC2BUQSDsyMfRMFH"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-dIXqYeDE6SxIqu9YuSONpyGk
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-dIXqYeDE6SxIqu9YuSONpyGk']
# Initialized job ft-xhZDFHKkefg1xeHTpsJFje6x
# with n_epochs 1
# with prompt_loss_weight:  0.01
#
#
#
# ['ft-dIXqYeDE6SxIqu9YuSONpyGk', 'ft-xhZDFHKkefg1xeHTpsJFje6x']
# Initialized job ft-70qbiGyetRyJer91QIMZPucH
# with n_epochs 1
# with prompt_loss_weight:  0.05
#
#
#
# ['ft-dIXqYeDE6SxIqu9YuSONpyGk', 'ft-xhZDFHKkefg1xeHTpsJFje6x', 'ft-70qbiGyetRyJer91QIMZPucH']
# Initialized job ft-OnIiKCCSeg5Fbnj5WHCkRcEr
# with n_epochs 1
# with prompt_loss_weight:  0.1
#
#
#
# ['ft-dIXqYeDE6SxIqu9YuSONpyGk', 'ft-xhZDFHKkefg1xeHTpsJFje6x', 'ft-70qbiGyetRyJer91QIMZPucH', 'ft-OnIiKCCSeg5Fbnj5WHCkRcEr']

# %%
# !openai api fine_tunes.get -i "ft-dIXqYeDE6SxIqu9YuSONpyGk"
# Out:
# {
#   "created_at": 1670663027,
#   "events": [
#     {
#       "created_at": 1670663027,
#       "level": "info",
#       "message": "Created fine-tune: ft-dIXqYeDE6SxIqu9YuSONpyGk",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": null,
#     "learning_rate_multiplier": null,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.0
#   },
#   "id": "ft-dIXqYeDE6SxIqu9YuSONpyGk",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 166940,
#       "created_at": 1670610732,
#       "filename": "file",
#       "id": "file-EmAzSAkmrINIyLAKarVjR61g",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670663027,
#   "validation_files": [
#     {
#       "bytes": 335949,
#       "created_at": 1670610733,
#       "filename": "file",
#       "id": "file-pu9igDtwPC2BUQSDsyMfRMFH",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
finetuning_ids_hp_tuning = ['ft-dIXqYeDE6SxIqu9YuSONpyGk', 'ft-xhZDFHKkefg1xeHTpsJFje6x', 'ft-70qbiGyetRyJer91QIMZPucH', 'ft-OnIiKCCSeg5Fbnj5WHCkRcEr']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-dIXqYeDE6SxIqu9YuSONpyGk ...
# [2022-12-10 09:03:47] Created fine-tune: ft-dIXqYeDE6SxIqu9YuSONpyGk
# [2022-12-10 10:25:28] Fine-tune costs $1.16
# [2022-12-10 10:25:28] Fine-tune enqueued. Queue number: 0
# [2022-12-10 10:25:30] Fine-tune started
# [2022-12-10 10:28:02] Completed epoch 1/1
# [2022-12-10 10:28:44] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-100-prompt-loss-weight-2022-12-10-10-28-44
# [2022-12-10 10:28:45] Uploaded result file: file-U4q0QmQngU0z3b2dOkPiboXO
# [2022-12-10 10:28:45] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-100-prompt-loss-weight-2022-12-10-10-28-44 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-xhZDFHKkefg1xeHTpsJFje6x ...
# [2022-12-10 09:03:47] Created fine-tune: ft-xhZDFHKkefg1xeHTpsJFje6x
# [2022-12-10 10:28:47] Fine-tune costs $1.16
# [2022-12-10 10:28:47] Fine-tune enqueued. Queue number: 0
# [2022-12-10 10:28:48] Fine-tune started
# [2022-12-10 10:31:11] Completed epoch 1/1
# [2022-12-10 10:31:52] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-100-prompt-loss-weight-2022-12-10-10-31-52
# [2022-12-10 10:31:53] Uploaded result file: file-AxREBgZ7wfsiu6VKikHvGYNH
# [2022-12-10 10:31:53] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-100-prompt-loss-weight-2022-12-10-10-31-52 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-70qbiGyetRyJer91QIMZPucH ...
# [2022-12-10 09:03:47] Created fine-tune: ft-70qbiGyetRyJer91QIMZPucH
# [2022-12-10 10:31:55] Fine-tune costs $1.16
# [2022-12-10 10:31:56] Fine-tune enqueued. Queue number: 0
# [2022-12-10 10:31:57] Fine-tune started
# [2022-12-10 10:34:30] Completed epoch 1/1
# [2022-12-10 10:35:12] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-100-prompt-loss-weight-2022-12-10-10-35-11
# [2022-12-10 10:35:13] Uploaded result file: file-8PBgnNllSxRuEvOP4E480ht7
# [2022-12-10 10:35:14] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-100-prompt-loss-weight-2022-12-10-10-35-11 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-OnIiKCCSeg5Fbnj5WHCkRcEr ...
# [2022-12-10 09:03:47] Created fine-tune: ft-OnIiKCCSeg5Fbnj5WHCkRcEr
# [2022-12-10 10:35:16] Fine-tune costs $1.16
# [2022-12-10 10:35:16] Fine-tune enqueued. Queue number: 0
# [2022-12-10 10:35:18] Fine-tune started
# [2022-12-10 10:37:40] Completed epoch 1/1
# [2022-12-10 10:38:21] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-100-prompt-loss-weight-2022-12-10-10-38-21
# [2022-12-10 10:38:22] Uploaded result file: file-FrCHgllOpvSaTMt2Qb2jHCir
# [2022-12-10 10:38:22] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-100-prompt-loss-weight-2022-12-10-10-38-21 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-dIXqYeDE6SxIqu9YuSONpyGk', 'ft-xhZDFHKkefg1xeHTpsJFje6x', 'ft-70qbiGyetRyJer91QIMZPucH', 'ft-OnIiKCCSeg5Fbnj5WHCkRcEr']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221210_154950-ft-dIXqYeDE6SxIqu9YuSONpyGk</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-dIXqYeDE6SxIqu9YuSONpyGk" target="_blank">ft-dIXqYeDE6SxIqu9YuSONpyGk</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>training_loss</td><td>▃▄▃▃▅▂▂█▃▂▃▃▂▄▄▄▂▃▂▂▂▄▂▂▃▂▃▃▃▃▂▄▂▁▁▂▃▃▁▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▂▂█▄▆▅▁▂▂▁▄▅▅▅▃▄▁█▂▃▅▅▅▅▂▅▄▅▄▄▅▃▇▇▆▄▆█▅</td></tr><tr><td>validation_loss</td><td>█▇▃▄▆▄█▆▃▁▅▃▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▅█▃▁█▅▆▆▄▃▃▃▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>101.0</td></tr><tr><td>elapsed_tokens</td><td>39469.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.12533</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.63043</td></tr><tr><td>validation_loss</td><td>0.18584</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.52174</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-dIXqYeDE6SxIqu9YuSONpyGk</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-dIXqYeDE6SxIqu9YuSONpyGk" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-dIXqYeDE6SxIqu9YuSONpyGk</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221210_154950-ft-dIXqYeDE6SxIqu9YuSONpyGk/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221210_154958-ft-xhZDFHKkefg1xeHTpsJFje6x</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-xhZDFHKkefg1xeHTpsJFje6x" target="_blank">ft-xhZDFHKkefg1xeHTpsJFje6x</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>█▃▁▃▄▃▃▅▆▆▂▁▃▂▄▃▁▆▇▂▃▆▅▂█▂▃▄▂▇▇▃▆▃█▃▄▂▄▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▁▄▆█▃▅▅▄▄▄▅█▄▇▆██▄▁▂▇▂▆▅▂▅▃▄▃▅▂▃▅▃▂▃▄▃▆▆</td></tr><tr><td>validation_loss</td><td>▄▄▄▂▁█▁▃▃▄▁▄▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▆▄▃▃▅▅▆▁▄▅█▂▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>101.0</td></tr><tr><td>elapsed_tokens</td><td>39381.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.18571</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.67391</td></tr><tr><td>validation_loss</td><td>0.15743</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.66667</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-xhZDFHKkefg1xeHTpsJFje6x</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-xhZDFHKkefg1xeHTpsJFje6x" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-xhZDFHKkefg1xeHTpsJFje6x</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221210_154958-ft-xhZDFHKkefg1xeHTpsJFje6x/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221210_155006-ft-70qbiGyetRyJer91QIMZPucH</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-70qbiGyetRyJer91QIMZPucH" target="_blank">ft-70qbiGyetRyJer91QIMZPucH</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>█▃▁▃▄▃▄▅▆▅▃▁▄▂▄▃▁▆▇▃▃▆▄▂▇▃▃▄▂▇▆▃▅▃▇▃▄▂▄▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▁▄▆▇▃▅▄▃▄▄▅▆▃▇▅█▇▄▁▁▇▃▅▅▂▅▃▅▃▆▃▃▅▃▂▃▃▄▆▆</td></tr><tr><td>validation_loss</td><td>▄▅▄▃▂█▂▃▄▄▁▄▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▆▄▄▃▆▆▆▁▄▅█▂▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>101.0</td></tr><tr><td>elapsed_tokens</td><td>39381.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.25663</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.67391</td></tr><tr><td>validation_loss</td><td>0.22668</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.62222</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-70qbiGyetRyJer91QIMZPucH</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-70qbiGyetRyJer91QIMZPucH" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-70qbiGyetRyJer91QIMZPucH</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221210_155006-ft-70qbiGyetRyJer91QIMZPucH/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221210_155013-ft-OnIiKCCSeg5Fbnj5WHCkRcEr</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-OnIiKCCSeg5Fbnj5WHCkRcEr" target="_blank">ft-OnIiKCCSeg5Fbnj5WHCkRcEr</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>█▃▁▂▄▃▄▄▅▅▃▂▄▂▄▂▁▆▇▄▃▆▄▂▆▃▃▄▂▇▅▃▄▃▇▃▃▂▄▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▁▄▆█▃▄▅▄▄▄▅▇▄▇▆██▄▁▁█▃▆▅▂▅▂▅▃▆▂▃▅▃▂▃▃▄▆▆</td></tr><tr><td>validation_loss</td><td>▅▆▅▄▂█▂▄▅▄▁▅▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▆▄▄▃▅▄▆▁▅▅█▂▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>101.0</td></tr><tr><td>elapsed_tokens</td><td>39381.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.34501</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.65217</td></tr><tr><td>validation_loss</td><td>0.30983</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.6</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-OnIiKCCSeg5Fbnj5WHCkRcEr</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-OnIiKCCSeg5Fbnj5WHCkRcEr" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-OnIiKCCSeg5Fbnj5WHCkRcEr</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221210_155013-ft-OnIiKCCSeg5Fbnj5WHCkRcEr/logs</code>

# %% [markdown]
# ## Learning rate Multiplier
#
# n_epochs=1
#
# prompt_loss_weight = 0
#
# learning_rate_multiplier = 0.02, 0.05, 0.1, or 0.2
#
# **Results**:
#
# *   learning_rate_multiplier 0.02: 6.79
# *   learning_rate_multiplier 0.05: 6.49
# *   learning_rate_multiplier 0.1: 6.5
# *   learning_rate_multiplier 0.2: 6.6
#
# **Best Epoch**:

# %%
final_tag = "hp_tuning_human_100_lr"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0],
                "learning_rate_multiplier": [0.02, 0.05, 0.1, 0.2]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
train_data_id = "file-EmAzSAkmrINIyLAKarVjR61g"
dev_data_id = "file-pu9igDtwPC2BUQSDsyMfRMFH"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight_and_lr(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-oj75vYLjM0aIbnMCHhxeo8eH
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-oj75vYLjM0aIbnMCHhxeo8eH']
# Initialized job ft-I493KatOg9VKz13A0zyY1OWd
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-oj75vYLjM0aIbnMCHhxeo8eH', 'ft-I493KatOg9VKz13A0zyY1OWd']
# Initialized job ft-rH5dkD2FMScT5FCfAMtOvoJz
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-oj75vYLjM0aIbnMCHhxeo8eH', 'ft-I493KatOg9VKz13A0zyY1OWd', 'ft-rH5dkD2FMScT5FCfAMtOvoJz']
# Initialized job ft-QYlMyKDz8qaqwf0OBKixmV2A
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-oj75vYLjM0aIbnMCHhxeo8eH', 'ft-I493KatOg9VKz13A0zyY1OWd', 'ft-rH5dkD2FMScT5FCfAMtOvoJz', 'ft-QYlMyKDz8qaqwf0OBKixmV2A']

# %%
# !openai api fine_tunes.get -i "ft-dIXqYeDE6SxIqu9YuSONpyGk"

# %%
finetuning_ids_hp_tuning = ['ft-oj75vYLjM0aIbnMCHhxeo8eH', 'ft-I493KatOg9VKz13A0zyY1OWd', 'ft-rH5dkD2FMScT5FCfAMtOvoJz', 'ft-QYlMyKDz8qaqwf0OBKixmV2A']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-oj75vYLjM0aIbnMCHhxeo8eH ...
# [2022-12-11 10:34:53] Created fine-tune: ft-oj75vYLjM0aIbnMCHhxeo8eH
# [2022-12-11 10:34:54] Fine-tune costs $1.16
# [2022-12-11 10:34:54] Fine-tune enqueued. Queue number: 3
# [2022-12-11 10:38:14] Fine-tune is in the queue. Queue number: 2
# [2022-12-11 10:47:46] Fine-tune is in the queue. Queue number: 1
# [2022-12-11 11:27:02] Fine-tune is in the queue. Queue number: 0
# [2022-12-11 11:27:03] Fine-tune started
# [2022-12-11 11:29:35] Completed epoch 1/1
# [2022-12-11 11:30:18] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-100-lr-2022-12-11-11-30-17
# [2022-12-11 11:30:18] Uploaded result file: file-0vIbHMkBc6WywvKxsDnfpAy2
# [2022-12-11 11:30:19] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-100-lr-2022-12-11-11-30-17 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-I493KatOg9VKz13A0zyY1OWd ...
# [2022-12-11 10:34:53] Created fine-tune: ft-I493KatOg9VKz13A0zyY1OWd
# [2022-12-11 12:38:17] Fine-tune costs $1.16
# [2022-12-11 12:38:17] Fine-tune enqueued. Queue number: 0
# [2022-12-11 12:38:20] Fine-tune started
# [2022-12-11 12:40:41] Completed epoch 1/1
# [2022-12-11 12:41:23] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-100-lr-2022-12-11-12-41-23
# [2022-12-11 12:41:24] Uploaded result file: file-4DLTKaYdGoRnijZqo1FFT1Zs
# [2022-12-11 12:41:24] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-100-lr-2022-12-11-12-41-23 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-rH5dkD2FMScT5FCfAMtOvoJz ...
# [2022-12-11 10:34:53] Created fine-tune: ft-rH5dkD2FMScT5FCfAMtOvoJz
# [2022-12-11 12:41:29] Fine-tune costs $1.16
# [2022-12-11 12:41:30] Fine-tune enqueued. Queue number: 0
# [2022-12-11 12:41:32] Fine-tune started
# [2022-12-11 12:43:52] Completed epoch 1/1
# [2022-12-11 12:44:36] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-100-lr-2022-12-11-12-44-35
# [2022-12-11 12:44:37] Uploaded result file: file-P7jZ8VGXCFbuyjcQwvopj5d6
# [2022-12-11 12:44:37] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-100-lr-2022-12-11-12-44-35 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-QYlMyKDz8qaqwf0OBKixmV2A ...
# [2022-12-11 10:34:54] Created fine-tune: ft-QYlMyKDz8qaqwf0OBKixmV2A
# [2022-12-11 12:44:38] Fine-tune costs $1.16
# [2022-12-11 12:44:38] Fine-tune enqueued. Queue number: 0
# [2022-12-11 12:44:39] Fine-tune started
# [2022-12-11 12:47:02] Completed epoch 1/1
# [2022-12-11 12:47:42] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-100-lr-2022-12-11-12-47-42
# [2022-12-11 12:47:43] Uploaded result file: file-JxrveQp7jqmUGZOLjtFqyuO6
# [2022-12-11 12:47:43] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-100-lr-2022-12-11-12-47-42 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-oj75vYLjM0aIbnMCHhxeo8eH', 'ft-I493KatOg9VKz13A0zyY1OWd', 'ft-rH5dkD2FMScT5FCfAMtOvoJz', 'ft-QYlMyKDz8qaqwf0OBKixmV2A']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_130033-ft-oj75vYLjM0aIbnMCHhxeo8eH</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-oj75vYLjM0aIbnMCHhxeo8eH" target="_blank">ft-oj75vYLjM0aIbnMCHhxeo8eH</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▇▃▄▁▅▄▇▄█▄▄▄▄▃▂▁▁▃▂▃▂▃▁▃▃▂▃▂▃▃▂▂▃▂▂▂▃▂▃▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▂▅▃▇▃▆▂▃▃▄▄▂▂▃▄▄▇▁▄▂▆▃█▂▅▅▆▇▄▂▆▅▃▄▄█▂▂▆█</td></tr><tr><td>validation_loss</td><td>▆▃▂▁▅█▅▂▂▆▇▁█</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▃▅█▄▁▇▃▁█▁▃▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>101.0</td></tr><tr><td>elapsed_tokens</td><td>39269.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.14642</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.76087</td></tr><tr><td>validation_loss</td><td>0.23824</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.45455</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-oj75vYLjM0aIbnMCHhxeo8eH</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-oj75vYLjM0aIbnMCHhxeo8eH" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-oj75vYLjM0aIbnMCHhxeo8eH</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_130033-ft-oj75vYLjM0aIbnMCHhxeo8eH/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_130040-ft-I493KatOg9VKz13A0zyY1OWd</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-I493KatOg9VKz13A0zyY1OWd" target="_blank">ft-I493KatOg9VKz13A0zyY1OWd</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▆▆▅▃▅▅▅▅▂█▃▃▆▅▆▃▆▂▇▅▄▃▃▄▃▆▃▆▃█▅▄▇▄▅▂▃▁▄▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▅▁▂▅▂▄▄▅▃▅▄▂▂▃▃▄▇▄▃▃▇▄▂▆▃▅▄▄▁▂▄▃▅▃▃▆█▄▅</td></tr><tr><td>validation_loss</td><td>▂▄▅▅▂█▁▄▃▁▁▃▃</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>█▇▁▆▇▅▄▆▆▅▇▇▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>101.0</td></tr><tr><td>elapsed_tokens</td><td>39333.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.12612</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.66667</td></tr><tr><td>validation_loss</td><td>0.14639</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.45238</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-I493KatOg9VKz13A0zyY1OWd</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-I493KatOg9VKz13A0zyY1OWd" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-I493KatOg9VKz13A0zyY1OWd</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_130040-ft-I493KatOg9VKz13A0zyY1OWd/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_130048-ft-rH5dkD2FMScT5FCfAMtOvoJz</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-rH5dkD2FMScT5FCfAMtOvoJz" target="_blank">ft-rH5dkD2FMScT5FCfAMtOvoJz</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▆▆▅▃▅▅▅▅▂▇▃▃▆▅▆▂▆▂▇▅▄▃▃▄▂▅▃▆▃█▅▄▆▄▅▃▃▁▄▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▅▁▂▆▃▅▄▆▄▅▃▂▂▃▄▄▇▅▂▃█▃▁▇▃▅▄▃▁▂▄▄▅▄▃▆█▄▅</td></tr><tr><td>validation_loss</td><td>▂▃▄▅▂█▁▄▃▁▁▂▃</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▇▅▁▆█▅▄▇▆▅▇▇▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>101.0</td></tr><tr><td>elapsed_tokens</td><td>39333.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.11673</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.64286</td></tr><tr><td>validation_loss</td><td>0.14574</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.45238</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-rH5dkD2FMScT5FCfAMtOvoJz</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-rH5dkD2FMScT5FCfAMtOvoJz" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-rH5dkD2FMScT5FCfAMtOvoJz</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_130048-ft-rH5dkD2FMScT5FCfAMtOvoJz/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_130056-ft-QYlMyKDz8qaqwf0OBKixmV2A</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-QYlMyKDz8qaqwf0OBKixmV2A" target="_blank">ft-QYlMyKDz8qaqwf0OBKixmV2A</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▇▆▄▃▅▅▅▆▂▇▃▃▆▅▇▂▆▂▇▅▅▃▃▄▃▅▃▆▃█▅▅▇▄▅▂▃▁▄▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▅▁▂▆▃▅▃▅▄▄▃▂▂▂▆▄▇▅▃▂█▃▂▆▄▄▅▃▁▂▄▄▅▄▂▅█▄▄</td></tr><tr><td>validation_loss</td><td>▂▃▄▅▃█▂▄▃▁▁▂▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>█▇▁▇█▅▄▇▆▄██▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>101.0</td></tr><tr><td>elapsed_tokens</td><td>39333.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.10436</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.61905</td></tr><tr><td>validation_loss</td><td>0.15216</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.42857</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-QYlMyKDz8qaqwf0OBKixmV2A</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-QYlMyKDz8qaqwf0OBKixmV2A" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-QYlMyKDz8qaqwf0OBKixmV2A</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_130056-ft-QYlMyKDz8qaqwf0OBKixmV2A/logs</code>

# %% [markdown]
# ## Final Run - Refinements

# %%
final_tag = "final_run_100_refinements"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0],
                "learning_rate_multiplier": [0.05]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/selected_refinement_finetuning_dataset_top_1_train_100.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
dev_data = "summarization_finetuning_datasets/selected_refinement_finetuning_dataset_top_1_development_200.jsonl"
dev_data_id = upload_dataset_to_openai(dev_data)
print("Train dataset id {}".format(train_data_id))
print("Validation dataset id {}".format(dev_data_id))
# Out:
# Train dataset id file-4cCT2tQHzo2orTNek3f9lw5K
# Validation dataset id file-JotOYuLabOvhSTzdgu0KNl10

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight_and_lr(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-0OUB6VCMm0nijxjj8wMV4zsr
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-0OUB6VCMm0nijxjj8wMV4zsr']

# %%
# !openai api fine_tunes.get -i "ft-0OUB6VCMm0nijxjj8wMV4zsr"
# Out:
# {
#   "created_at": 1670772867,
#   "events": [
#     {
#       "created_at": 1670772867,
#       "level": "info",
#       "message": "Created fine-tune: ft-0OUB6VCMm0nijxjj8wMV4zsr",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670772872,
#       "level": "info",
#       "message": "Fine-tune costs $1.14",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670772873,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 3",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670772880,
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 2",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": 1,
#     "learning_rate_multiplier": 0.05,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.0
#   },
#   "id": "ft-0OUB6VCMm0nijxjj8wMV4zsr",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 164447,
#       "created_at": 1670772850,
#       "filename": "file",
#       "id": "file-4cCT2tQHzo2orTNek3f9lw5K",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670772880,
#   "validation_files": [
#     {
#       "bytes": 332653,
#       "created_at": 1670772852,
#       "filename": "file",
#       "id": "file-JotOYuLabOvhSTzdgu0KNl10",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
finetuning_ids_hp_tuning = ['ft-0OUB6VCMm0nijxjj8wMV4zsr']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-0OUB6VCMm0nijxjj8wMV4zsr ...
# [2022-12-11 15:34:27] Created fine-tune: ft-0OUB6VCMm0nijxjj8wMV4zsr
# [2022-12-11 15:34:32] Fine-tune costs $1.14
# [2022-12-11 15:34:33] Fine-tune enqueued. Queue number: 3
# [2022-12-11 15:34:40] Fine-tune is in the queue. Queue number: 2
# [2022-12-11 15:35:28] Fine-tune is in the queue. Queue number: 1
# [2022-12-11 15:40:51] Fine-tune is in the queue. Queue number: 0
# [2022-12-11 15:46:21] Fine-tune started
# [2022-12-11 15:48:58] Completed epoch 1/1
# [2022-12-11 15:49:35] Uploaded model: davinci:ft-academicsnyuperez:final-run-100-refinements-2022-12-11-15-49-34
# [2022-12-11 15:49:36] Uploaded result file: file-Kil25fQxt5qmdgOMuprbqHiI
# [2022-12-11 15:49:36] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:final-run-100-refinements-2022-12-11-15-49-34 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-0OUB6VCMm0nijxjj8wMV4zsr']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_173344-ft-0OUB6VCMm0nijxjj8wMV4zsr</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-0OUB6VCMm0nijxjj8wMV4zsr" target="_blank">ft-0OUB6VCMm0nijxjj8wMV4zsr</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▂▄▃▂▅▃▂▃▅▄▃▅▃▂█▅▃▂▃▅▃▂▁▂▁▄▃▂▁▄▃▅▃▃▂▄▂▂▃▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▆▁▄▅▅▆▆▇▄▅▅▃▅▅▁▅▅▄▆▄▂▄▇▅▆▃▄▅█▅▃▄▅▄▃▄▄▆▅▃</td></tr><tr><td>validation_loss</td><td>▆▇█▂▅▆▆█▂▁▇▁▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▁█▆▆▆▁▃▇▄▆█▄▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>101.0</td></tr><tr><td>elapsed_tokens</td><td>39005.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.11126</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.6</td></tr><tr><td>validation_loss</td><td>0.11648</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.61765</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-0OUB6VCMm0nijxjj8wMV4zsr</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-0OUB6VCMm0nijxjj8wMV4zsr" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-0OUB6VCMm0nijxjj8wMV4zsr</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_173344-ft-0OUB6VCMm0nijxjj8wMV4zsr/logs</code>

# %% [markdown]
# ## Fianl Run - Intial Summaries

# %%
final_tag = "final_run_100_refinements"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0],
                "learning_rate_multiplier": [0.05]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/initial_summary_finetuning_dataset_train_100.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
dev_data = "summarization_finetuning_datasets/initial_summary_finetuning_dataset_development_200.jsonl"
dev_data_id = upload_dataset_to_openai(dev_data)
print("Train dataset id {}".format(train_data_id))
print("Validation dataset id {}".format(dev_data_id))
# Out:
# Train dataset id file-6kesvUvXy4AkKEtgWcEqnspn
# Validation dataset id file-6Y7Q4g9LIiuVZ3TfCVcxJI0s

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight_and_lr(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-d9lxpfYcGUgNPf2xPkBonzvb
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-d9lxpfYcGUgNPf2xPkBonzvb']

# %%
# !openai api fine_tunes.get -i "ft-dIXqYeDE6SxIqu9YuSONpyGk"

# %%
finetuning_ids_hp_tuning = ['ft-d9lxpfYcGUgNPf2xPkBonzvb']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-d9lxpfYcGUgNPf2xPkBonzvb ...
# [2022-12-11 15:35:32] Created fine-tune: ft-d9lxpfYcGUgNPf2xPkBonzvb
# [2022-12-11 15:49:36] Fine-tune costs $1.12
# [2022-12-11 15:49:37] Fine-tune enqueued. Queue number: 0
# [2022-12-11 15:49:38] Fine-tune started
# [2022-12-11 15:52:01] Completed epoch 1/1
# [2022-12-11 15:52:52] Uploaded model: davinci:ft-academicsnyuperez:final-run-100-initial-summaries-2022-12-11-15-52-52
# [2022-12-11 15:52:53] Uploaded result file: file-GaX7UyBQK2DqLsDLI1N64fMg
# [2022-12-11 15:52:53] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:final-run-100-initial-summaries-2022-12-11-15-52-52 -p <YOUR_PROMPT>

# %%
#finetuning_ids_hp_tuning = ['ft-d9lxpfYcGUgNPf2xPkBonzvb']
#for finetuning_id in finetuning_ids_hp_tuning:
#  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# !openai wandb sync --id "ft-d9lxpfYcGUgNPf2xPkBonzvb" --project "training_language_models_with_langauge_feedback" --force
# Out:
# wandb: Currently logged in as: jerry_crea. Use `wandb login --relogin` to force relogin
# A run for fine-tune ft-d9lxpfYcGUgNPf2xPkBonzvb was previously created but didn't end successfully
# A new wandb run will be created for fine-tune ft-d9lxpfYcGUgNPf2xPkBonzvb and previous run will be overwritten
# wandb: wandb version 0.13.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.13.5
# wandb: Run data is saved locally in /content/wandb/run-20221211_173917-ft-d9lxpfYcGUgNPf2xPkBonzvb
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run ft-d9lxpfYcGUgNPf2xPkBonzvb
# wandb: ⭐️ View project at https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback
# wandb: 🚀 View run at https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-d9lxpfYcGUgNPf2xPkBonzvb
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb: Run history:
# wandb:             elapsed_examples ▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███
# wandb:               elapsed_tokens ▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███
# wandb:                training_loss ▂▂▃▂▄▂▃▄▃▅▂▄▄▁█▄▃▃▃▅▁▂▂▃▂▅▄▃▂▄▃▄▄▃▁▂▃▁▁▂
# wandb:   training_sequence_accuracy ▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:      training_token_accuracy ▃▄▁▄▃▇▅▅▃▂▃▂▃█▁▄▃▄▅▄▄▃▆▄▅▂▄▃▇▃▄▄▁▂▄▅▅▆▇▆
# wandb:              validation_loss ▆█▄▄▅▄▅▄▄▃█▁▅
# wandb: validation_sequence_accuracy ▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:    validation_token_accuracy ▆▇█▅█▂▁▆▅▆▆▆▆
# wandb:
# wandb: Run summary:
# wandb:             elapsed_examples 101.0
# wandb:               elapsed_tokens 38293.0
# wandb:             fine_tuned_model davinci:ft-academics...
# wandb:                       status succeeded
# wandb:                training_loss 0.03836
# wandb:   training_sequence_accuracy 0.0
# wandb:      training_token_accuracy 0.81818
# wandb:              validation_loss 0.08662
# wandb: validation_sequence_accuracy 0.0
# wandb:    validation_token_accuracy 0.72917
# wandb:
# wandb: Synced ft-d9lxpfYcGUgNPf2xPkBonzvb: https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-d9lxpfYcGUgNPf2xPkBonzvb
# wandb: Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20221211_173917-ft-d9lxpfYcGUgNPf2xPkBonzvb/logs
# 🎉 wandb sync completed successfully

# %% [markdown]
# # Data Set Size 1K
#
# *Final Parameters*
#
# n_epochs=1
#
# prompt_loss_weight = 0
#
# learning_rate_multiplier = 0.02

# %% [markdown]
# ## Epochs
#
# n_epochs=1,2,3,4
#
# **Results**:
#
# *   Epoch 1: 6.73
# *   Epoch 2: 7.16
# *   Epoch 3: 8.7
# *   Epoch 4:11.69
#
# **Best Epoch**: 1

# %%
final_tag = "hp_tuning_human_1K_n_epochs"
parameter_combinations = {
                "n_epochs":[1,2,3,4], 
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/ideal_human_summary_finetuning_dataset_train_1000.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
dev_data = "summarization_finetuning_datasets/ideal_human_summary_finetuning_dataset_development_200.jsonl"
dev_data_id = upload_dataset_to_openai(dev_data)
print("Train dataset id {}".format(train_data_id))
print("Validation dataset id {}".format(dev_data_id))
# Out:
# Train dataset id file-t443KKz8t7tzjRJKdY5hvolj
# Validation dataset id file-tOqIGbtK4VtEgmFLhnzjSEwO

# %%
train_data_id = "file-t443KKz8t7tzjRJKdY5hvolj"
dev_data_id = "file-tOqIGbtK4VtEgmFLhnzjSEwO"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs(n_epochs=n_epochs, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-Ojq9WNAdDARzD6x1vYwWR03A
# with n_epochs 1
#
#
#
# ['ft-Ojq9WNAdDARzD6x1vYwWR03A']
# Initialized job ft-jiuEU2mRhb85kST1OtPTsz0g
# with n_epochs 2
#
#
#
# ['ft-Ojq9WNAdDARzD6x1vYwWR03A', 'ft-jiuEU2mRhb85kST1OtPTsz0g']
# Initialized job ft-j5F3r1eXsNxag0TkRqnotTCA
# with n_epochs 3
#
#
#
# ['ft-Ojq9WNAdDARzD6x1vYwWR03A', 'ft-jiuEU2mRhb85kST1OtPTsz0g', 'ft-j5F3r1eXsNxag0TkRqnotTCA']
# Initialized job ft-C9Bt2APglVxwtfFO9bCxqH3z
# with n_epochs 4
#
#
#
# ['ft-Ojq9WNAdDARzD6x1vYwWR03A', 'ft-jiuEU2mRhb85kST1OtPTsz0g', 'ft-j5F3r1eXsNxag0TkRqnotTCA', 'ft-C9Bt2APglVxwtfFO9bCxqH3z']

# %%
# !openai api fine_tunes.get -i "ft-Ojq9WNAdDARzD6x1vYwWR03A"
# Out:
# {
#   "created_at": 1670661243,
#   "events": [
#     {
#       "created_at": 1670661243,
#       "level": "info",
#       "message": "Created fine-tune: ft-Ojq9WNAdDARzD6x1vYwWR03A",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670661246,
#       "level": "info",
#       "message": "Fine-tune costs $11.94",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670661247,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 0",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670661250,
#       "level": "info",
#       "message": "Fine-tune started",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670661941,
#       "level": "info",
#       "message": "Completed epoch 1/1",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670661992,
#       "level": "info",
#       "message": "Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-n-epochs-2022-12-10-08-46-32",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670661993,
#       "level": "info",
#       "message": "Uploaded result file: file-P1wVhhnku89itS3hDQSjuw4o",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670661994,
#       "level": "info",
#       "message": "Fine-tune succeeded",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": "davinci:ft-academicsnyuperez:hp-tuning-human-1k-n-epochs-2022-12-10-08-46-32",
#   "hyperparams": {
#     "batch_size": 2,
#     "learning_rate_multiplier": 0.1,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.01
#   },
#   "id": "ft-Ojq9WNAdDARzD6x1vYwWR03A",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [
#     {
#       "bytes": 32228,
#       "created_at": 1670661993,
#       "filename": "compiled_results.csv",
#       "id": "file-P1wVhhnku89itS3hDQSjuw4o",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "status": "succeeded",
#   "training_files": [
#     {
#       "bytes": 1719755,
#       "created_at": 1670661210,
#       "filename": "file",
#       "id": "file-t443KKz8t7tzjRJKdY5hvolj",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670661994,
#   "validation_files": [
#     {
#       "bytes": 335949,
#       "created_at": 1670661211,
#       "filename": "file",
#       "id": "file-tOqIGbtK4VtEgmFLhnzjSEwO",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
finetuning_ids_hp_tuning = ['ft-Ojq9WNAdDARzD6x1vYwWR03A', 'ft-jiuEU2mRhb85kST1OtPTsz0g', 'ft-j5F3r1eXsNxag0TkRqnotTCA', 'ft-C9Bt2APglVxwtfFO9bCxqH3z']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-Ojq9WNAdDARzD6x1vYwWR03A ...
# [2022-12-10 08:34:03] Created fine-tune: ft-Ojq9WNAdDARzD6x1vYwWR03A
# [2022-12-10 08:34:06] Fine-tune costs $11.94
# [2022-12-10 08:34:07] Fine-tune enqueued. Queue number: 0
# [2022-12-10 08:34:10] Fine-tune started
# [2022-12-10 08:45:41] Completed epoch 1/1
# [2022-12-10 08:46:32] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-n-epochs-2022-12-10-08-46-32
# [2022-12-10 08:46:33] Uploaded result file: file-P1wVhhnku89itS3hDQSjuw4o
# [2022-12-10 08:46:34] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-1k-n-epochs-2022-12-10-08-46-32 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-jiuEU2mRhb85kST1OtPTsz0g ...
# [2022-12-10 08:34:04] Created fine-tune: ft-jiuEU2mRhb85kST1OtPTsz0g
# [2022-12-10 08:46:38] Fine-tune costs $23.88
# [2022-12-10 08:46:39] Fine-tune enqueued. Queue number: 0
# [2022-12-10 08:48:02] Fine-tune started
# [2022-12-10 08:59:30] Completed epoch 1/2
# [2022-12-10 09:09:32] Completed epoch 2/2
# [2022-12-10 09:10:13] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-n-epochs-2022-12-10-09-10-13
# [2022-12-10 09:10:14] Uploaded result file: file-Enuz6Ln4jju9RFHYH5sziItl
# [2022-12-10 09:10:15] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-1k-n-epochs-2022-12-10-09-10-13 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-j5F3r1eXsNxag0TkRqnotTCA ...
# [2022-12-10 08:34:04] Created fine-tune: ft-j5F3r1eXsNxag0TkRqnotTCA
# [2022-12-10 09:10:19] Fine-tune costs $35.82
# [2022-12-10 09:10:19] Fine-tune enqueued. Queue number: 0
# [2022-12-10 09:10:20] Fine-tune started
# [2022-12-10 09:21:57] Completed epoch 1/3
# [2022-12-10 09:32:08] Completed epoch 2/3
# [2022-12-10 09:42:12] Completed epoch 3/3
# [2022-12-10 09:42:51] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-n-epochs-2022-12-10-09-42-51
# [2022-12-10 09:42:52] Uploaded result file: file-gHyg59rbn1sLpFeQltR2pXmO
# [2022-12-10 09:42:52] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-1k-n-epochs-2022-12-10-09-42-51 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-C9Bt2APglVxwtfFO9bCxqH3z ...
# [2022-12-10 08:34:04] Created fine-tune: ft-C9Bt2APglVxwtfFO9bCxqH3z
# [2022-12-10 09:42:54] Fine-tune costs $47.76
# [2022-12-10 09:42:54] Fine-tune enqueued. Queue number: 0
# [2022-12-10 09:42:55] Fine-tune started
# [2022-12-10 09:54:26] Completed epoch 1/4
# [2022-12-10 10:04:30] Completed epoch 2/4
# [2022-12-10 10:14:33] Completed epoch 3/4
# [2022-12-10 10:24:40] Completed epoch 4/4
# [2022-12-10 10:25:25] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-n-epochs-2022-12-10-10-25-25
# [2022-12-10 10:25:27] Uploaded result file: file-zko2zQykennuPad0ER55iUh3
# [2022-12-10 10:25:27] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-1k-n-epochs-2022-12-10-10-25-25 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-Ojq9WNAdDARzD6x1vYwWR03A', 'ft-jiuEU2mRhb85kST1OtPTsz0g', 'ft-j5F3r1eXsNxag0TkRqnotTCA', 'ft-C9Bt2APglVxwtfFO9bCxqH3z']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: jerry_crea. Use `wandb login --relogin` to force relogin
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221210_154843-ft-Ojq9WNAdDARzD6x1vYwWR03A</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-Ojq9WNAdDARzD6x1vYwWR03A" target="_blank">ft-Ojq9WNAdDARzD6x1vYwWR03A</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▄▆▆▂▇▆█▆▆▅█▅▄▆▃▄▆▃▃▇▄▁▂▆▁▅▅▃▅▁▅▂▄▃▄█▃▅▅▄</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▃▃▄▆▄▃▃▄▄▃▃▁▅▅▄▅▃▅▆▁▄█▇▂▇▄▃▄▄▇▂▅▅▃▄▃▅▄▃▃</td></tr><tr><td>validation_loss</td><td>▆▅▄▆▃▃▂▅▃▅▇▄▆▅▄▄▆▆▆▂▃▇▆▄▅▅▆█▂▇▁▅▆▄▄▃▆▄▃▆</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▅█▃▄▅▁▇▂▄▄▂▂▄▆▁▃▃▃▃▆▂▃▃▅▂▅▅▄▇▄█▅▂▃▄▅▃▃▁▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>1004.0</td></tr><tr><td>elapsed_tokens</td><td>456508.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.13576</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.6129</td></tr><tr><td>validation_loss</td><td>0.16284</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.5</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-Ojq9WNAdDARzD6x1vYwWR03A</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-Ojq9WNAdDARzD6x1vYwWR03A" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-Ojq9WNAdDARzD6x1vYwWR03A</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221210_154843-ft-Ojq9WNAdDARzD6x1vYwWR03A/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221210_154853-ft-jiuEU2mRhb85kST1OtPTsz0g</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-jiuEU2mRhb85kST1OtPTsz0g" target="_blank">ft-jiuEU2mRhb85kST1OtPTsz0g</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▄█▅▇▃▅▂▄▇▃▄▃▅▅▆▂▆▂▅▃▄▆▂▃▃▄▇▅▁▆▃▃▅▃▃▅▁▄▄▅</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▁▃▃▅▃▆▅▄▃▅▆▄▄▂█▃█▄▆▅▆▅▇▅▅▃▅▇▅▄▆▅▆▇▄█▆▃▄</td></tr><tr><td>validation_loss</td><td>█▇▃▂▄▁█▂▃▃▃▅▂▅▂▄▅▄▃▃▄▄▂▂▄▃█▃▁▂▃▄▅▃▄▅▃▂▂▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▅▅▅▆▇▂▄▅▃▅▃▁▆▂▅▇▅▄▅▅▃▂▇▆▃▆▃▅▆▃▄█▃▇▁▂▆▅▄▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>2004.0</td></tr><tr><td>elapsed_tokens</td><td>911716.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.09285</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.74194</td></tr><tr><td>validation_loss</td><td>0.14028</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.58108</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-jiuEU2mRhb85kST1OtPTsz0g</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-jiuEU2mRhb85kST1OtPTsz0g" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-jiuEU2mRhb85kST1OtPTsz0g</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221210_154853-ft-jiuEU2mRhb85kST1OtPTsz0g/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221210_154901-ft-j5F3r1eXsNxag0TkRqnotTCA</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-j5F3r1eXsNxag0TkRqnotTCA" target="_blank">ft-j5F3r1eXsNxag0TkRqnotTCA</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▇▇█▆▃▅▃▅▃▆▃▆▅▃▄▄▄▆▆▂▄▆▅▅▃▄▅▄▃▃▄▂▄▂▄▆▃▃▄▁</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▃▁▁▄▂▄▂▅▂▆▄▂▅▅▄▂▂▃▅▃▂▂▅▄▄▂▅▅▄▄▇▄▆▅▄▄▅▆█</td></tr><tr><td>validation_loss</td><td>▃▄▂▄▇▅▄▄▃▄▁▂▃▂▄▇▁▁▄▃▄▅▂▄▃▃▂▅▄▃▅▂▅▃▂▇▃█▅▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▂▅█▁▅█▆▆▇▃█▅▆█▃▄▇▆▆▆▇▄█▆▆▅▆▅▆▇▄▅▁▅▆▆▄▂▇▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>3002.0</td></tr><tr><td>elapsed_tokens</td><td>1363866.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.07722</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.78161</td></tr><tr><td>validation_loss</td><td>0.19669</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.48</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-j5F3r1eXsNxag0TkRqnotTCA</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-j5F3r1eXsNxag0TkRqnotTCA" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-j5F3r1eXsNxag0TkRqnotTCA</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221210_154901-ft-j5F3r1eXsNxag0TkRqnotTCA/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221210_154912-ft-C9Bt2APglVxwtfFO9bCxqH3z</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-C9Bt2APglVxwtfFO9bCxqH3z" target="_blank">ft-C9Bt2APglVxwtfFO9bCxqH3z</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▇▆▃▃█▅▃▅▇▆▅▃▆▅▂▅▆▅▇▂▅▃▅▂▄▃▆▄▄▁▁▂▄▄▃▂▁▁▃▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▁▄▄▂▃▃▃▃▂▄▄▂▂▅▃▃▄▃▆▄▅▄▆▅▅▃▄▅██▆▄▄▆▇██▄▇</td></tr><tr><td>validation_loss</td><td>▃▅▂▆▃▅▂▄▄▃▂▂▂▅▁▃▄▃▃▂▁▃▃▂▄▃▆▃▃▂▄▅▄▅▄▄▃█▅▃</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▁▆▄▅▄▃▇▆▆▇█▂█▄▇▇▃▇▆▄▃▆▆▆▁▄▃▅▅▇▄▁▃▃▅▅▄▃▄▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>4002.0</td></tr><tr><td>elapsed_tokens</td><td>1817842.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.03389</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.94366</td></tr><tr><td>validation_loss</td><td>0.18964</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.55224</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-C9Bt2APglVxwtfFO9bCxqH3z</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-C9Bt2APglVxwtfFO9bCxqH3z" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-C9Bt2APglVxwtfFO9bCxqH3z</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221210_154912-ft-C9Bt2APglVxwtfFO9bCxqH3z/logs</code>

# %% [markdown]
# ## Prompt Loss Weight
# **Sweep**:
#
# n_epochs=1
#
# prompt_loss_weight = 0, 0.01, 0.05, 0.1
#
# **Results:**
#
#
# *   prompt_loss_weight 0 = 6.71
# *   prompt_loss_weight 0.01 = 6.681
# *   prompt_loss_weight 0.05 = 6.680
# *   prompt_loss_weight 0.1 = 6.683

# %%
final_tag = "hp_tuning_human_1K_prompt_loss_weight"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0, 0.01, 0.05, 0.1]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
train_data_id = "file-t443KKz8t7tzjRJKdY5hvolj"
dev_data_id = "file-tOqIGbtK4VtEgmFLhnzjSEwO"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-aFEjM3ZZNaBdM8zvvRScAgoi
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-aFEjM3ZZNaBdM8zvvRScAgoi']
# Initialized job ft-Z6Cur5qh1jrE9fpUGqXp4quv
# with n_epochs 1
# with prompt_loss_weight:  0.01
#
#
#
# ['ft-aFEjM3ZZNaBdM8zvvRScAgoi', 'ft-Z6Cur5qh1jrE9fpUGqXp4quv']
# Initialized job ft-1xZlLRMMO1tNT1XiF2YqAkX5
# with n_epochs 1
# with prompt_loss_weight:  0.05
#
#
#
# ['ft-aFEjM3ZZNaBdM8zvvRScAgoi', 'ft-Z6Cur5qh1jrE9fpUGqXp4quv', 'ft-1xZlLRMMO1tNT1XiF2YqAkX5']
# Initialized job ft-3cDuSd9kt7GElcQajrmUxV5L
# with n_epochs 1
# with prompt_loss_weight:  0.1
#
#
#
# ['ft-aFEjM3ZZNaBdM8zvvRScAgoi', 'ft-Z6Cur5qh1jrE9fpUGqXp4quv', 'ft-1xZlLRMMO1tNT1XiF2YqAkX5', 'ft-3cDuSd9kt7GElcQajrmUxV5L']

# %%
# !openai api fine_tunes.get -i "ft-Z6Cur5qh1jrE9fpUGqXp4quv"
# Out:
# {
#   "created_at": 1670755249,
#   "events": [
#     {
#       "created_at": 1670755249,
#       "level": "info",
#       "message": "Created fine-tune: ft-Z6Cur5qh1jrE9fpUGqXp4quv",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670758219,
#       "level": "info",
#       "message": "Fine-tune costs $11.94",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670758219,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 4",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670758221,
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 3",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670758357,
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 2",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670758555,
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 1",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670760623,
#       "level": "info",
#       "message": "Fine-tune is in the queue. Queue number: 0",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670760732,
#       "level": "info",
#       "message": "Fine-tune started",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670761423,
#       "level": "info",
#       "message": "Completed epoch 1/1",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670761495,
#       "level": "info",
#       "message": "Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-prompt-loss-weight-2022-12-11-12-24-55",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670761496,
#       "level": "info",
#       "message": "Uploaded result file: file-7g5EF9MzSKKOKxkm8jgtU4g5",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670761496,
#       "level": "info",
#       "message": "Fine-tune succeeded",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": "davinci:ft-academicsnyuperez:hp-tuning-human-1k-prompt-loss-weight-2022-12-11-12-24-55",
#   "hyperparams": {
#     "batch_size": 2,
#     "learning_rate_multiplier": 0.1,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.01
#   },
#   "id": "ft-Z6Cur5qh1jrE9fpUGqXp4quv",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [
#     {
#       "bytes": 32150,
#       "created_at": 1670761496,
#       "filename": "compiled_results.csv",
#       "id": "file-7g5EF9MzSKKOKxkm8jgtU4g5",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "status": "succeeded",
#   "training_files": [
#     {
#       "bytes": 1719755,
#       "created_at": 1670661210,
#       "filename": "file",
#       "id": "file-t443KKz8t7tzjRJKdY5hvolj",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670761496,
#   "validation_files": [
#     {
#       "bytes": 335949,
#       "created_at": 1670661211,
#       "filename": "file",
#       "id": "file-tOqIGbtK4VtEgmFLhnzjSEwO",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
finetuning_ids_hp_tuning = ['ft-aFEjM3ZZNaBdM8zvvRScAgoi', 'ft-Z6Cur5qh1jrE9fpUGqXp4quv', 'ft-1xZlLRMMO1tNT1XiF2YqAkX5', 'ft-3cDuSd9kt7GElcQajrmUxV5L']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-aFEjM3ZZNaBdM8zvvRScAgoi ...
# [2022-12-11 10:40:48] Created fine-tune: ft-aFEjM3ZZNaBdM8zvvRScAgoi
# [2022-12-11 12:47:45] Fine-tune costs $11.94
# [2022-12-11 12:47:45] Fine-tune enqueued. Queue number: 0
# [2022-12-11 12:47:46] Fine-tune started
# [2022-12-11 12:59:11] Completed epoch 1/1
# [2022-12-11 12:59:58] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-prompt-loss-weight-2022-12-11-12-59-58
# [2022-12-11 12:59:59] Uploaded result file: file-1Wrtb6s5fTda5oQzT7DK9Mvn
# [2022-12-11 12:59:59] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-1k-prompt-loss-weight-2022-12-11-12-59-58 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-Z6Cur5qh1jrE9fpUGqXp4quv ...
# [2022-12-11 10:40:49] Created fine-tune: ft-Z6Cur5qh1jrE9fpUGqXp4quv
# [2022-12-11 11:30:19] Fine-tune costs $11.94
# [2022-12-11 11:30:19] Fine-tune enqueued. Queue number: 4
# [2022-12-11 11:30:21] Fine-tune is in the queue. Queue number: 3
# [2022-12-11 11:32:37] Fine-tune is in the queue. Queue number: 2
# [2022-12-11 11:35:55] Fine-tune is in the queue. Queue number: 1
# [2022-12-11 12:10:23] Fine-tune is in the queue. Queue number: 0
# [2022-12-11 12:12:12] Fine-tune started
# [2022-12-11 12:23:43] Completed epoch 1/1
# [2022-12-11 12:24:55] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-prompt-loss-weight-2022-12-11-12-24-55
# [2022-12-11 12:24:56] Uploaded result file: file-7g5EF9MzSKKOKxkm8jgtU4g5
# [2022-12-11 12:24:56] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-1k-prompt-loss-weight-2022-12-11-12-24-55 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-1xZlLRMMO1tNT1XiF2YqAkX5 ...
# [2022-12-11 10:40:49] Created fine-tune: ft-1xZlLRMMO1tNT1XiF2YqAkX5
# [2022-12-11 13:00:01] Fine-tune costs $11.94
# [2022-12-11 13:00:01] Fine-tune enqueued. Queue number: 2
# [2022-12-11 13:00:02] Fine-tune is in the queue. Queue number: 1
# [2022-12-11 13:03:01] Fine-tune is in the queue. Queue number: 0
# [2022-12-11 13:08:35] Fine-tune started
# [2022-12-11 13:20:13] Completed epoch 1/1
# [2022-12-11 13:21:38] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-prompt-loss-weight-2022-12-11-13-21-38
# [2022-12-11 13:21:39] Uploaded result file: file-pxIBNmOvNIRFglExwaEgcwJl
# [2022-12-11 13:21:39] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-1k-prompt-loss-weight-2022-12-11-13-21-38 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-3cDuSd9kt7GElcQajrmUxV5L ...
# [2022-12-11 10:40:49] Created fine-tune: ft-3cDuSd9kt7GElcQajrmUxV5L
# [2022-12-11 12:24:56] Fine-tune costs $11.94
# [2022-12-11 12:24:57] Fine-tune enqueued. Queue number: 1
# [2022-12-11 12:25:12] Fine-tune is in the queue. Queue number: 0
# [2022-12-11 12:26:03] Fine-tune started
# [2022-12-11 12:37:35] Completed epoch 1/1
# [2022-12-11 12:38:15] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-prompt-loss-weight-2022-12-11-12-38-15
# [2022-12-11 12:38:17] Uploaded result file: file-6MRVL59TF2UbWP50LwHdpyhJ
# [2022-12-11 12:38:17] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-1k-prompt-loss-weight-2022-12-11-12-38-15 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-aFEjM3ZZNaBdM8zvvRScAgoi', 'ft-Z6Cur5qh1jrE9fpUGqXp4quv', 'ft-1xZlLRMMO1tNT1XiF2YqAkX5', 'ft-3cDuSd9kt7GElcQajrmUxV5L']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_151312-ft-aFEjM3ZZNaBdM8zvvRScAgoi</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-aFEjM3ZZNaBdM8zvvRScAgoi" target="_blank">ft-aFEjM3ZZNaBdM8zvvRScAgoi</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▄▂▁▄▃▂▆▃▃▆█▄▄▆▃▃▄▇▄▃▃▄▁▅▅▃▄▃▃▆▄▄▂▄▅▃▅▄▅▅</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▆█▅▅▅▅▆▃▃▄▆▅▁▆▆▅▅▆▄▇▄█▄▃▅▅▅▃▃▆▆▆▄▅▇▃▄▄▄</td></tr><tr><td>validation_loss</td><td>▁▂▂▁▁▂▃▃▃▃▃▁▂▃▄▃█▁▃▅▃▃▂▁▃▄▅▃▄▂▁▂▅▄▂▄▂▆▃▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▆▂▃▆▄▂▅▂▅▄▅▇▃▁▄▂▂█▃▁▄▃▃▃▄▂▆▆▁▃▂█▃▄▄▇▃▆▅▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>1002.0</td></tr><tr><td>elapsed_tokens</td><td>454522.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.12507</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.54412</td></tr><tr><td>validation_loss</td><td>0.12931</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.5</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-aFEjM3ZZNaBdM8zvvRScAgoi</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-aFEjM3ZZNaBdM8zvvRScAgoi" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-aFEjM3ZZNaBdM8zvvRScAgoi</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_151312-ft-aFEjM3ZZNaBdM8zvvRScAgoi/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_151321-ft-Z6Cur5qh1jrE9fpUGqXp4quv</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-Z6Cur5qh1jrE9fpUGqXp4quv" target="_blank">ft-Z6Cur5qh1jrE9fpUGqXp4quv</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>█▄▃▃▄▅▄▄▅▂▃▃▇▁▁▂▅▅▁▃▃▇▄▆▃▃▃▆▄▅▂▇▇▄▄█▂▄▄▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▃▃▅▄▃▅▂▃▅▇▃▄▂█▆▅▃▅█▄▆▅▂▄▃▄▄▅▃▄▅▁▆▄▃▂▆▅▃▅</td></tr><tr><td>validation_loss</td><td>▅▃▅▅▆▃▅▇▆▆▅▄▆▆▃▇▇▃▂▅▄▄▅▅▆▃█▅▂▃▂▁▄▄▄▂▅▄▅▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▄▆▃▇▃▆▅▆▅▅▃▂▅▂▇▅▅▁█▆▃▃▅▁▆▃▃▅▆▅▅▇▅▆▅▃▄▄▂▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>1004.0</td></tr><tr><td>elapsed_tokens</td><td>457612.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.10991</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.64198</td></tr><tr><td>validation_loss</td><td>0.17192</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.575</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-Z6Cur5qh1jrE9fpUGqXp4quv</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-Z6Cur5qh1jrE9fpUGqXp4quv" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-Z6Cur5qh1jrE9fpUGqXp4quv</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_151321-ft-Z6Cur5qh1jrE9fpUGqXp4quv/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_151330-ft-1xZlLRMMO1tNT1XiF2YqAkX5</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-1xZlLRMMO1tNT1XiF2YqAkX5" target="_blank">ft-1xZlLRMMO1tNT1XiF2YqAkX5</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▄▁▁▄▃▁▆▂▄▆█▃▄▇▃▂▄▇▄▃▃▄▁▄▅▂▂▃▃▅▅▃▂▄▅▂▅▄▄▄</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▆▇▅▅▅▆▆▄▃▄▆▅▁▆▆▅▅▆▄▆▄█▄▃▅▅▆▃▃▅▅▅▅▅▇▃▄▄▄</td></tr><tr><td>validation_loss</td><td>▂▃▃▂▁▃▃▃▃▃▃▁▂▃▅▃█▂▄▅▃▂▂▁▃▄▅▃▅▂▂▂▅▄▃▄▂▆▃▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▆▂▂▅▅▃▆▃▅▄▄▆▃▂▃▂▂█▂▁▃▄▃▄▃▁▆▆▁▄▂▇▃▄▄▆▃▆▅▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>1002.0</td></tr><tr><td>elapsed_tokens</td><td>454522.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.20739</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.52941</td></tr><tr><td>validation_loss</td><td>0.20247</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.4875</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-1xZlLRMMO1tNT1XiF2YqAkX5</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-1xZlLRMMO1tNT1XiF2YqAkX5" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-1xZlLRMMO1tNT1XiF2YqAkX5</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_151330-ft-1xZlLRMMO1tNT1XiF2YqAkX5/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_151337-ft-3cDuSd9kt7GElcQajrmUxV5L</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-3cDuSd9kt7GElcQajrmUxV5L" target="_blank">ft-3cDuSd9kt7GElcQajrmUxV5L</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▄▁▁▄▃▁▅▃▄▆█▃▅▇▄▂▅▇▃▂▃▅▂▄▅▂▂▄▄▅▅▃▂▄▅▂▆▄▃▄</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▆█▅▅▅▆▆▃▄▄▆▅▁▆▆▅▅▆▅▇▅█▄▃▅▆▅▃▃▅▆▆▅▅▇▃▄▄▄</td></tr><tr><td>validation_loss</td><td>▃▃▃▃▁▃▄▃▃▂▃▁▂▃▆▄█▂▄▅▃▂▂▁▃▄▄▃▅▂▂▂▅▃▃▄▂▆▃▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▇▂▂▅▅▃▇▃▅▄▄▇▃▁▄▂▂█▂▂▃▄▄▄▄▂▇▅▁▄▂█▃▆▄▇▃▇▆▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>1002.0</td></tr><tr><td>elapsed_tokens</td><td>454522.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.28942</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.51471</td></tr><tr><td>validation_loss</td><td>0.27352</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.5</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-3cDuSd9kt7GElcQajrmUxV5L</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-3cDuSd9kt7GElcQajrmUxV5L" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-3cDuSd9kt7GElcQajrmUxV5L</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_151337-ft-3cDuSd9kt7GElcQajrmUxV5L/logs</code>

# %% [markdown]
# ## Learning rate Multiplier
#
# n_epochs=1
#
# prompt_loss_weight = 0
#
# **Results**:
#
# *   learning_rate_multiplier 0.02: 6.64
# *   learning_rate_multiplier 0.05: 6.65
# *   learning_rate_multiplier 0.1: 6.67
# *   learning_rate_multiplier 0.2: 6.69
#
# **Best Epoch**:

# %%
final_tag = "hp_tuning_human_1K_lr"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0.05],
                "learning_rate_multiplier": [0.02, 0.05, 0.1, 0.2]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
train_data_id = "file-t443KKz8t7tzjRJKdY5hvolj"
dev_data_id = "file-tOqIGbtK4VtEgmFLhnzjSEwO"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight_and_lr(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-L68R2zxlrdxD43BJNH6VAH2H
# with n_epochs 1
# with prompt_loss_weight:  0.05
#
#
#
# ['ft-L68R2zxlrdxD43BJNH6VAH2H']
# Initialized job ft-5PfL1ILSyPr4U8xKKOF6lBgu
# with n_epochs 1
# with prompt_loss_weight:  0.05
#
#
#
# ['ft-L68R2zxlrdxD43BJNH6VAH2H', 'ft-5PfL1ILSyPr4U8xKKOF6lBgu']
# Initialized job ft-lpyCvrqN6pgUYwa4ir0zYW3s
# with n_epochs 1
# with prompt_loss_weight:  0.05
#
#
#
# ['ft-L68R2zxlrdxD43BJNH6VAH2H', 'ft-5PfL1ILSyPr4U8xKKOF6lBgu', 'ft-lpyCvrqN6pgUYwa4ir0zYW3s']
# Initialized job ft-fpTDjm5YJmJgRJXwiIppqxF6
# with n_epochs 1
# with prompt_loss_weight:  0.05
#
#
#
# ['ft-L68R2zxlrdxD43BJNH6VAH2H', 'ft-5PfL1ILSyPr4U8xKKOF6lBgu', 'ft-lpyCvrqN6pgUYwa4ir0zYW3s', 'ft-fpTDjm5YJmJgRJXwiIppqxF6']

# %%
# !openai api fine_tunes.get -i "ft-fpTDjm5YJmJgRJXwiIppqxF6"
# Out:
# {
#   "created_at": 1670780908,
#   "events": [
#     {
#       "created_at": 1670780908,
#       "level": "info",
#       "message": "Created fine-tune: ft-fpTDjm5YJmJgRJXwiIppqxF6",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670783174,
#       "level": "info",
#       "message": "Fine-tune costs $11.94",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670783174,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 0",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670783175,
#       "level": "info",
#       "message": "Fine-tune started",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670783862,
#       "level": "info",
#       "message": "Completed epoch 1/1",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670783907,
#       "level": "info",
#       "message": "Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-lr-2022-12-11-18-38-27",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670783908,
#       "level": "info",
#       "message": "Uploaded result file: file-6cdUk8go8liRMoQXcGRVHWsD",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670783908,
#       "level": "info",
#       "message": "Fine-tune succeeded",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": "davinci:ft-academicsnyuperez:hp-tuning-human-1k-lr-2022-12-11-18-38-27",
#   "hyperparams": {
#     "batch_size": 2,
#     "learning_rate_multiplier": 0.2,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.05
#   },
#   "id": "ft-fpTDjm5YJmJgRJXwiIppqxF6",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [
#     {
#       "bytes": 32127,
#       "created_at": 1670783908,
#       "filename": "compiled_results.csv",
#       "id": "file-6cdUk8go8liRMoQXcGRVHWsD",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "status": "succeeded",
#   "training_files": [
#     {
#       "bytes": 1719755,
#       "created_at": 1670661210,
#       "filename": "file",
#       "id": "file-t443KKz8t7tzjRJKdY5hvolj",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670783908,
#   "validation_files": [
#     {
#       "bytes": 335949,
#       "created_at": 1670661211,
#       "filename": "file",
#       "id": "file-tOqIGbtK4VtEgmFLhnzjSEwO",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
finetuning_ids_hp_tuning = ['ft-L68R2zxlrdxD43BJNH6VAH2H', 'ft-5PfL1ILSyPr4U8xKKOF6lBgu', 'ft-lpyCvrqN6pgUYwa4ir0zYW3s', 'ft-fpTDjm5YJmJgRJXwiIppqxF6']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-L68R2zxlrdxD43BJNH6VAH2H ...
# [2022-12-11 17:48:28] Created fine-tune: ft-L68R2zxlrdxD43BJNH6VAH2H
# [2022-12-11 17:48:30] Fine-tune costs $11.94
# [2022-12-11 17:48:31] Fine-tune enqueued. Queue number: 0
# [2022-12-11 17:48:33] Fine-tune started
# [2022-12-11 18:00:14] Completed epoch 1/1
# [2022-12-11 18:01:05] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-lr-2022-12-11-18-01-05
# [2022-12-11 18:01:07] Uploaded result file: file-k9ZkMf7IeNfUBnc2f0WJNIkJ
# [2022-12-11 18:01:07] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-1k-lr-2022-12-11-18-01-05 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-5PfL1ILSyPr4U8xKKOF6lBgu ...
# [2022-12-11 17:48:28] Created fine-tune: ft-5PfL1ILSyPr4U8xKKOF6lBgu
# [2022-12-11 18:01:07] Fine-tune costs $11.94
# [2022-12-11 18:01:08] Fine-tune enqueued. Queue number: 0
# [2022-12-11 18:01:09] Fine-tune started
# [2022-12-11 18:13:01] Completed epoch 1/1
# [2022-12-11 18:13:52] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-lr-2022-12-11-18-13-51
# [2022-12-11 18:13:53] Uploaded result file: file-fl8aXGKrjwIJL0ZFN38yPTvr
# [2022-12-11 18:13:53] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-1k-lr-2022-12-11-18-13-51 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-lpyCvrqN6pgUYwa4ir0zYW3s ...
# [2022-12-11 17:48:28] Created fine-tune: ft-lpyCvrqN6pgUYwa4ir0zYW3s
# [2022-12-11 18:13:57] Fine-tune costs $11.94
# [2022-12-11 18:13:58] Fine-tune enqueued. Queue number: 0
# [2022-12-11 18:13:59] Fine-tune started
# [2022-12-11 18:25:27] Completed epoch 1/1
# [2022-12-11 18:26:11] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-lr-2022-12-11-18-26-11
# [2022-12-11 18:26:12] Uploaded result file: file-pebAM3i8tU0PvjSXdNaUyykP
# [2022-12-11 18:26:12] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-1k-lr-2022-12-11-18-26-11 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-fpTDjm5YJmJgRJXwiIppqxF6 ...
# [2022-12-11 17:48:28] Created fine-tune: ft-fpTDjm5YJmJgRJXwiIppqxF6
# [2022-12-11 18:26:14] Fine-tune costs $11.94
# [2022-12-11 18:26:14] Fine-tune enqueued. Queue number: 0
# [2022-12-11 18:26:15] Fine-tune started
# [2022-12-11 18:37:42] Completed epoch 1/1
# [2022-12-11 18:38:27] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-1k-lr-2022-12-11-18-38-27
# [2022-12-11 18:38:28] Uploaded result file: file-6cdUk8go8liRMoQXcGRVHWsD
# [2022-12-11 18:38:28] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-1k-lr-2022-12-11-18-38-27 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-L68R2zxlrdxD43BJNH6VAH2H', 'ft-5PfL1ILSyPr4U8xKKOF6lBgu', 'ft-lpyCvrqN6pgUYwa4ir0zYW3s', 'ft-fpTDjm5YJmJgRJXwiIppqxF6']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag], force=True)
# Out:
# A run for fine-tune ft-L68R2zxlrdxD43BJNH6VAH2H was previously created but didn't end successfully
# A new wandb run will be created for fine-tune ft-L68R2zxlrdxD43BJNH6VAH2H and previous run will be overwritten
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221212_090416-ft-L68R2zxlrdxD43BJNH6VAH2H</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-L68R2zxlrdxD43BJNH6VAH2H" target="_blank">ft-L68R2zxlrdxD43BJNH6VAH2H</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▅▆▆▄▆▃▅▃▂▆▆▅▄▆▇▂█▂▄▃▃▂▃▂█▄▄▆▅▇▃▅▄▄▁▆▂▇▅▅</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▇▄▄▆▄▄▂▄█▅▅▃▆▄▄▅▁▇▆▆▅█▅▄▃▇▇▆▇▄▄▆▆▇█▂▆▃▅▅</td></tr><tr><td>validation_loss</td><td>█▃▅▄▃▃▆▂▅▄▁▅▄▂▃█▅▄▆▂▇▃▃▄▃▂█▆▃▃▃▆▁▄▅▆▄▃▃▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▇▇▅█▂▅▃█▄▂█▅▄▄▅▅▅▆▄▆▅▅▇█▆▄▄▃▆▅▅▄▄▃▁▂▁▇▃█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>1002.0</td></tr><tr><td>elapsed_tokens</td><td>455450.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.21683</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.56471</td></tr><tr><td>validation_loss</td><td>0.20127</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.64706</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-L68R2zxlrdxD43BJNH6VAH2H</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-L68R2zxlrdxD43BJNH6VAH2H" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-L68R2zxlrdxD43BJNH6VAH2H</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221212_090416-ft-L68R2zxlrdxD43BJNH6VAH2H/logs</code>
# Fine-tune ft-5PfL1ILSyPr4U8xKKOF6lBgu has already been logged successfully at https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-5PfL1ILSyPr4U8xKKOF6lBgu
# A new wandb run will be created for fine-tune ft-5PfL1ILSyPr4U8xKKOF6lBgu and previous run will be overwritten
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221212_090433-ft-5PfL1ILSyPr4U8xKKOF6lBgu</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-5PfL1ILSyPr4U8xKKOF6lBgu" target="_blank">ft-5PfL1ILSyPr4U8xKKOF6lBgu</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▅▆▆▄▆▃▄▃▁▆▆▅▄▇▇▂█▂▄▃▃▂▃▂█▄▄▆▅▇▃▅▄▄▁▆▂▇▅▅</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▇▄▄▆▄▅▂▄▇▄▅▄▆▄▃▅▁▇▆▅▅▇▄▄▂▇▇▆▆▄▃▇▆▇█▃▆▃▄▅</td></tr><tr><td>validation_loss</td><td>█▃▅▄▄▃▆▂▅▃▁▅▄▂▂█▅▄▆▂▇▃▃▄▃▂█▆▃▃▃▆▁▅▅▆▄▃▃▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▆▆▅█▂▅▅█▃▁█▃▄▄▅▅▅▅▃▅▅▄▆█▅▃▅▄▆▄▅▄▅▂▁▂▁▆▂▇</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>1002.0</td></tr><tr><td>elapsed_tokens</td><td>455450.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.20956</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.55294</td></tr><tr><td>validation_loss</td><td>0.20029</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.65882</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-5PfL1ILSyPr4U8xKKOF6lBgu</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-5PfL1ILSyPr4U8xKKOF6lBgu" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-5PfL1ILSyPr4U8xKKOF6lBgu</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221212_090433-ft-5PfL1ILSyPr4U8xKKOF6lBgu/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221212_090447-ft-lpyCvrqN6pgUYwa4ir0zYW3s</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-lpyCvrqN6pgUYwa4ir0zYW3s" target="_blank">ft-lpyCvrqN6pgUYwa4ir0zYW3s</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▄▁▁▄▃▁▅▂▄▆█▃▄▆▃▂▄▇▃▂▃▄▁▄▅▂▂▃▃▅▄▃▂▄▅▂▅▄▄▄</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▆█▅▅▅▆▆▃▄▄▇▅▁▇▆▅▆▆▅▇▅█▄▃▅▆▆▄▄▆▆▆▅▅▇▃▅▅▄</td></tr><tr><td>validation_loss</td><td>▂▃▃▂▁▃▃▃▃▃▃▁▂▃▅▃█▂▄▅▃▂▂▁▃▄▅▃▅▂▂▂▅▄▃▄▂▆▃▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▆▂▂▅▄▃▆▂▅▄▃▅▃▁▄▃▂█▂▁▃▄▄▄▃▂▆▅▂▄▃▇▃▅▃▇▃▆▆▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>1002.0</td></tr><tr><td>elapsed_tokens</td><td>454522.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.20732</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.51471</td></tr><tr><td>validation_loss</td><td>0.20109</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.5125</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-lpyCvrqN6pgUYwa4ir0zYW3s</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-lpyCvrqN6pgUYwa4ir0zYW3s" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-lpyCvrqN6pgUYwa4ir0zYW3s</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221212_090447-ft-lpyCvrqN6pgUYwa4ir0zYW3s/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221212_090503-ft-fpTDjm5YJmJgRJXwiIppqxF6</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-fpTDjm5YJmJgRJXwiIppqxF6" target="_blank">ft-fpTDjm5YJmJgRJXwiIppqxF6</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▃▁▁▄▃▁▅▃▃▆█▃▄▆▃▂▄▆▃▂▂▄▁▄▅▂▂▃▃▅▄▃▂▄▅▂▅▄▃▄</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▆▇▅▆▅▆▆▄▄▄▆▅▁▇▆▅▆▆▅▇▅█▃▃▆▆▆▃▃▅▆▆▅▅█▃▅▅▄</td></tr><tr><td>validation_loss</td><td>▂▂▃▂▁▃▃▃▃▃▃▁▂▃▅▃█▂▄▅▃▂▂▁▃▄▅▃▅▂▂▂▅▄▃▄▂▆▃▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▇▃▃▆▅▂█▂▅▄▃▆▂▁▄▂▂█▁▁▃▄▄▄▃▂▆▆▂▃▂█▃▆▄▅▃█▅▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>1002.0</td></tr><tr><td>elapsed_tokens</td><td>454522.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.20629</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.52941</td></tr><tr><td>validation_loss</td><td>0.19987</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.5125</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-fpTDjm5YJmJgRJXwiIppqxF6</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-fpTDjm5YJmJgRJXwiIppqxF6" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-fpTDjm5YJmJgRJXwiIppqxF6</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221212_090503-ft-fpTDjm5YJmJgRJXwiIppqxF6/logs</code>

# %% [markdown]
# ## Final Run - Refinements

# %%
final_tag = "final_run_1K_refinements"
parameter_combinations = {
                 "n_epochs":[1], 
                "prompt_loss_weight": [0],
                "learning_rate_multiplier": [0.02]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/selected_refinement_finetuning_dataset_top_1_train_1000.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
dev_data = "summarization_finetuning_datasets/selected_refinement_finetuning_dataset_top_1_development_200.jsonl"
dev_data_id = upload_dataset_to_openai(dev_data)
print("Train dataset id {}".format(train_data_id))
print("Validation dataset id {}".format(dev_data_id))
# Out:
# Train dataset id file-4FWqVdDJOOtd7rUYAufoAYBz
# Validation dataset id file-YjnmMwSJzJvdVzMx0trNvZQi

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight_and_lr(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-K2MfPALLc49lqnU80CHIuftv
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-K2MfPALLc49lqnU80CHIuftv']

# %%
# !openai api fine_tunes.get -i "ft-K2MfPALLc49lqnU80CHIuftv"
# Out:
# {
#   "created_at": 1670832492,
#   "events": [
#     {
#       "created_at": 1670832492,
#       "level": "info",
#       "message": "Created fine-tune: ft-K2MfPALLc49lqnU80CHIuftv",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670832494,
#       "level": "info",
#       "message": "Fine-tune costs $11.78",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670832495,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 0",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670832497,
#       "level": "info",
#       "message": "Fine-tune started",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": 2,
#     "learning_rate_multiplier": 0.02,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.0
#   },
#   "id": "ft-K2MfPALLc49lqnU80CHIuftv",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "running",
#   "training_files": [
#     {
#       "bytes": 1697459,
#       "created_at": 1670832478,
#       "filename": "file",
#       "id": "file-4FWqVdDJOOtd7rUYAufoAYBz",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670832497,
#   "validation_files": [
#     {
#       "bytes": 332653,
#       "created_at": 1670832480,
#       "filename": "file",
#       "id": "file-YjnmMwSJzJvdVzMx0trNvZQi",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
finetuning_ids_hp_tuning = ['ft-K2MfPALLc49lqnU80CHIuftv']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-K2MfPALLc49lqnU80CHIuftv ...
# [2022-12-12 08:08:12] Created fine-tune: ft-K2MfPALLc49lqnU80CHIuftv
# [2022-12-12 08:08:14] Fine-tune costs $11.78
# [2022-12-12 08:08:15] Fine-tune enqueued. Queue number: 0
# [2022-12-12 08:08:17] Fine-tune started
# [2022-12-12 08:20:22] Completed epoch 1/1
# [2022-12-12 08:21:10] Uploaded model: davinci:ft-academicsnyuperez:final-run-1k-refinements-2022-12-12-08-21-10
# [2022-12-12 08:21:12] Uploaded result file: file-Z5bg7zQqVQrWUjuqQo1XCfNo
# [2022-12-12 08:21:12] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:final-run-1k-refinements-2022-12-12-08-21-10 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-K2MfPALLc49lqnU80CHIuftv']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221212_091632-ft-K2MfPALLc49lqnU80CHIuftv</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-K2MfPALLc49lqnU80CHIuftv" target="_blank">ft-K2MfPALLc49lqnU80CHIuftv</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>training_loss</td><td>▆▇▂█▄▅▃▄▄▅▃▁▃▁▅▂▅▃█▂▃▅▇▄█▂▃▅▁▃▃▆▃▅▃▄▃▅▄▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▂▃▅▁▅▃▅▁▂▄▄█▅▆▃▆▃▅▃▆▆▃▇▄▃▄▅▅▅▅▆▃▇▃▅▂▇▄▆▇</td></tr><tr><td>validation_loss</td><td>▄▃▄▄▃▃▄▄▃▆▂▄▇▄▄▄▂█▃▅▃▃▃▄▄▄▂▂▃▃▂▅▃▅▄▂▄▃▁▃</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▁▆▄▃▃▄▄▂▅▃▄▄▃▃▃▂▅▂▄▄▄▅▅▃▃▅▇▄▆▂▅▃▃▃▂▆▅▄█▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>1004.0</td></tr><tr><td>elapsed_tokens</td><td>450476.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.18539</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.57576</td></tr><tr><td>validation_loss</td><td>0.08341</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.71429</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-K2MfPALLc49lqnU80CHIuftv</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-K2MfPALLc49lqnU80CHIuftv" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-K2MfPALLc49lqnU80CHIuftv</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221212_091632-ft-K2MfPALLc49lqnU80CHIuftv/logs</code>

# %% [markdown]
# ## Fianl Run - Intial Summaries

# %%
final_tag = "final_run_1K_initial_summaries"
parameter_combinations = {
                 "n_epochs":[1], 
                "prompt_loss_weight": [0],
                "learning_rate_multiplier": [0.02]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/initial_summary_finetuning_dataset_train_1000.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
dev_data = "summarization_finetuning_datasets/initial_summary_finetuning_dataset_development_200.jsonl"
dev_data_id = upload_dataset_to_openai(dev_data)
print("Train dataset id {}".format(train_data_id))
print("Validation dataset id {}".format(dev_data_id))
# Out:
# Train dataset id file-h49ZI7TeKE0JRcTRjt4lMLcB
# Validation dataset id file-GMRIsoBF4Tj6Gk27hf4qsTp8

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight_and_lr(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-t8rNOsZEraoFfIrcIFZeTbtu
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-t8rNOsZEraoFfIrcIFZeTbtu']

# %%
# !openai api fine_tunes.get -i "ft-t8rNOsZEraoFfIrcIFZeTbtu"
# Out:
# {
#   "created_at": 1670832545,
#   "events": [
#     {
#       "created_at": 1670832545,
#       "level": "info",
#       "message": "Created fine-tune: ft-t8rNOsZEraoFfIrcIFZeTbtu",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": null,
#     "learning_rate_multiplier": 0.02,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.0
#   },
#   "id": "ft-t8rNOsZEraoFfIrcIFZeTbtu",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 1667356,
#       "created_at": 1670832541,
#       "filename": "file",
#       "id": "file-h49ZI7TeKE0JRcTRjt4lMLcB",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670832545,
#   "validation_files": [
#     {
#       "bytes": 325310,
#       "created_at": 1670832543,
#       "filename": "file",
#       "id": "file-GMRIsoBF4Tj6Gk27hf4qsTp8",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
finetuning_ids_hp_tuning = ['ft-t8rNOsZEraoFfIrcIFZeTbtu']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-t8rNOsZEraoFfIrcIFZeTbtu ...
# [2022-12-12 08:09:05] Created fine-tune: ft-t8rNOsZEraoFfIrcIFZeTbtu
# [2022-12-12 08:21:15] Fine-tune costs $11.63
# [2022-12-12 08:21:16] Fine-tune enqueued. Queue number: 0
# [2022-12-12 08:21:17] Fine-tune started
# [2022-12-12 08:32:42] Completed epoch 1/1
# [2022-12-12 08:33:29] Uploaded model: davinci:ft-academicsnyuperez:final-run-1k-initial-summaries-2022-12-12-08-33-29
# [2022-12-12 08:33:30] Uploaded result file: file-FmyGR62qZdi5k1rGSYYIRLZd
# [2022-12-12 08:33:31] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:final-run-1k-initial-summaries-2022-12-12-08-33-29 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-t8rNOsZEraoFfIrcIFZeTbtu']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221212_091703-ft-t8rNOsZEraoFfIrcIFZeTbtu</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-t8rNOsZEraoFfIrcIFZeTbtu" target="_blank">ft-t8rNOsZEraoFfIrcIFZeTbtu</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>training_loss</td><td>▃▂▂▇▆▃▃▄▂▅▃▂▅▂▅▂▆▂▄▃▄▂▅▂█▃▃▅▁▂▄▅▁▄▃▄▃▄▃▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▂▇▆▂▅▃▅▅▅▄▆█▃▇▁▆▃▅▆▇▄▅▇▇▄▄▄▂▇▇▄▅▆▄▂▁▆▄▇▇</td></tr><tr><td>validation_loss</td><td>▄▅▅▄▄▄▄▆▃▆▄▄█▃▂█▃▇▅▇▄▃▃▃▄▄▃▄▄▅▂█▃▆▇▄▅▁▂▃</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▃▆▃▄▅▅▇▃▄▄▆▆▃▅▆▃▃▅▄▄▄▄▄▅▂▆▆▅▆▃▇▃▅▃▁▅▅█▇▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>1004.0</td></tr><tr><td>elapsed_tokens</td><td>445756.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.10387</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.68889</td></tr><tr><td>validation_loss</td><td>0.07931</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.7381</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-t8rNOsZEraoFfIrcIFZeTbtu</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-t8rNOsZEraoFfIrcIFZeTbtu" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-t8rNOsZEraoFfIrcIFZeTbtu</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221212_091703-ft-t8rNOsZEraoFfIrcIFZeTbtu/logs</code>

# %% [markdown]
# # Data Set Size - 5K
#
# *Final Parameters*
#
# n_epochs=1
#
# prompt_loss_weight = 0.1
#
# learning_rate_multipleir = 0.2

# %% [markdown]
# ## Epochs
#
# n_epochs=1,2,3,4
#
# **Results**:
#
# *   Epoch 1: 6.26
# *   Epoch 2: 6.37
# *   Epoch 3: 6.88
# *   Epoch 4: 7.7
#
# **Best Epoch**: 1

# %%
final_tag = "hp_tuning_human_5K_n_epochs"
parameter_combinations = {
                "n_epochs":[1,2,3,4], 
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/ideal_human_summary_finetuning_dataset_train_5000.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
dev_data = "summarization_finetuning_datasets/ideal_human_summary_finetuning_dataset_development_200.jsonl"
dev_data_id = upload_dataset_to_openai(dev_data)
print("Train dataset id {}".format(train_data_id))
print("Validation dataset id {}".format(dev_data_id))
# Out:
# Train dataset id file-0wd6yJsQqfhusGarNFUjFWra
# Validation dataset id file-TBmfYhPVyGQFW8MTcQGID5zt

# %%
train_data_id = "file-0wd6yJsQqfhusGarNFUjFWra"
dev_data_id = "file-TBmfYhPVyGQFW8MTcQGID5zt"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs(n_epochs=n_epochs, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)

# %%
# !openai api fine_tunes.get -i "ft-Lfd0FEwgkapQt49V9JrH0WNK"

# %%
finetuning_ids_hp_tuning = ['ft-Lfd0FEwgkapQt49V9JrH0WNK', 'ft-CywIuXtCuVdY4HAhXDAc21yP', 'ft-kmecQN9h3PCIchbSWRrNGsOR', 'ft-Dp0BqBjyDyJtG4ySsJGhBkN6']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")

# %%
finetuning_ids_hp_tuning = ['ft-Lfd0FEwgkapQt49V9JrH0WNK', 'ft-CywIuXtCuVdY4HAhXDAc21yP', 'ft-kmecQN9h3PCIchbSWRrNGsOR', 'ft-Dp0BqBjyDyJtG4ySsJGhBkN6']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])

# %% [markdown]
# ## Prompt Loss Weight
# **Sweep**:
#
# n_epochs=1
#
# prompt_loss_weight = 0, 0.01, 0.05, 0.1
#
# **Results:**
#
# * prompt_loss_weight 0 = 6.28
# * prompt_loss_weight 0.01 = 6.29
# * prompt_loss_weight 0.05 = 6.23
# * prompt_loss_weight 0.1 = 6.22
#
# **final parameter**: prompt_loss_weight = 0.1

# %%
final_tag = "hp_tuning_human_5K_prompt_loss_weight"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0, 0.01, 0.05, 0.1]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
train_data_id = "file-0wd6yJsQqfhusGarNFUjFWra"
dev_data_id = "file-TBmfYhPVyGQFW8MTcQGID5zt"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-ITJZuS8yPZVWGtbN6uVy6Fmy
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-ITJZuS8yPZVWGtbN6uVy6Fmy']
# Initialized job ft-4nuVVfkUV6itowZ3g1YNEjtN
# with n_epochs 1
# with prompt_loss_weight:  0.01
#
#
#
# ['ft-ITJZuS8yPZVWGtbN6uVy6Fmy', 'ft-4nuVVfkUV6itowZ3g1YNEjtN']
# Initialized job ft-QSlPs0xMi3z45V9E3BauMlMH
# with n_epochs 1
# with prompt_loss_weight:  0.05
#
#
#
# ['ft-ITJZuS8yPZVWGtbN6uVy6Fmy', 'ft-4nuVVfkUV6itowZ3g1YNEjtN', 'ft-QSlPs0xMi3z45V9E3BauMlMH']
# Initialized job ft-0vUWFl1dnj92wFcEb9zIyjNU
# with n_epochs 1
# with prompt_loss_weight:  0.1
#
#
#
# ['ft-ITJZuS8yPZVWGtbN6uVy6Fmy', 'ft-4nuVVfkUV6itowZ3g1YNEjtN', 'ft-QSlPs0xMi3z45V9E3BauMlMH', 'ft-0vUWFl1dnj92wFcEb9zIyjNU']

# %%
# !openai api fine_tunes.get -i "ft-ITJZuS8yPZVWGtbN6uVy6Fmy"
# Out:
# {
#   "created_at": 1670712194,
#   "events": [
#     {
#       "created_at": 1670712194,
#       "level": "info",
#       "message": "Created fine-tune: ft-ITJZuS8yPZVWGtbN6uVy6Fmy",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670712199,
#       "level": "info",
#       "message": "Fine-tune costs $57.50",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670712199,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 17",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": 8,
#     "learning_rate_multiplier": 0.1,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.0
#   },
#   "id": "ft-ITJZuS8yPZVWGtbN6uVy6Fmy",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 8296292,
#       "created_at": 1670629794,
#       "filename": "file",
#       "id": "file-0wd6yJsQqfhusGarNFUjFWra",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670712199,
#   "validation_files": [
#     {
#       "bytes": 335949,
#       "created_at": 1670629794,
#       "filename": "file",
#       "id": "file-TBmfYhPVyGQFW8MTcQGID5zt",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
finetuning_ids_hp_tuning = ['ft-ITJZuS8yPZVWGtbN6uVy6Fmy', 'ft-4nuVVfkUV6itowZ3g1YNEjtN', 'ft-QSlPs0xMi3z45V9E3BauMlMH', 'ft-0vUWFl1dnj92wFcEb9zIyjNU']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-ITJZuS8yPZVWGtbN6uVy6Fmy ...
# [2022-12-10 22:43:14] Created fine-tune: ft-ITJZuS8yPZVWGtbN6uVy6Fmy
# [2022-12-10 22:43:19] Fine-tune costs $57.50
# [2022-12-10 22:43:19] Fine-tune enqueued. Queue number: 17
# [2022-12-10 22:43:54] Fine-tune is in the queue. Queue number: 16
# [2022-12-10 22:43:55] Fine-tune is in the queue. Queue number: 15
# [2022-12-10 22:49:45] Fine-tune is in the queue. Queue number: 14
# [2022-12-10 22:55:15] Fine-tune is in the queue. Queue number: 13
# [2022-12-10 23:00:06] Fine-tune is in the queue. Queue number: 12
# [2022-12-10 23:02:34] Fine-tune is in the queue. Queue number: 11
# [2022-12-10 23:13:36] Fine-tune is in the queue. Queue number: 10
# [2022-12-10 23:19:16] Fine-tune is in the queue. Queue number: 9
# [2022-12-10 23:21:12] Fine-tune is in the queue. Queue number: 8
# [2022-12-10 23:21:13] Fine-tune is in the queue. Queue number: 7
# [2022-12-10 23:25:11] Fine-tune is in the queue. Queue number: 6
# [2022-12-10 23:27:38] Fine-tune is in the queue. Queue number: 5
# [2022-12-10 23:27:39] Fine-tune is in the queue. Queue number: 4
# [2022-12-10 23:36:21] Fine-tune is in the queue. Queue number: 3
# [2022-12-10 23:36:22] Fine-tune is in the queue. Queue number: 2
# [2022-12-10 23:42:33] Fine-tune is in the queue. Queue number: 1
# [2022-12-10 23:42:34] Fine-tune is in the queue. Queue number: 0
# [2022-12-10 23:48:25] Fine-tune started
# [2022-12-11 00:15:05] Completed epoch 1/1
# [2022-12-11 00:15:51] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-5k-prompt-loss-weight-2022-12-11-00-15-51
# [2022-12-11 00:15:52] Uploaded result file: file-z6KV0iAkaNUoVHNESD8f3hPP
# [2022-12-11 00:15:53] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-5k-prompt-loss-weight-2022-12-11-00-15-51 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-4nuVVfkUV6itowZ3g1YNEjtN ...
# [2022-12-10 22:43:14] Created fine-tune: ft-4nuVVfkUV6itowZ3g1YNEjtN
# [2022-12-11 00:15:59] Fine-tune costs $57.50
# [2022-12-11 00:15:59] Fine-tune enqueued. Queue number: 16
# [2022-12-11 00:21:05] Fine-tune is in the queue. Queue number: 15
# [2022-12-11 00:25:34] Fine-tune is in the queue. Queue number: 14
# [2022-12-11 00:25:35] Fine-tune is in the queue. Queue number: 13
# [2022-12-11 00:37:52] Fine-tune is in the queue. Queue number: 12
# [2022-12-11 00:42:46] Fine-tune is in the queue. Queue number: 11
# [2022-12-11 00:43:32] Fine-tune is in the queue. Queue number: 10
# [2022-12-11 00:48:27] Fine-tune is in the queue. Queue number: 9
# [2022-12-11 00:48:29] Fine-tune is in the queue. Queue number: 8
# [2022-12-11 00:49:02] Fine-tune is in the queue. Queue number: 7
# [2022-12-11 00:51:59] Fine-tune is in the queue. Queue number: 6
# [2022-12-11 00:53:48] Fine-tune is in the queue. Queue number: 5
# [2022-12-11 00:57:40] Fine-tune is in the queue. Queue number: 4
# [2022-12-11 00:57:41] Fine-tune is in the queue. Queue number: 3
# [2022-12-11 00:58:48] Fine-tune is in the queue. Queue number: 2
# [2022-12-11 01:01:37] Fine-tune is in the queue. Queue number: 1
# [2022-12-11 01:03:12] Fine-tune is in the queue. Queue number: 0
# [2022-12-11 01:03:45] Fine-tune started
# [2022-12-11 01:29:41] Completed epoch 1/1
# [2022-12-11 01:30:31] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-5k-prompt-loss-weight-2022-12-11-01-30-31
# [2022-12-11 01:30:32] Uploaded result file: file-COAnuLFFPCbGDeaEsnv2GdgE
# [2022-12-11 01:30:33] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-5k-prompt-loss-weight-2022-12-11-01-30-31 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-QSlPs0xMi3z45V9E3BauMlMH ...
# [2022-12-10 22:43:14] Created fine-tune: ft-QSlPs0xMi3z45V9E3BauMlMH
# [2022-12-11 01:30:37] Fine-tune costs $57.50
# [2022-12-11 01:30:38] Fine-tune enqueued. Queue number: 9
# [2022-12-11 01:36:45] Fine-tune is in the queue. Queue number: 8
# [2022-12-11 01:46:30] Fine-tune is in the queue. Queue number: 7
# [2022-12-11 01:52:12] Fine-tune is in the queue. Queue number: 6
# [2022-12-11 01:52:14] Fine-tune is in the queue. Queue number: 5
# [2022-12-11 01:55:23] Fine-tune is in the queue. Queue number: 4
# [2022-12-11 02:00:54] Fine-tune is in the queue. Queue number: 3
# [2022-12-11 02:07:26] Fine-tune is in the queue. Queue number: 2
# [2022-12-11 02:12:57] Fine-tune is in the queue. Queue number: 1
# [2022-12-11 02:12:58] Fine-tune is in the queue. Queue number: 0
# [2022-12-11 02:15:26] Fine-tune started
# [2022-12-11 02:41:18] Completed epoch 1/1
# [2022-12-11 02:42:01] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-5k-prompt-loss-weight-2022-12-11-02-42-01
# [2022-12-11 02:42:02] Uploaded result file: file-noD2iFjvTovdsUjMXVJOdAZW
# [2022-12-11 02:42:02] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-5k-prompt-loss-weight-2022-12-11-02-42-01 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-0vUWFl1dnj92wFcEb9zIyjNU ...
# [2022-12-10 22:43:14] Created fine-tune: ft-0vUWFl1dnj92wFcEb9zIyjNU
# [2022-12-11 02:42:03] Fine-tune costs $57.50
# [2022-12-11 02:42:04] Fine-tune enqueued. Queue number: 9
# [2022-12-11 02:42:05] Fine-tune is in the queue. Queue number: 8
# [2022-12-11 02:45:31] Fine-tune is in the queue. Queue number: 7
# [2022-12-11 02:46:24] Fine-tune is in the queue. Queue number: 6
# [2022-12-11 02:48:31] Fine-tune is in the queue. Queue number: 5
# [2022-12-11 02:48:31] Fine-tune is in the queue. Queue number: 4
# [2022-12-11 02:49:39] Fine-tune is in the queue. Queue number: 3
# [2022-12-11 02:50:48] Fine-tune is in the queue. Queue number: 2
# [2022-12-11 02:55:13] Fine-tune is in the queue. Queue number: 1
# [2022-12-11 02:56:17] Fine-tune is in the queue. Queue number: 0
# [2022-12-11 02:59:36] Fine-tune started
# [2022-12-11 03:25:34] Completed epoch 1/1
# [2022-12-11 03:26:21] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-5k-prompt-loss-weight-2022-12-11-03-26-21
# [2022-12-11 03:26:23] Uploaded result file: file-pmJVsnmcnGo0oNbPa3bwtGaY
# [2022-12-11 03:26:23] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-5k-prompt-loss-weight-2022-12-11-03-26-21 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-ITJZuS8yPZVWGtbN6uVy6Fmy', 'ft-4nuVVfkUV6itowZ3g1YNEjtN', 'ft-QSlPs0xMi3z45V9E3BauMlMH', 'ft-0vUWFl1dnj92wFcEb9zIyjNU']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: jerry_crea. Use `wandb login --relogin` to force relogin
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_101020-ft-ITJZuS8yPZVWGtbN6uVy6Fmy</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-ITJZuS8yPZVWGtbN6uVy6Fmy" target="_blank">ft-ITJZuS8yPZVWGtbN6uVy6Fmy</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▆▆▅▅▃▄▇▆█▄▂▅█▄▁▃▇▄▃▇▂▃▄▁▃▆▄▅▃▂▅▄▃▆▇▆▃▄▃▄</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▂▁▃▂▄▄▂▂▃▇▄▄▁▄█▇▃▄▄▄▆▄▁▆▆▃▃▅▅▅▃▆▇▁▁▁▇▃▄▅</td></tr><tr><td>validation_loss</td><td>▄▂▄▃▃▆▃▄▅▂▄▄▆▅▂▄▃▄▄▂▄▄▃█▁▄▄▄▃▂▄▃▄▁▂▄▂▄▄▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▂▁▇▇▃▃▄▅▅█▃▄▇▆▆▅▇▁█▇▃▅▇▅▇▄▄▂▆▇▆▇▇▆▆▇▃▄▂▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>5016.0</td></tr><tr><td>elapsed_tokens</td><td>2572632.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.09521</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.7181</td></tr><tr><td>validation_loss</td><td>0.12218</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.54072</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-ITJZuS8yPZVWGtbN6uVy6Fmy</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-ITJZuS8yPZVWGtbN6uVy6Fmy" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-ITJZuS8yPZVWGtbN6uVy6Fmy</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_101020-ft-ITJZuS8yPZVWGtbN6uVy6Fmy/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_101028-ft-4nuVVfkUV6itowZ3g1YNEjtN</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-4nuVVfkUV6itowZ3g1YNEjtN" target="_blank">ft-4nuVVfkUV6itowZ3g1YNEjtN</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▆▃▃▅▄▂▆▂▅▄▅▃▇▇▅▅▃▆▃▂▅▃▅▆▃█▂▇▁▄▂▃▃▃▃▃▄▁▄▄</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▁▅█▅▇▇▂▇▃▆▆▅▄█▃▇▄▄▅▇▅▇▆▆▄▃▇▃▅▆▆█▅▆▇▄▃█▅▅</td></tr><tr><td>validation_loss</td><td>█▄▃▅▃▂▅▅▂▁▃▄▃▁▆▃▄▃▅▂▃▄▄▄▄▃▅▄▄▄▃▄▅▄▃▃▅▂▃▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▃▄▄▁▅▄▄▆▅█▄▃▅█▄▃▂▃▂▆▃▃▆█▂▃▄▅▅▃▅▄▂▅▃▄▄▅▅▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>5016.0</td></tr><tr><td>elapsed_tokens</td><td>2575192.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.13731</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.58702</td></tr><tr><td>validation_loss</td><td>0.14999</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.5477</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-4nuVVfkUV6itowZ3g1YNEjtN</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-4nuVVfkUV6itowZ3g1YNEjtN" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-4nuVVfkUV6itowZ3g1YNEjtN</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_101028-ft-4nuVVfkUV6itowZ3g1YNEjtN/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_101036-ft-QSlPs0xMi3z45V9E3BauMlMH</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-QSlPs0xMi3z45V9E3BauMlMH" target="_blank">ft-QSlPs0xMi3z45V9E3BauMlMH</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▅█▅▅▅▅▇▃▇▅▄▃▂▄▂▅▇▃▄▂▄▄▂▂▅▇▅▃▄▅▃▅▅▂▂▃▁▁▂▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▁▃▂▄▃▅▂▄▂▃▄▃▅▄▅▃▂▅▂▃▃▂▆▃▃▃▅█▆▃▄▄▆▇▆▅▅▅▂▃</td></tr><tr><td>validation_loss</td><td>▅▂▅▇▅▃▆▄▆▂█▆▂▁▇▂▃▅▄▃▄▅▃▆▅▅▂▇▄▇▃▆▇▄▇▄▃▂▄▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▄▄▃▅▅▃▅▁▄▇▆▁▄█▃▆▄▃▅▃▂▅▄▁▂▅▅▃▄▅▄▃▅▅▃▄▅▆▄▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>5016.0</td></tr><tr><td>elapsed_tokens</td><td>2563800.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.14867</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.66972</td></tr><tr><td>validation_loss</td><td>0.18499</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.56954</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-QSlPs0xMi3z45V9E3BauMlMH</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-QSlPs0xMi3z45V9E3BauMlMH" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-QSlPs0xMi3z45V9E3BauMlMH</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_101036-ft-QSlPs0xMi3z45V9E3BauMlMH/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_101044-ft-0vUWFl1dnj92wFcEb9zIyjNU</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-0vUWFl1dnj92wFcEb9zIyjNU" target="_blank">ft-0vUWFl1dnj92wFcEb9zIyjNU</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▄▇▅▅▅▅▇▃▇▅▄▃▂▅▂▅█▅▃▂▃▃▂▂▅█▄▃▄▅▃▆▆▁▂▄▁▂▁▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▂▄▂▄▃▄▂▄▂▃▃▃▄▄▄▂▁▄▂▂▃▂▅▃▃▃▅█▆▂▄▄▅▆▆▄▅▅▂▃</td></tr><tr><td>validation_loss</td><td>▆▂▄█▆▃▇▄▆▂█▆▁▂▆▁▃▄▅▃▄▅▄▆▅▅▂▇▃▇▃▆▇▄▇▅▃▂▃▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▄▃▂▄▅▂▅▁▅▇▆▁▅█▃▅▄▁▅▃▁▅▄▁▂▄▅▃▄▆▄▃▅▆▃▄▆▆▃▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>5016.0</td></tr><tr><td>elapsed_tokens</td><td>2563800.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.21154</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.69113</td></tr><tr><td>validation_loss</td><td>0.24843</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.57616</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-0vUWFl1dnj92wFcEb9zIyjNU</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-0vUWFl1dnj92wFcEb9zIyjNU" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-0vUWFl1dnj92wFcEb9zIyjNU</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_101044-ft-0vUWFl1dnj92wFcEb9zIyjNU/logs</code>

# %%
n_epochs =1
prompt_loss_weight = 0.1
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-4tsg3p1BLV6dNzGlFvfT3kRA
# with n_epochs 1
# with prompt_loss_weight:  0.1
#
#
#
# ['ft-L68R2zxlrdxD43BJNH6VAH2H', 'ft-5PfL1ILSyPr4U8xKKOF6lBgu', 'ft-lpyCvrqN6pgUYwa4ir0zYW3s', 'ft-fpTDjm5YJmJgRJXwiIppqxF6', 'ft-kin0ZAV3RYBzLXFyDIERojwK', 'ft-4tsg3p1BLV6dNzGlFvfT3kRA']

# %%
# !openai api fine_tunes.get -i "ft-4tsg3p1BLV6dNzGlFvfT3kRA"
# Out:
# {
#   "created_at": 1670785569,
#   "events": [
#     {
#       "created_at": 1670785569,
#       "level": "info",
#       "message": "Created fine-tune: ft-4tsg3p1BLV6dNzGlFvfT3kRA",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670785569,
#       "level": "info",
#       "message": "Fine-tune costs $57.50",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670785570,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 0",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": 8,
#     "learning_rate_multiplier": 0.2,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.1
#   },
#   "id": "ft-4tsg3p1BLV6dNzGlFvfT3kRA",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 8296292,
#       "created_at": 1670629794,
#       "filename": "file",
#       "id": "file-0wd6yJsQqfhusGarNFUjFWra",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670785570,
#   "validation_files": [
#     {
#       "bytes": 335949,
#       "created_at": 1670629794,
#       "filename": "file",
#       "id": "file-TBmfYhPVyGQFW8MTcQGID5zt",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
# !openai api fine_tunes.cancel -i "ft-4tsg3p1BLV6dNzGlFvfT3kRA"
# Out:
# {
#   "created_at": 1670785569,
#   "events": [
#     {
#       "created_at": 1670785569,
#       "level": "info",
#       "message": "Created fine-tune: ft-4tsg3p1BLV6dNzGlFvfT3kRA",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670785569,
#       "level": "info",
#       "message": "Fine-tune costs $57.50",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670785570,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 0",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670785598,
#       "level": "info",
#       "message": "Fine-tune cancelled",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": 8,
#     "learning_rate_multiplier": 0.2,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.1
#   },
#   "id": "ft-4tsg3p1BLV6dNzGlFvfT3kRA",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "cancelled",
#   "training_files": [
#     {
#       "bytes": 8296292,
#       "created_at": 1670629794,
#       "filename": "file",
#       "id": "file-0wd6yJsQqfhusGarNFUjFWra",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670785598,
#   "validation_files": [
#     {
#       "bytes": 335949,
#       "created_at": 1670629794,
#       "filename": "file",
#       "id": "file-TBmfYhPVyGQFW8MTcQGID5zt",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %% [markdown]
# Indeed if we pick prompt_loss_weight 0.1, it will automatically adjust the learning rate to 0.2 if we don't set it.

# %% [markdown]
# ## Learning rate Multiplier
#
# ## Epochs
#
# n_epochs=1
#
# prompt_loss_weight = 0.1
#
# learning_rate_multiplier = 0.02, 0.05, 0.1, or 0.2
#
# **Results**:
#
# *   learning_rate_multiplier 0.02: 6.39
# *   learning_rate_multiplier 0.05: 6.32
# *   learning_rate_multiplier 0.1: 6.28
# *   learning_rate_multiplier 0.2: 6.27
#
# **Best Epoch**:

# %%
final_tag = "hp_tuning_human_5K_lr"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0.1],
                "learning_rate_multiplier": [0.02, 0.05, 0.1, 0.2]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
train_data_id = "file-0wd6yJsQqfhusGarNFUjFWra"
dev_data_id = "file-TBmfYhPVyGQFW8MTcQGID5zt"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight_and_lr(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-12zYY9Z5uQk9bpW7D5TzqlA0
# with n_epochs 1
# with prompt_loss_weight:  0.1
#
#
#
# ['ft-12zYY9Z5uQk9bpW7D5TzqlA0']
# Initialized job ft-xTefuLb3XXalQoML3nnxLslQ
# with n_epochs 1
# with prompt_loss_weight:  0.1
#
#
#
# ['ft-12zYY9Z5uQk9bpW7D5TzqlA0', 'ft-xTefuLb3XXalQoML3nnxLslQ']
# Initialized job ft-WCXlHSTLWPI20dXjBMyrzZjI
# with n_epochs 1
# with prompt_loss_weight:  0.1
#
#
#
# ['ft-12zYY9Z5uQk9bpW7D5TzqlA0', 'ft-xTefuLb3XXalQoML3nnxLslQ', 'ft-WCXlHSTLWPI20dXjBMyrzZjI']
# Initialized job ft-o7dOcHbIvQmXgBzqPWyf3izw
# with n_epochs 1
# with prompt_loss_weight:  0.1
#
#
#
# ['ft-12zYY9Z5uQk9bpW7D5TzqlA0', 'ft-xTefuLb3XXalQoML3nnxLslQ', 'ft-WCXlHSTLWPI20dXjBMyrzZjI', 'ft-o7dOcHbIvQmXgBzqPWyf3izw']

# %%
# !openai api fine_tunes.get -i "ft-o7dOcHbIvQmXgBzqPWyf3izw"
# Out:
# {
#   "created_at": 1670764055,
#   "events": [
#     {
#       "created_at": 1670764055,
#       "level": "info",
#       "message": "Created fine-tune: ft-o7dOcHbIvQmXgBzqPWyf3izw",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670771003,
#       "level": "info",
#       "message": "Fine-tune costs $57.50",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670771004,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 0",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670771121,
#       "level": "info",
#       "message": "Fine-tune started",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": 8,
#     "learning_rate_multiplier": 0.2,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.1
#   },
#   "id": "ft-o7dOcHbIvQmXgBzqPWyf3izw",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "running",
#   "training_files": [
#     {
#       "bytes": 8296292,
#       "created_at": 1670629794,
#       "filename": "file",
#       "id": "file-0wd6yJsQqfhusGarNFUjFWra",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670771121,
#   "validation_files": [
#     {
#       "bytes": 335949,
#       "created_at": 1670629794,
#       "filename": "file",
#       "id": "file-TBmfYhPVyGQFW8MTcQGID5zt",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
finetuning_ids_hp_tuning = ['ft-12zYY9Z5uQk9bpW7D5TzqlA0', 'ft-xTefuLb3XXalQoML3nnxLslQ', 'ft-WCXlHSTLWPI20dXjBMyrzZjI', 'ft-o7dOcHbIvQmXgBzqPWyf3izw']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-12zYY9Z5uQk9bpW7D5TzqlA0 ...
# [2022-12-11 13:07:34] Created fine-tune: ft-12zYY9Z5uQk9bpW7D5TzqlA0
# [2022-12-11 13:21:42] Fine-tune costs $57.50
# [2022-12-11 13:21:42] Fine-tune enqueued. Queue number: 0
# [2022-12-11 13:21:43] Fine-tune started
# [2022-12-11 13:47:24] Completed epoch 1/1
# [2022-12-11 13:48:18] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-5k-lr-2022-12-11-13-48-18
# [2022-12-11 13:48:19] Uploaded result file: file-plK1vYDIJ5aOINvolBhSBRuj
# [2022-12-11 13:48:19] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-5k-lr-2022-12-11-13-48-18 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-xTefuLb3XXalQoML3nnxLslQ ...
# [2022-12-11 13:07:34] Created fine-tune: ft-xTefuLb3XXalQoML3nnxLslQ
# [2022-12-11 13:48:23] Fine-tune costs $57.50
# [2022-12-11 13:48:23] Fine-tune enqueued. Queue number: 0
# [2022-12-11 13:55:38] Fine-tune started
# [2022-12-11 14:21:12] Completed epoch 1/1
# [2022-12-11 14:21:53] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-5k-lr-2022-12-11-14-21-52
# [2022-12-11 14:21:54] Uploaded result file: file-a7aCQsJ0aJyg0t55x3mWDFNI
# [2022-12-11 14:21:54] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-5k-lr-2022-12-11-14-21-52 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-WCXlHSTLWPI20dXjBMyrzZjI ...
# [2022-12-11 13:07:34] Created fine-tune: ft-WCXlHSTLWPI20dXjBMyrzZjI
# [2022-12-11 14:21:58] Fine-tune costs $57.50
# [2022-12-11 14:21:59] Fine-tune enqueued. Queue number: 7
# [2022-12-11 14:24:03] Fine-tune is in the queue. Queue number: 6
# [2022-12-11 14:26:29] Fine-tune is in the queue. Queue number: 5
# [2022-12-11 14:28:45] Fine-tune is in the queue. Queue number: 4
# [2022-12-11 14:31:02] Fine-tune is in the queue. Queue number: 3
# [2022-12-11 14:31:25] Fine-tune is in the queue. Queue number: 2
# [2022-12-11 14:33:07] Fine-tune is in the queue. Queue number: 1
# [2022-12-11 14:35:26] Fine-tune is in the queue. Queue number: 0
# [2022-12-11 14:36:45] Fine-tune started
# [2022-12-11 15:02:35] Completed epoch 1/1
# [2022-12-11 15:03:19] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-5k-lr-2022-12-11-15-03-19
# [2022-12-11 15:03:21] Uploaded result file: file-RqIptGCsq5IUGxTB6NZFYf1c
# [2022-12-11 15:03:21] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-5k-lr-2022-12-11-15-03-19 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-o7dOcHbIvQmXgBzqPWyf3izw ...
# [2022-12-11 13:07:35] Created fine-tune: ft-o7dOcHbIvQmXgBzqPWyf3izw
# [2022-12-11 15:03:23] Fine-tune costs $57.50
# [2022-12-11 15:03:24] Fine-tune enqueued. Queue number: 0
# [2022-12-11 15:05:21] Fine-tune started
# [2022-12-11 15:31:18] Completed epoch 1/1
# [2022-12-11 15:32:19] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-human-5k-lr-2022-12-11-15-32-18
# [2022-12-11 15:32:20] Uploaded result file: file-pX0QGgxpi6ye4q32sXBQtBBg
# [2022-12-11 15:32:20] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-human-5k-lr-2022-12-11-15-32-18 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-12zYY9Z5uQk9bpW7D5TzqlA0', 'ft-xTefuLb3XXalQoML3nnxLslQ', 'ft-WCXlHSTLWPI20dXjBMyrzZjI', 'ft-o7dOcHbIvQmXgBzqPWyf3izw']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_153642-ft-12zYY9Z5uQk9bpW7D5TzqlA0</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-12zYY9Z5uQk9bpW7D5TzqlA0" target="_blank">ft-12zYY9Z5uQk9bpW7D5TzqlA0</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▅▄▅▅▅▃▃█▅▁▄▅▄▄▄▂▄▄▃▃▄▄▅▄▅▂▄▅▄▅▄▅▃▆▂▃▃▄▁▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▃▄▂▄▄▆▄▁▄▅▅▄▄▇▂▄▄▅▃▃▅▅▃▃▄▆▅▄▅▄▄▄▆▂▅▅▆▂█▅</td></tr><tr><td>validation_loss</td><td>▅▆▄▆▅▂▇▄▅▅▁▅▆▄▄▃▇▄▄▂▅▂▂▁█▁▂▄▅▅█▂▆█▄▂▂▄█▁</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▃▅▅▅▂▅▆▃▅▅▆▆▁▃▅▄▃▄▂▆▆▃▆▆▃▇▆▄▃▄▅▃▆▄▂█▅▂▄▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>5016.0</td></tr><tr><td>elapsed_tokens</td><td>2575768.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.24477</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.625</td></tr><tr><td>validation_loss</td><td>0.24492</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.55517</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-12zYY9Z5uQk9bpW7D5TzqlA0</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-12zYY9Z5uQk9bpW7D5TzqlA0" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-12zYY9Z5uQk9bpW7D5TzqlA0</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_153642-ft-12zYY9Z5uQk9bpW7D5TzqlA0/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_153650-ft-xTefuLb3XXalQoML3nnxLslQ</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-xTefuLb3XXalQoML3nnxLslQ" target="_blank">ft-xTefuLb3XXalQoML3nnxLslQ</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▇▇▄▃▅▄▆▅▃▅▆▁▆▅▄▃▄▅▅▅▄▅▄▂▅▃▆▆▁██▄█▄▅▄▂▄█▇</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▃▃▆▁▄▂▅▆▆▄▅▃▃▄▅▃▄▄▄▃▄▄▆▃▆▆▄█▂▃▅▁▅▄▃█▄▄▂</td></tr><tr><td>validation_loss</td><td>█▄▆▂█▃▃▄▃▅▅▇▅▄▄▅▄▃▃▅▅▅▃▃▃▄▂▁▆▆▄▅▃▅▄▅▄▄▅▃</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▄▂▁▅▂▅▅▅▇▂▅▅▆▄▅▇▄▆▅▁▄▂█▆▆▅▆▅▂▂▅▂█▂▄▄▆▄▄▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>5008.0</td></tr><tr><td>elapsed_tokens</td><td>2575248.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.26927</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.59146</td></tr><tr><td>validation_loss</td><td>0.25412</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.56522</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-xTefuLb3XXalQoML3nnxLslQ</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-xTefuLb3XXalQoML3nnxLslQ" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-xTefuLb3XXalQoML3nnxLslQ</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_153650-ft-xTefuLb3XXalQoML3nnxLslQ/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_153659-ft-WCXlHSTLWPI20dXjBMyrzZjI</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-WCXlHSTLWPI20dXjBMyrzZjI" target="_blank">ft-WCXlHSTLWPI20dXjBMyrzZjI</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▅▄▄▅▄▃▃█▅▁▄▅▄▄▄▂▄▄▃▃▄▅▅▄▅▂▄▅▄▅▄▅▃▆▃▃▃▄▁▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▃▅▄▅▄▅▄▁▄▆▅▄▅▆▂▅▄▅▃▃▅▅▄▄▄▆▄▄▅▄▄▄▆▂▆▅▅▄█▅</td></tr><tr><td>validation_loss</td><td>▅▅▄▆▄▂▆▄▅▄▁▅▆▅▄▄▇▄▅▂▆▃▂▁█▁▂▄▅▆█▂▆█▄▂▂▃█▁</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▃▆▆▅▂▄▆▃▄▆▅▆▂▃▆▄▃▄▂▅▅▄▄▅▃▆▅▄▂▃▄▄▅▃▁█▅▃▃▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>5016.0</td></tr><tr><td>elapsed_tokens</td><td>2575768.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.23847</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.60976</td></tr><tr><td>validation_loss</td><td>0.24276</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.55517</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-WCXlHSTLWPI20dXjBMyrzZjI</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-WCXlHSTLWPI20dXjBMyrzZjI" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-WCXlHSTLWPI20dXjBMyrzZjI</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_153659-ft-WCXlHSTLWPI20dXjBMyrzZjI/logs</code>
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221211_153708-ft-o7dOcHbIvQmXgBzqPWyf3izw</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-o7dOcHbIvQmXgBzqPWyf3izw" target="_blank">ft-o7dOcHbIvQmXgBzqPWyf3izw</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>█▅▅▅▄▃▂█▄▆▇▅▄▁▃▅▇▁▅▅▅▆▆▅▃▄▃▃▄▂▅▂▆▄▄▂▄▃▆▁</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▁▃▃▅▅▅▇▂▄▄▃▅▂▆▅▄▆▅▅▅▃▂▅▃▅▃▅▄▆▄▃▆▁▆▅▆▆█▂█</td></tr><tr><td>validation_loss</td><td>▅▇▃▅▅▄▃▄▃▆▆▆▅▃▂▂▅▄▁▅▄▇▃▂▅▁▄▄█▄▄▂▃▄▃▅▃▄▇▃</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▆▆▅█▆▅▄▂▄▄▁▇▃▃▇▆▅▁█▄█▅▆▆▆▇▄▅▂▃▅▅▇▆▇▄▆▄▃█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>5016.0</td></tr><tr><td>elapsed_tokens</td><td>2577688.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.24101</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.57835</td></tr><tr><td>validation_loss</td><td>0.2551</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.59813</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-o7dOcHbIvQmXgBzqPWyf3izw</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-o7dOcHbIvQmXgBzqPWyf3izw" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-o7dOcHbIvQmXgBzqPWyf3izw</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221211_153708-ft-o7dOcHbIvQmXgBzqPWyf3izw/logs</code>

# %% [markdown]
# ## Final Run - Refinements

# %%
final_tag = "final_run_5K_refinements"
parameter_combinations = {
                 "n_epochs":[1], 
                "prompt_loss_weight": [0.1],
                "learning_rate_multiplier": [0.2]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/selected_refinement_finetuning_dataset_top_1_train_5000.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
# this dev data is wrong, but it doesent matter since we dont useto select anything.
dev_data = "summarization_finetuning_datasets/selected_refinement_finetuning_dataset_top_1_train_5000.jsonl"
dev_data_id = upload_dataset_to_openai(dev_data)
print("Train dataset id {}".format(train_data_id))
print("Validation dataset id {}".format(dev_data_id))
# Out:
# Train dataset id file-Hzos2jlBJQgVPQFRwE8CA3UW
# Validation dataset id file-yQCqAlMZ2hCIXLoWtBFmJ8mx

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight_and_lr(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-nDHc9W0bNbt6SM8rz8VSWw8l
# with n_epochs 1
# with prompt_loss_weight:  0.1
#
#
#
# ['ft-nDHc9W0bNbt6SM8rz8VSWw8l']

# %%
# !openai api fine_tunes.get -i "ft-nDHc9W0bNbt6SM8rz8VSWw8l"
# Out:
# {
#   "created_at": 1670785819,
#   "events": [
#     {
#       "created_at": 1670785819,
#       "level": "info",
#       "message": "Created fine-tune: ft-nDHc9W0bNbt6SM8rz8VSWw8l",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670785821,
#       "level": "info",
#       "message": "Fine-tune costs $56.70",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1670785821,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 0",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": 8,
#     "learning_rate_multiplier": 0.2,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.1
#   },
#   "id": "ft-nDHc9W0bNbt6SM8rz8VSWw8l",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 8184621,
#       "created_at": 1670785811,
#       "filename": "file",
#       "id": "file-Hzos2jlBJQgVPQFRwE8CA3UW",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670785821,
#   "validation_files": [
#     {
#       "bytes": 8184621,
#       "created_at": 1670785813,
#       "filename": "file",
#       "id": "file-yQCqAlMZ2hCIXLoWtBFmJ8mx",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
finetuning_ids_hp_tuning = ['ft-nDHc9W0bNbt6SM8rz8VSWw8l']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-nDHc9W0bNbt6SM8rz8VSWw8l ...
# [2022-12-11 19:10:19] Created fine-tune: ft-nDHc9W0bNbt6SM8rz8VSWw8l
# [2022-12-11 19:10:21] Fine-tune costs $56.70
# [2022-12-11 19:10:21] Fine-tune enqueued. Queue number: 0
# [2022-12-11 19:13:49] Fine-tune started
# [2022-12-11 19:39:58] Completed epoch 1/1
# [2022-12-11 19:40:45] Uploaded model: davinci:ft-academicsnyuperez:final-run-5k-refinements-2022-12-11-19-40-44
# [2022-12-11 19:40:46] Uploaded result file: file-58XLcSLLDT7h0YkvC7pPVUvG
# [2022-12-11 19:40:46] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:final-run-5k-refinements-2022-12-11-19-40-44 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-nDHc9W0bNbt6SM8rz8VSWw8l']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
# ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: jerry_crea. Use `wandb login --relogin` to force relogin
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221212_075724-ft-nDHc9W0bNbt6SM8rz8VSWw8l</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-nDHc9W0bNbt6SM8rz8VSWw8l" target="_blank">ft-nDHc9W0bNbt6SM8rz8VSWw8l</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▇▇▅▅▃▃▇▆▅▅▃▄▇▆▅▆▅▅▆▃█▆▅▃▆▁▄▂▄▄▄▅▃▆▃▆▂▆▆▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▁▁▂▂▅▅▄▃▃▄▇▅▅▄▆▄▃▅▂▆▄▃▅█▃▇▇▃▃▃▄▄▅▅▅▄█▂▃▅</td></tr><tr><td>validation_loss</td><td>█▂▄▄▅▆▅▃▅▆▄▄▄▃▄▃▄▆▁▄▄▁▄▅▃▃▄▂▃▃▄▄▃▄▆▄▁▄▆▃</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▂▄▂▄▄▅▂▄▃▃▆▄▄▇▄▇▇▅▅▁▅▄▄▄▆▅█▄▃▂▅▅▆▂▃▅▇▅▃▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>5016.0</td></tr><tr><td>elapsed_tokens</td><td>2556312.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.16692</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.72222</td></tr><tr><td>validation_loss</td><td>0.19788</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.73611</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-nDHc9W0bNbt6SM8rz8VSWw8l</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-nDHc9W0bNbt6SM8rz8VSWw8l" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-nDHc9W0bNbt6SM8rz8VSWw8l</a><br/>Synced 4 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221212_075724-ft-nDHc9W0bNbt6SM8rz8VSWw8l/logs</code>

# %% [markdown]
# ## Fianl Run - Intial Summaries

# %%
final_tag = "final_run_5K_initial_summaries"
parameter_combinations = {
                 "n_epochs":[1], 
                "prompt_loss_weight": [0.1],
                "learning_rate_multiplier": [0.2]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/initial_summary_finetuning_dataset_train_5000.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
dev_data = "summarization_finetuning_datasets/initial_summary_finetuning_dataset_development_200.jsonl"
dev_data_id = upload_dataset_to_openai(dev_data)
print("Train dataset id {}".format(train_data_id))
print("Validation dataset id {}".format(dev_data_id))
# Out:
# Train dataset id file-3oSJjEpz5uYjJ6FwGlW0D4HU
# Validation dataset id file-Q9W8HTJJHzNNE4r2S0EQqoDS

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight_and_lr(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-HXmsrUGZWq03HcWrLl6MsbAf
# with n_epochs 1
# with prompt_loss_weight:  0.1
#
#
#
# ['ft-HXmsrUGZWq03HcWrLl6MsbAf']

# %%
# !openai api fine_tunes.get -i "ft-HXmsrUGZWq03HcWrLl6MsbAf"
# Out:
# {
#   "created_at": 1670785850,
#   "events": [
#     {
#       "created_at": 1670785850,
#       "level": "info",
#       "message": "Created fine-tune: ft-HXmsrUGZWq03HcWrLl6MsbAf",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": null,
#     "learning_rate_multiplier": 0.2,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.1
#   },
#   "id": "ft-HXmsrUGZWq03HcWrLl6MsbAf",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 8013932,
#       "created_at": 1670785847,
#       "filename": "file",
#       "id": "file-3oSJjEpz5uYjJ6FwGlW0D4HU",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1670785850,
#   "validation_files": [
#     {
#       "bytes": 325310,
#       "created_at": 1670785848,
#       "filename": "file",
#       "id": "file-Q9W8HTJJHzNNE4r2S0EQqoDS",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "uploaded",
#       "status_details": null
#     }
#   ]
# }

# %%
finetuning_ids_hp_tuning = ['ft-HXmsrUGZWq03HcWrLl6MsbAf']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-HXmsrUGZWq03HcWrLl6MsbAf ...
# [2022-12-11 19:10:50] Created fine-tune: ft-HXmsrUGZWq03HcWrLl6MsbAf
# [2022-12-11 19:40:47] Fine-tune costs $55.76
# [2022-12-11 19:40:47] Fine-tune enqueued. Queue number: 0
# [2022-12-11 19:40:48] Fine-tune started
# [2022-12-11 20:06:23] Completed epoch 1/1
# [2022-12-11 20:07:23] Uploaded model: davinci:ft-academicsnyuperez:final-run-5k-initial-summaries-2022-12-11-20-07-23
# [2022-12-11 20:07:25] Uploaded result file: file-qJQ5OyrG9UpcKTqRxpi7ffIH
# [2022-12-11 20:07:25] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:final-run-5k-initial-summaries-2022-12-11-20-07-23 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-HXmsrUGZWq03HcWrLl6MsbAf']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221212_075754-ft-HXmsrUGZWq03HcWrLl6MsbAf</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-HXmsrUGZWq03HcWrLl6MsbAf" target="_blank">ft-HXmsrUGZWq03HcWrLl6MsbAf</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▆▆▅▂▃▁▆▆▃▅▂▂▄▅▃▄▅▄▆▃█▆▄▃▆▁▃▁▅▃▂▄▃▆▃▃▃▄▄▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▁▁▃▅▃▆▂▄▃▃▄▅▅▁█▄▄▅▃▃▄▂▄▅▃▅▃▆▂▃▅▂▃▃▅▆▄▃▅▅</td></tr><tr><td>validation_loss</td><td>▇█▆▅█▅▁▄▄▅▆▄▄▅▆█▇▅▃▃▆▅▃▂▄▃▆▄▅▂▇▄▅▂▅▄▆▇▂▇</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▃▅▄▃▁▅█▆▆▆▄▅▅▄▃▃▄▅▅▆▅▇██▅▅▃▄▅▄▇▆▆█▅▄▆▆▇▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>5016.0</td></tr><tr><td>elapsed_tokens</td><td>2531288.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.15701</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.74286</td></tr><tr><td>validation_loss</td><td>0.21984</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.66298</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-HXmsrUGZWq03HcWrLl6MsbAf</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-HXmsrUGZWq03HcWrLl6MsbAf" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-HXmsrUGZWq03HcWrLl6MsbAf</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221212_075754-ft-HXmsrUGZWq03HcWrLl6MsbAf/logs</code>

# %% [markdown]
# ## Fianl Run - Selected Refinement with Feedback

# %%
final_tag = "final_run_5K_refinement_feedback"
parameter_combinations = {
                 "n_epochs":[1], 
                "prompt_loss_weight": [0.1],
                "learning_rate_multiplier": [0.2]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/selected_refinement_with_feedback_finetuning_dataset_train_5000.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
dev_data = "summarization_finetuning_datasets/selected_refinement_with_feedback_finetuning_dataset_development_200.jsonl"
dev_data_id = upload_dataset_to_openai(dev_data)
print("Train dataset id {}".format(train_data_id))
print("Validation dataset id {}".format(dev_data_id))
# Out:
# Train dataset id file-oTf7rliA43JzY1vxlHNXFlgv
# Validation dataset id file-fy5ezk8Rn92b6GFkAqBsnOnH

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight_and_lr(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-TesWYnDMFpmvro1A4TKyPzr0
# with n_epochs 1
# with prompt_loss_weight:  0.1
#
#
#
# ['ft-TesWYnDMFpmvro1A4TKyPzr0']

# %%
# !openai api fine_tunes.get -i "ft-TesWYnDMFpmvro1A4TKyPzr0"

# %%
finetuning_ids_hp_tuning = ['ft-TesWYnDMFpmvro1A4TKyPzr0']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-TesWYnDMFpmvro1A4TKyPzr0 ...
# [2022-12-12 08:21:28] Created fine-tune: ft-TesWYnDMFpmvro1A4TKyPzr0
# [2022-12-12 08:33:35] Fine-tune costs $67.87
# [2022-12-12 08:33:35] Fine-tune enqueued. Queue number: 0
# [2022-12-12 08:33:37] Fine-tune started
# [2022-12-12 09:01:43] Completed epoch 1/1
# [2022-12-12 09:02:24] Uploaded model: davinci:ft-academicsnyuperez:final-run-5k-refinement-feedback-2022-12-12-09-02-24
# [2022-12-12 09:02:26] Uploaded result file: file-YEOAiSQJBZWCXXR7KEIoevZX
# [2022-12-12 09:02:26] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:final-run-5k-refinement-feedback-2022-12-12-09-02-24 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-TesWYnDMFpmvro1A4TKyPzr0']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: jerry_crea. Use `wandb login --relogin` to force relogin
# wandb version 0.13.6 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221213_141830-ft-TesWYnDMFpmvro1A4TKyPzr0</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-TesWYnDMFpmvro1A4TKyPzr0" target="_blank">ft-TesWYnDMFpmvro1A4TKyPzr0</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>█▆▅█▆▄▅▆▃▃▃█▅▄▃▆▃▄▄▆▆▄▆▅▂▅▃▆▆▅▁▃▅▄▃▅▇▅▄▆</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▅▃▄▃▃▅▅▂▅▆▇▂▁▅▅▃▇▅▃▆▃▃▂▂▇▂▅▃▄▃█▆▃▆▆▅▁▅▆▃</td></tr><tr><td>validation_loss</td><td>█▆▅▄▄▃▆▄▃▄▃▄▂▄▅▃▅▃▃▃▄▃▄▃▃▅▂▄▆▅▁▃▃▃▃▂▃▄▄▃</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▁▁▂▃▄▅▃▇▅▄▆▄▅▄▃▆▄▄▅▆▄▃█▄▇▂▅▅▂▃█▆▃▆▅█▆▄▄▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>5008.0</td></tr><tr><td>elapsed_tokens</td><td>2940176.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.21042</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.842</td></tr><tr><td>validation_loss</td><td>0.25118</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.73302</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-TesWYnDMFpmvro1A4TKyPzr0</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-TesWYnDMFpmvro1A4TKyPzr0" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-TesWYnDMFpmvro1A4TKyPzr0</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221213_141830-ft-TesWYnDMFpmvro1A4TKyPzr0/logs</code>

# %% [markdown]
# # Refinmenents Data Set size - 200
#
# Here we do more hp-tuning for the iterative refinement experiments.

# %% [markdown]
# ## Epochs
#
#
# n_epochs=1,2,3,4
#
# Results:
#
# Epoch 1: 3.31
#
# Epoch 2: 3.60
#
# Epoch 3: 4.54
#
# Epoch 4: 6.52
#
# Best Epoch: 1

# %%
final_tag = "hp_tuning_refi_base_200_n_epochs"
parameter_combinations = {
                "n_epochs":[1,2,3,4], 
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/iterative_finetuning/baseline_refinement_dataset_round_1_200.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
dev_data = "summarization_finetuning_datasets/selected_refinement_finetuning_dataset_top_1_development_200.jsonl"
dev_data_id = upload_dataset_to_openai(dev_data)
print("Train dataset id {}".format(train_data_id))
print("Validation dataset id {}".format(dev_data_id))
# Out:
# Train dataset id file-jvNNiWWhoSyjI7xSDNJBC453
# Validation dataset id file-X0wgIqqs117OWeITus0yKPDj

# %%
train_data_id = "file-jvNNiWWhoSyjI7xSDNJBC453"
dev_data_id = "file-X0wgIqqs117OWeITus0yKPDj"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs(n_epochs=n_epochs, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-bDCgR71oXfL4xSeR8e3YAQvm
# with n_epochs 1
#
#
#
# ['ft-bDCgR71oXfL4xSeR8e3YAQvm']
# Initialized job ft-3AtPWb51Of1hSxDfg2z7hDlg
# with n_epochs 2
#
#
#
# ['ft-bDCgR71oXfL4xSeR8e3YAQvm', 'ft-3AtPWb51Of1hSxDfg2z7hDlg']
# Initialized job ft-A8TlEcv2Xd2CBaO1gqACHPSm
# with n_epochs 3
#
#
#
# ['ft-bDCgR71oXfL4xSeR8e3YAQvm', 'ft-3AtPWb51Of1hSxDfg2z7hDlg', 'ft-A8TlEcv2Xd2CBaO1gqACHPSm']
# Initialized job ft-Q05UN9MRjAVOAsNMWVV8rcWT
# with n_epochs 4
#
#
#
# ['ft-bDCgR71oXfL4xSeR8e3YAQvm', 'ft-3AtPWb51Of1hSxDfg2z7hDlg', 'ft-A8TlEcv2Xd2CBaO1gqACHPSm', 'ft-Q05UN9MRjAVOAsNMWVV8rcWT']

# %%
# !openai api fine_tunes.get -i "ft-bDCgR71oXfL4xSeR8e3YAQvm"
# Out:
# {
#   "created_at": 1672132122,
#   "events": [
#     {
#       "created_at": 1672132122,
#       "level": "info",
#       "message": "Created fine-tune: ft-bDCgR71oXfL4xSeR8e3YAQvm",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": null,
#     "learning_rate_multiplier": null,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.01
#   },
#   "id": "ft-bDCgR71oXfL4xSeR8e3YAQvm",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 330875,
#       "created_at": 1672132072,
#       "filename": "file",
#       "id": "file-jvNNiWWhoSyjI7xSDNJBC453",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1672132122,
#   "validation_files": [
#     {
#       "bytes": 332653,
#       "created_at": 1672132074,
#       "filename": "file",
#       "id": "file-X0wgIqqs117OWeITus0yKPDj",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-bDCgR71oXfL4xSeR8e3YAQvm ...
# [2022-12-27 09:08:42] Created fine-tune: ft-bDCgR71oXfL4xSeR8e3YAQvm
# [2022-12-27 09:09:28] Fine-tune costs $2.31
# [2022-12-27 09:09:29] Fine-tune enqueued. Queue number: 0
# [2022-12-27 09:09:32] Fine-tune started
# [2022-12-27 09:12:53] Completed epoch 1/1
# [2022-12-27 09:13:37] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-n-epochs-2022-12-27-09-13-37
# [2022-12-27 09:13:38] Uploaded result file: file-5MSXF0edkYM7kJIF2MRKXvY0
# [2022-12-27 09:13:38] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-n-epochs-2022-12-27-09-13-37 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-3AtPWb51Of1hSxDfg2z7hDlg ...
# [2022-12-27 09:08:43] Created fine-tune: ft-3AtPWb51Of1hSxDfg2z7hDlg
# [2022-12-27 09:14:26] Fine-tune costs $4.62
# [2022-12-27 09:14:27] Fine-tune enqueued. Queue number: 0
# [2022-12-27 09:14:31] Fine-tune started
# [2022-12-27 09:17:51] Completed epoch 1/2
# [2022-12-27 09:19:46] Completed epoch 2/2
# [2022-12-27 09:20:28] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-n-epochs-2022-12-27-09-20-27
# [2022-12-27 09:20:29] Uploaded result file: file-2OO06E5fcx5IIORyeGNh7poP
# [2022-12-27 09:20:29] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-n-epochs-2022-12-27-09-20-27 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-A8TlEcv2Xd2CBaO1gqACHPSm ...
# [2022-12-27 09:08:43] Created fine-tune: ft-A8TlEcv2Xd2CBaO1gqACHPSm
# [2022-12-27 09:21:03] Fine-tune costs $6.93
# [2022-12-27 09:21:03] Fine-tune enqueued. Queue number: 0
# [2022-12-27 09:21:06] Fine-tune started
# [2022-12-27 09:24:24] Completed epoch 1/3
# [2022-12-27 09:26:18] Completed epoch 2/3
# [2022-12-27 09:28:14] Completed epoch 3/3
# [2022-12-27 09:28:56] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-n-epochs-2022-12-27-09-28-55
# [2022-12-27 09:28:57] Uploaded result file: file-1XeEMXDdo4Oo1OsHso4Kh2as
# [2022-12-27 09:28:57] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-n-epochs-2022-12-27-09-28-55 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-Q05UN9MRjAVOAsNMWVV8rcWT ...
# [2022-12-27 09:08:43] Created fine-tune: ft-Q05UN9MRjAVOAsNMWVV8rcWT
# [2022-12-27 09:29:18] Fine-tune costs $9.24
# [2022-12-27 09:29:19] Fine-tune enqueued. Queue number: 0
# [2022-12-27 09:29:20] Fine-tune started
# [2022-12-27 09:33:01] Completed epoch 1/4
# [2022-12-27 09:34:57] Completed epoch 2/4
# [2022-12-27 09:36:52] Completed epoch 3/4
# [2022-12-27 09:38:45] Completed epoch 4/4
# [2022-12-27 09:39:31] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-n-epochs-2022-12-27-09-39-31
# [2022-12-27 09:39:33] Uploaded result file: file-QJXYCfPMQrtSAiab2dlqS2y9
# [2022-12-27 09:39:33] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-n-epochs-2022-12-27-09-39-31 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-bDCgR71oXfL4xSeR8e3YAQvm', 'ft-3AtPWb51Of1hSxDfg2z7hDlg', 'ft-A8TlEcv2Xd2CBaO1gqACHPSm', 'ft-Q05UN9MRjAVOAsNMWVV8rcWT']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: jerry_crea. Use `wandb login --relogin` to force relogin
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_100556-ft-bDCgR71oXfL4xSeR8e3YAQvm</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-bDCgR71oXfL4xSeR8e3YAQvm" target="_blank">ft-bDCgR71oXfL4xSeR8e3YAQvm</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.629 MB of 0.629 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>█▅▄▅▁▆▄▄▇▂▃▃▄▄▄▄▅▃▃▅▄▂▅▄▂▅▃▂▃▅▆▃▄▄▂▅▄█▄▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▁▅▃▃█▄▅▁▄▅▅▆▂▅▂▄▆▆▄▃▅▄▁▅▇▃▆▇▆▅▄▄▂▁▅▅▅▃▅█</td></tr><tr><td>validation_loss</td><td>▄▄▅▁█▄▄▅▇▅▃▃▄▃▇▇▄▁▂▅▂▃▅▂▂▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▅▅▄█▅▅▆▇▅▆▇▆▇█▅▁▇▆▅▆█▆▆█▃▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>202.0</td></tr><tr><td>elapsed_tokens</td><td>78530.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.06943</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.89655</td></tr><tr><td>validation_loss</td><td>0.09632</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.61538</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-bDCgR71oXfL4xSeR8e3YAQvm</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-bDCgR71oXfL4xSeR8e3YAQvm" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-bDCgR71oXfL4xSeR8e3YAQvm</a><br/>Synced 4 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_100556-ft-bDCgR71oXfL4xSeR8e3YAQvm/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_100609-ft-3AtPWb51Of1hSxDfg2z7hDlg</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-3AtPWb51Of1hSxDfg2z7hDlg" target="_blank">ft-3AtPWb51Of1hSxDfg2z7hDlg</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>█▅▆▄▆▄▄▅▅▅▄▃▃▂▃▆▂▃▅▄▄▂▂▃▃▄▂▂▂▄▃▄▂▃▄▂▃▁▁▄</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▁▂▃▄▃▅▇▂▆▄▄▃▇▄▆▃▅▄▄▄█▃▇▅▆▇▆▇▅▃▃▄▆▂▅▆▅▇▇▆</td></tr><tr><td>validation_loss</td><td>▃▃▄▂▃▃▄▅▃▃▄▅▅▃▂▄▂▃▃▂▂▄▃▆▃▅▃▂▂▂▅▃▅▃▃▅▁▇▂█</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▄▄▃▆▄▅▅▄▅▅▅▄▁▅▅▄▆▅▆▂▄▂▆▄▆▅▄▅█▇▃▆▄▆▅▆█▄▅▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>402.0</td></tr><tr><td>elapsed_tokens</td><td>156194.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.04425</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.93023</td></tr><tr><td>validation_loss</td><td>0.30193</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.53488</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-3AtPWb51Of1hSxDfg2z7hDlg</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-3AtPWb51Of1hSxDfg2z7hDlg" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-3AtPWb51Of1hSxDfg2z7hDlg</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_100609-ft-3AtPWb51Of1hSxDfg2z7hDlg/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_100619-ft-A8TlEcv2Xd2CBaO1gqACHPSm</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-A8TlEcv2Xd2CBaO1gqACHPSm" target="_blank">ft-A8TlEcv2Xd2CBaO1gqACHPSm</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▆▅▅▅▅▆▂▅▃█▅▆▄▃▃▂▃▁▂▄▃▄▃▂▃▄▃▁▁▂▁▂▁▂▂▄▁▂▃▁</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▃▁▃▅▅▃▁▄▂▃▃▃▄▂▅▅▅▇▆▆▃▅▄▅▇▅▃▇▇▇█▆▇▅▆▅▆▆▆▇</td></tr><tr><td>validation_loss</td><td>▅▆▅▄▇▃▂▂▁▅▂▁▁▃▃▅▁▃▅▃▃▆▄▃▅█▄▃▃▅▂▃▃▇▂▆▆▂▂▃</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▆▃▆▄▁▅▅▅▆▆▅▇█▅▆▃▇▅▃▆▅▄█▇▂▄▃▆▆▄█▄▄▄█▃▆▆▅▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>602.0</td></tr><tr><td>elapsed_tokens</td><td>233874.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.09135</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.83871</td></tr><tr><td>validation_loss</td><td>0.12758</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.59524</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-A8TlEcv2Xd2CBaO1gqACHPSm</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-A8TlEcv2Xd2CBaO1gqACHPSm" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-A8TlEcv2Xd2CBaO1gqACHPSm</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_100619-ft-A8TlEcv2Xd2CBaO1gqACHPSm/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_100629-ft-Q05UN9MRjAVOAsNMWVV8rcWT</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-Q05UN9MRjAVOAsNMWVV8rcWT" target="_blank">ft-Q05UN9MRjAVOAsNMWVV8rcWT</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▅█▄▅▃▅▃▇▅▃▅▃▃▅▂▂▂▂▃▃▂▁▂▂▁▁▃▂▂▂▂▁▂▁▁▁▁▂▁▁</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁██</td></tr><tr><td>training_token_accuracy</td><td>▂▁▄▃▅▁▁▃▂▃▃▁▄▄▅▄▅▄▅▄▇▇█▆▇▇▄▆▆▆▇▇▅▇█▇█▇██</td></tr><tr><td>validation_loss</td><td>▃▃▃▄▄▂▁▃▃▁▂▃▁▄▂▂▃▁▃▄▂▂▂▄▂▁▇▄▂▂█▂▃▄▃▂▄▃▂▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▆▇▄▁▅▆▆▆▄█▆▃▇▅▄▅▆▆▂▅▅▇▆▅▅▅▆▆▅▆▃▅▅▃▅▇▄▇▆▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>802.0</td></tr><tr><td>elapsed_tokens</td><td>311802.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.03836</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.82609</td></tr><tr><td>validation_loss</td><td>0.19878</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.67442</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-Q05UN9MRjAVOAsNMWVV8rcWT</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-Q05UN9MRjAVOAsNMWVV8rcWT" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-Q05UN9MRjAVOAsNMWVV8rcWT</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_100629-ft-Q05UN9MRjAVOAsNMWVV8rcWT/logs</code>

# %% [markdown]
# ## Prompt Loss Weight
# **Sweep**:
#
# n_epochs=1
#
# prompt_loss_weight = 0, 0.01, 0.05, 0.1
#
# **Results:**
#
#
# *   prompt_loss_weight 0 = 3.34
# *   prompt_loss_weight 0.01 = 3.35
# *   prompt_loss_weight 0.05 = 3.33
# *   prompt_loss_weight 0.1 = 3.35
#
# best promtp loss weight = 0.05

# %%
final_tag = "hp_tuning_refi_base_200_prompt_l_weight"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0, 0.01, 0.05, 0.1]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
train_data_id = "file-jvNNiWWhoSyjI7xSDNJBC453"
dev_data_id = "file-X0wgIqqs117OWeITus0yKPDj"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-yb3GdQudccplAAtWo10Mwi0w
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-yb3GdQudccplAAtWo10Mwi0w']
# Initialized job ft-sJS6UQ0JGsFq2EzMQ7t2J112
# with n_epochs 1
# with prompt_loss_weight:  0.01
#
#
#
# ['ft-yb3GdQudccplAAtWo10Mwi0w', 'ft-sJS6UQ0JGsFq2EzMQ7t2J112']
# Initialized job ft-wB2YMeBvova1btiS9z7gGmou
# with n_epochs 1
# with prompt_loss_weight:  0.05
#
#
#
# ['ft-yb3GdQudccplAAtWo10Mwi0w', 'ft-sJS6UQ0JGsFq2EzMQ7t2J112', 'ft-wB2YMeBvova1btiS9z7gGmou']
# Initialized job ft-bVmP9q0xLb4GcNs1lyK8JgUT
# with n_epochs 1
# with prompt_loss_weight:  0.1
#
#
#
# ['ft-yb3GdQudccplAAtWo10Mwi0w', 'ft-sJS6UQ0JGsFq2EzMQ7t2J112', 'ft-wB2YMeBvova1btiS9z7gGmou', 'ft-bVmP9q0xLb4GcNs1lyK8JgUT']

# %%
# !openai api fine_tunes.get -i "ft-yb3GdQudccplAAtWo10Mwi0w"
# Out:
# {
#   "created_at": 1672139179,
#   "events": [
#     {
#       "created_at": 1672139179,
#       "level": "info",
#       "message": "Created fine-tune: ft-yb3GdQudccplAAtWo10Mwi0w",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1672139262,
#       "level": "info",
#       "message": "Fine-tune costs $2.31",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1672139262,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 0",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1672139265,
#       "level": "info",
#       "message": "Fine-tune started",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": 1,
#     "learning_rate_multiplier": 0.1,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.0
#   },
#   "id": "ft-yb3GdQudccplAAtWo10Mwi0w",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "running",
#   "training_files": [
#     {
#       "bytes": 330875,
#       "created_at": 1672132072,
#       "filename": "file",
#       "id": "file-jvNNiWWhoSyjI7xSDNJBC453",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1672139265,
#   "validation_files": [
#     {
#       "bytes": 332653,
#       "created_at": 1672132074,
#       "filename": "file",
#       "id": "file-X0wgIqqs117OWeITus0yKPDj",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
finetuning_ids_hp_tuning = ['ft-yb3GdQudccplAAtWo10Mwi0w', 'ft-sJS6UQ0JGsFq2EzMQ7t2J112', 'ft-wB2YMeBvova1btiS9z7gGmou', 'ft-bVmP9q0xLb4GcNs1lyK8JgUT']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-yb3GdQudccplAAtWo10Mwi0w ...
# [2022-12-27 11:06:19] Created fine-tune: ft-yb3GdQudccplAAtWo10Mwi0w
# [2022-12-27 11:07:42] Fine-tune costs $2.31
# [2022-12-27 11:07:42] Fine-tune enqueued. Queue number: 0
# [2022-12-27 11:07:45] Fine-tune started
# [2022-12-27 11:11:14] Completed epoch 1/1
# [2022-12-27 11:12:00] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-prompt-l-weight-2022-12-27-11-12-00
# [2022-12-27 11:12:01] Uploaded result file: file-XduCG68BeGIyLKK60k0VWxWc
# [2022-12-27 11:12:01] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-prompt-l-weight-2022-12-27-11-12-00 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-sJS6UQ0JGsFq2EzMQ7t2J112 ...
# [2022-12-27 11:06:19] Created fine-tune: ft-sJS6UQ0JGsFq2EzMQ7t2J112
# [2022-12-27 11:12:39] Fine-tune costs $2.31
# [2022-12-27 11:12:39] Fine-tune enqueued. Queue number: 0
# [2022-12-27 11:12:41] Fine-tune started
# [2022-12-27 11:16:13] Completed epoch 1/1
# [2022-12-27 11:16:56] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-prompt-l-weight-2022-12-27-11-16-55
# [2022-12-27 11:16:58] Uploaded result file: file-tvXQrxSKX0blY4RLyT8UO5V9
# [2022-12-27 11:16:58] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-prompt-l-weight-2022-12-27-11-16-55 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-wB2YMeBvova1btiS9z7gGmou ...
# [2022-12-27 11:06:19] Created fine-tune: ft-wB2YMeBvova1btiS9z7gGmou
# [2022-12-27 11:17:39] Fine-tune costs $2.31
# [2022-12-27 11:17:39] Fine-tune enqueued. Queue number: 0
# [2022-12-27 11:17:40] Fine-tune started
# [2022-12-27 11:21:01] Completed epoch 1/1
# [2022-12-27 11:21:45] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-prompt-l-weight-2022-12-27-11-21-45
# [2022-12-27 11:21:46] Uploaded result file: file-4eZmzaAcDtUENn3C8HDhDPMm
# [2022-12-27 11:21:47] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-prompt-l-weight-2022-12-27-11-21-45 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-bVmP9q0xLb4GcNs1lyK8JgUT ...
# [2022-12-27 11:06:19] Created fine-tune: ft-bVmP9q0xLb4GcNs1lyK8JgUT
# [2022-12-27 11:21:52] Fine-tune costs $2.31
# [2022-12-27 11:21:53] Fine-tune enqueued. Queue number: 0
# [2022-12-27 11:21:54] Fine-tune started
# [2022-12-27 11:25:12] Completed epoch 1/1
# [2022-12-27 11:25:59] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-prompt-l-weight-2022-12-27-11-25-59
# [2022-12-27 11:26:02] Uploaded result file: file-K902HPrOQwGkyuOosNms2vuE
# [2022-12-27 11:26:02] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-prompt-l-weight-2022-12-27-11-25-59 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = finetuning_ids_hp_tuning = ['ft-yb3GdQudccplAAtWo10Mwi0w', 'ft-sJS6UQ0JGsFq2EzMQ7t2J112', 'ft-wB2YMeBvova1btiS9z7gGmou', 'ft-bVmP9q0xLb4GcNs1lyK8JgUT']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_123131-ft-yb3GdQudccplAAtWo10Mwi0w</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-yb3GdQudccplAAtWo10Mwi0w" target="_blank">ft-yb3GdQudccplAAtWo10Mwi0w</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▂▁▂▂▂▂▂▂▂▂▂▂▃▂▃▂▁▂█▂▂▃▃▂▃▂▂▃▄▃▂▁▂▁▄▂▂▄▂▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄█▇▂▅▄▅▆▄▆▆▅▂▂▃▅▄▇▇▄▄▁▂▅▄▂▅▄▄▄▄▃▃▆▆▅▆▅▂▄</td></tr><tr><td>validation_loss</td><td>▇▇▇▇▄▆▁█▃▅█▄▄▃▇▃▄▆▆▄▆▃▃▃▃▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▆▃▆▆▅▄▇▁█▅▄▆▅▅▅▆▆▅▆▆▅▇▇█▅▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>202.0</td></tr><tr><td>elapsed_tokens</td><td>78322.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.16498</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.64286</td></tr><tr><td>validation_loss</td><td>0.09407</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.70588</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-yb3GdQudccplAAtWo10Mwi0w</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-yb3GdQudccplAAtWo10Mwi0w" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-yb3GdQudccplAAtWo10Mwi0w</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_123131-ft-yb3GdQudccplAAtWo10Mwi0w/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_123141-ft-sJS6UQ0JGsFq2EzMQ7t2J112</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-sJS6UQ0JGsFq2EzMQ7t2J112" target="_blank">ft-sJS6UQ0JGsFq2EzMQ7t2J112</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▇▄▄▄▄▄▃▅▄▂▃▅▂▅█▇▄▄▇▅▁▃▆▃▆▃▃▃▄▅▃▅▄▅▅▃▅▅▃▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▃▅▃▂▄▁▃▅▆▃▅▂█▄▃▃▃▄▄▄█▆▃▆▄▅▄▅▃▅▆▃▄▄▄▅▄▂▃▄</td></tr><tr><td>validation_loss</td><td>▄▂▁▂▂▂▃▃▁▁▇▄▄█▃▂▂▂▃▄▆▂▅▂▄▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▆▅█▇█▂█▅▆▄▂█▃▅▇▆▅▇▁▅▄▇▇▂▇▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>201.0</td></tr><tr><td>elapsed_tokens</td><td>78081.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.09254</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.8</td></tr><tr><td>validation_loss</td><td>0.14654</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.61364</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-sJS6UQ0JGsFq2EzMQ7t2J112</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-sJS6UQ0JGsFq2EzMQ7t2J112" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-sJS6UQ0JGsFq2EzMQ7t2J112</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_123141-ft-sJS6UQ0JGsFq2EzMQ7t2J112/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_123150-ft-wB2YMeBvova1btiS9z7gGmou</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-wB2YMeBvova1btiS9z7gGmou" target="_blank">ft-wB2YMeBvova1btiS9z7gGmou</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▃▁▂▃▃▂▂▂▂▂▂▂▃▃▃▂▁▂█▂▂▃▃▂▃▂▂▃▄▃▃▂▂▁▄▃▂▄▂▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄█▇▄▅▅▆▆▅▇▆▆▂▃▄▅▅▇▅▅▅▁▃▆▅▃▅▃▅▅▄▃▄▆▇▆▇▅▄▆</td></tr><tr><td>validation_loss</td><td>▇▇▆▆▄▆▁█▂▅▇▃▄▃▇▂▄▅▅▃▆▃▃▂▄▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▆▃▆▆▅▄▇▁█▅▄▅▆▅▅▇▇▆▇▆▅▇▇▇▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>202.0</td></tr><tr><td>elapsed_tokens</td><td>78322.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.2499</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.69048</td></tr><tr><td>validation_loss</td><td>0.18832</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.67647</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-wB2YMeBvova1btiS9z7gGmou</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-wB2YMeBvova1btiS9z7gGmou" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-wB2YMeBvova1btiS9z7gGmou</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_123150-ft-wB2YMeBvova1btiS9z7gGmou/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_123159-ft-bVmP9q0xLb4GcNs1lyK8JgUT</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-bVmP9q0xLb4GcNs1lyK8JgUT" target="_blank">ft-bVmP9q0xLb4GcNs1lyK8JgUT</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▃▁▃▃▃▂▂▂▃▃▃▂▄▄▃▂▁▂█▁▃▄▃▃▃▃▂▃▃▃▄▂▃▂▄▄▂▄▂▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄█▇▃▅▄▆▆▄▇▆▅▂▃▄▅▅▇▅▅▄▁▃▅▄▂▅▂▅▅▃▂▃▆▆▆▆▅▃▅</td></tr><tr><td>validation_loss</td><td>▇▇▆▆▄▅▁█▁▄▆▂▄▂▇▂▄▅▅▂▆▃▃▂▅▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▅▂▆▆▆▃▆▁█▄▃▅▅▄▅▆▆▅▅▄▅▆▆▇▆▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>202.0</td></tr><tr><td>elapsed_tokens</td><td>78322.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.31714</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.71429</td></tr><tr><td>validation_loss</td><td>0.2822</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.64706</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-bVmP9q0xLb4GcNs1lyK8JgUT</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-bVmP9q0xLb4GcNs1lyK8JgUT" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-bVmP9q0xLb4GcNs1lyK8JgUT</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_123159-ft-bVmP9q0xLb4GcNs1lyK8JgUT/logs</code>

# %% [markdown]
# ## Learning rate Multiplier
#
# n_epochs=1
#
# prompt_loss_weight = 0.05
#
# learning_rate_multiplier = 0.02, 0.05, 0.1, or 0.2
#
# **Results**:
#
# *   learning_rate_multiplier 0.02: 3.52
# *   learning_rate_multiplier 0.05: 3.37
# *   learning_rate_multiplier 0.1: 3.31
# *   learning_rate_multiplier 0.2: 3.32
#
# **Best lr**: 0.1

# %%
final_tag = "hp_tuning_refi_base_200_lr"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0.05],
                "learning_rate_multiplier": [0.02, 0.05, 0.1, 0.2]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
train_data_id = "file-jvNNiWWhoSyjI7xSDNJBC453"
dev_data_id = "file-X0wgIqqs117OWeITus0yKPDj"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight_and_lr(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-lPVOx8YvErpMqG40HcpOIvTD
# with n_epochs 1
# with prompt_loss_weight:  0.05
#
#
#
# ['ft-lPVOx8YvErpMqG40HcpOIvTD']
# Initialized job ft-bDTCyBIreERL6FACL6WDwZr8
# with n_epochs 1
# with prompt_loss_weight:  0.05
#
#
#
# ['ft-lPVOx8YvErpMqG40HcpOIvTD', 'ft-bDTCyBIreERL6FACL6WDwZr8']
# Initialized job ft-cF72VjqoAdcWg1ZgHuc9JaNZ
# with n_epochs 1
# with prompt_loss_weight:  0.05
#
#
#
# ['ft-lPVOx8YvErpMqG40HcpOIvTD', 'ft-bDTCyBIreERL6FACL6WDwZr8', 'ft-cF72VjqoAdcWg1ZgHuc9JaNZ']
# Initialized job ft-oy7nUTVNVQZ1j0RovxmXGKsP
# with n_epochs 1
# with prompt_loss_weight:  0.05
#
#
#
# ['ft-lPVOx8YvErpMqG40HcpOIvTD', 'ft-bDTCyBIreERL6FACL6WDwZr8', 'ft-cF72VjqoAdcWg1ZgHuc9JaNZ', 'ft-oy7nUTVNVQZ1j0RovxmXGKsP']

# %%
# !openai api fine_tunes.get -i "ft-lPVOx8YvErpMqG40HcpOIvTD"
# Out:
# {
#   "created_at": 1672146256,
#   "events": [
#     {
#       "created_at": 1672146256,
#       "level": "info",
#       "message": "Created fine-tune: ft-lPVOx8YvErpMqG40HcpOIvTD",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1672146348,
#       "level": "info",
#       "message": "Fine-tune costs $2.31",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1672146349,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 0",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1672146351,
#       "level": "info",
#       "message": "Fine-tune started",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1672146589,
#       "level": "info",
#       "message": "Completed epoch 1/1",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1672146647,
#       "level": "info",
#       "message": "Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-lr-2022-12-27-13-10-46",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1672146648,
#       "level": "info",
#       "message": "Uploaded result file: file-XE1bhCNdtnIqs09iITKA7BUq",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1672146648,
#       "level": "info",
#       "message": "Fine-tune succeeded",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": "davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-lr-2022-12-27-13-10-46",
#   "hyperparams": {
#     "batch_size": 1,
#     "learning_rate_multiplier": 0.02,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.05
#   },
#   "id": "ft-lPVOx8YvErpMqG40HcpOIvTD",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [
#     {
#       "bytes": 12468,
#       "created_at": 1672146648,
#       "filename": "compiled_results.csv",
#       "id": "file-XE1bhCNdtnIqs09iITKA7BUq",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "status": "succeeded",
#   "training_files": [
#     {
#       "bytes": 330875,
#       "created_at": 1672132072,
#       "filename": "file",
#       "id": "file-jvNNiWWhoSyjI7xSDNJBC453",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1672146648,
#   "validation_files": [
#     {
#       "bytes": 332653,
#       "created_at": 1672132074,
#       "filename": "file",
#       "id": "file-X0wgIqqs117OWeITus0yKPDj",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
finetuning_ids_hp_tuning = ['ft-lPVOx8YvErpMqG40HcpOIvTD', 'ft-bDTCyBIreERL6FACL6WDwZr8', 'ft-cF72VjqoAdcWg1ZgHuc9JaNZ', 'ft-oy7nUTVNVQZ1j0RovxmXGKsP']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-lPVOx8YvErpMqG40HcpOIvTD ...
# [2022-12-27 13:04:16] Created fine-tune: ft-lPVOx8YvErpMqG40HcpOIvTD
# [2022-12-27 13:05:48] Fine-tune costs $2.31
# [2022-12-27 13:05:49] Fine-tune enqueued. Queue number: 0
# [2022-12-27 13:05:51] Fine-tune started
# [2022-12-27 13:09:49] Completed epoch 1/1
# [2022-12-27 13:10:47] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-lr-2022-12-27-13-10-46
# [2022-12-27 13:10:48] Uploaded result file: file-XE1bhCNdtnIqs09iITKA7BUq
# [2022-12-27 13:10:48] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-lr-2022-12-27-13-10-46 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-bDTCyBIreERL6FACL6WDwZr8 ...
# [2022-12-27 13:04:16] Created fine-tune: ft-bDTCyBIreERL6FACL6WDwZr8
# [2022-12-27 13:11:36] Fine-tune costs $2.31
# [2022-12-27 13:11:37] Fine-tune enqueued. Queue number: 0
# [2022-12-27 13:11:39] Fine-tune started
# [2022-12-27 13:15:07] Completed epoch 1/1
# [2022-12-27 13:15:54] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-lr-2022-12-27-13-15-53
# [2022-12-27 13:15:55] Uploaded result file: file-3YXQ7RoarOeqVb4ljJP2rKWE
# [2022-12-27 13:15:55] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-lr-2022-12-27-13-15-53 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-cF72VjqoAdcWg1ZgHuc9JaNZ ...
# [2022-12-27 13:04:17] Created fine-tune: ft-cF72VjqoAdcWg1ZgHuc9JaNZ
# [2022-12-27 13:16:35] Fine-tune costs $2.31
# [2022-12-27 13:16:35] Fine-tune enqueued. Queue number: 0
# [2022-12-27 13:16:37] Fine-tune started
# [2022-12-27 13:20:32] Completed epoch 1/1
# [2022-12-27 13:21:13] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-lr-2022-12-27-13-21-13
# [2022-12-27 13:21:14] Uploaded result file: file-DMySrxoiLmUoV7u2UQsnT45W
# [2022-12-27 13:21:14] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-lr-2022-12-27-13-21-13 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-oy7nUTVNVQZ1j0RovxmXGKsP ...
# [2022-12-27 13:04:18] Created fine-tune: ft-oy7nUTVNVQZ1j0RovxmXGKsP
# [2022-12-27 13:21:31] Fine-tune costs $2.31
# [2022-12-27 13:21:32] Fine-tune enqueued. Queue number: 0
# [2022-12-27 13:21:34] Fine-tune started
# [2022-12-27 13:24:54] Completed epoch 1/1
# [2022-12-27 13:25:49] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-lr-2022-12-27-13-25-48
# [2022-12-27 13:25:50] Uploaded result file: file-LrH0Zej7ctxz01RbWuj1eMGy
# [2022-12-27 13:25:50] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-200-lr-2022-12-27-13-25-48 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-lPVOx8YvErpMqG40HcpOIvTD', 'ft-bDTCyBIreERL6FACL6WDwZr8', 'ft-cF72VjqoAdcWg1ZgHuc9JaNZ', 'ft-oy7nUTVNVQZ1j0RovxmXGKsP']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_132857-ft-lPVOx8YvErpMqG40HcpOIvTD</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-lPVOx8YvErpMqG40HcpOIvTD" target="_blank">ft-lPVOx8YvErpMqG40HcpOIvTD</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▁▅▄▃▅▂▇▃▇▆▃▆▆▂▃▇▄▅▂▆▅▄▃▆▃▁▄█▇▅▇▃▃▇▅▄▅▂▁▁</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>█▃▅▂▄▆▄▅▂▄▃▅▄▅▅▁▅▃▇▃▃▄▄▆▇▆▃▄▃▄▆▆▅▃▅▆▂▇▇▇</td></tr><tr><td>validation_loss</td><td>▄▅▂▇▄▅█▃▄▃▅▆▃▅▅▁▄▄▂▄▄▃▂▃▄▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>█▁▆▄▆▆▂▄▅█▆▂▄▆▃▇▅▂▇▃▇▄▄▆▆▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>202.0</td></tr><tr><td>elapsed_tokens</td><td>78594.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.14954</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.79412</td></tr><tr><td>validation_loss</td><td>0.17727</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.725</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-lPVOx8YvErpMqG40HcpOIvTD</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-lPVOx8YvErpMqG40HcpOIvTD" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-lPVOx8YvErpMqG40HcpOIvTD</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_132857-ft-lPVOx8YvErpMqG40HcpOIvTD/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_132906-ft-bDTCyBIreERL6FACL6WDwZr8</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-bDTCyBIreERL6FACL6WDwZr8" target="_blank">ft-bDTCyBIreERL6FACL6WDwZr8</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>█▅▅▅▄▅▄▆▄▂▃▆▂▅██▄▅▇▅▁▃▆▂▆▃▃▃▄▅▃▅▄▅▅▃▅▅▂▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▃▅▂▁▄▁▁▄▆▃▅▂█▄▂▃▃▅▄▄█▅▂▅▄▆▄▄▃▄▅▃▃▃▅▆▄▁▂▅</td></tr><tr><td>validation_loss</td><td>▅▃▂▂▂▃▃▄▂▁█▄▄█▃▂▃▂▅▄▆▁▄▂▄▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▆▅█▆█▂█▅▆▄▂▇▄▆▇▆▆▆▁▆▄▆▇▂▇▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>201.0</td></tr><tr><td>elapsed_tokens</td><td>78081.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.19611</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.68571</td></tr><tr><td>validation_loss</td><td>0.22999</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.56818</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-bDTCyBIreERL6FACL6WDwZr8</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-bDTCyBIreERL6FACL6WDwZr8" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-bDTCyBIreERL6FACL6WDwZr8</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_132906-ft-bDTCyBIreERL6FACL6WDwZr8/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_132916-ft-cF72VjqoAdcWg1ZgHuc9JaNZ</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-cF72VjqoAdcWg1ZgHuc9JaNZ" target="_blank">ft-cF72VjqoAdcWg1ZgHuc9JaNZ</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▃▄▅▅▃▄▂▇█▄█▄▃▂▅▂▂▄▁▆▄▅▃▂▂▁▅▂▃▅█▂▄▃▂▂▄▃▄▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▇▆▄▄▆▆▆▆▅▅▅▃▅▆▄█▅▄▁▃▆▁▆▇▄█▃▆▄▄▃▄▆▄▆█▅▇▅▆</td></tr><tr><td>validation_loss</td><td>▃▄▃▄▅▄▃▃▃▂▄▃█▃▁▃▃▃▆▃▃▄▁▂▆▄</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▄▅▄▃▃▄▅▅▄▆▅▁▁▃█▃▆▅▁▄█▂▆█▃▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>202.0</td></tr><tr><td>elapsed_tokens</td><td>78322.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.1832</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.73333</td></tr><tr><td>validation_loss</td><td>0.23117</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.52632</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-cF72VjqoAdcWg1ZgHuc9JaNZ</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-cF72VjqoAdcWg1ZgHuc9JaNZ" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-cF72VjqoAdcWg1ZgHuc9JaNZ</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_132916-ft-cF72VjqoAdcWg1ZgHuc9JaNZ/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_132925-ft-oy7nUTVNVQZ1j0RovxmXGKsP</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-oy7nUTVNVQZ1j0RovxmXGKsP" target="_blank">ft-oy7nUTVNVQZ1j0RovxmXGKsP</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▁▅▄▃▄▃▇▃▆▅▄▆▅▃▃▇▄▅▂▆▆▄▄▅▂▁▄█▇▄▇▃▃▇▅▄▅▁▁▁</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>█▂▅▃▃▆▄▅▃▅▃▃▅▄▅▃▂▂▆▂▃▄▄▆▆▇▃▂▃▃▆▆▆▃▆▇▁▇▆█</td></tr><tr><td>validation_loss</td><td>▄▄▃▆▃▅█▃▄▃▅▇▄▅▅▁▄▄▃▄▄▃▂▃▅▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▇▃█▅▆▆▃▄▄█▆▁▂▄▄█▄▁▇▃▆▃▄▅▆▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>202.0</td></tr><tr><td>elapsed_tokens</td><td>78594.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.12868</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.88235</td></tr><tr><td>validation_loss</td><td>0.1576</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.65</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-oy7nUTVNVQZ1j0RovxmXGKsP</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-oy7nUTVNVQZ1j0RovxmXGKsP" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-oy7nUTVNVQZ1j0RovxmXGKsP</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_132925-ft-oy7nUTVNVQZ1j0RovxmXGKsP/logs</code>

# %% [markdown]
# # Refinmenents Data Set size - 300

# %% [markdown]
# ## Epochs
#
# n_epochs=1,2,3,4
#
# Results:
#
# Epoch 1: 3.30
#
# Epoch 2: 3.52
#
# Epoch 3: 4.49
#
# Epoch 4: 6.59
#
# Best Epoch:

# %%
final_tag = "hp_tuning_refi_base_300_n_epochs"
parameter_combinations = {
                "n_epochs":[1,2,3,4], 
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/iterative_finetuning/baseline_refinement_dataset_round_2_300.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
dev_data = "summarization_finetuning_datasets/selected_refinement_finetuning_dataset_top_1_development_200.jsonl"
dev_data_id = upload_dataset_to_openai(dev_data)
print("Train dataset id {}".format(train_data_id))
print("Validation dataset id {}".format(dev_data_id))
# Out:
# Train dataset id file-HbtJxMykYTvJz8r3PRIYGMhM
# Validation dataset id file-tFLYaioVGvwXZQEsNF0cXVuP

# %%
train_data_id = "file-HbtJxMykYTvJz8r3PRIYGMhM"
dev_data_id = "file-tFLYaioVGvwXZQEsNF0cXVuP"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs(n_epochs=n_epochs, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-3Yr9977DJCGhJcATJjvpvBxO
# with n_epochs 1
#
#
#
# ['ft-3Yr9977DJCGhJcATJjvpvBxO']
# Initialized job ft-aIGwhqS7sH8Ri0TkdTXjWgf2
# with n_epochs 2
#
#
#
# ['ft-3Yr9977DJCGhJcATJjvpvBxO', 'ft-aIGwhqS7sH8Ri0TkdTXjWgf2']
# Initialized job ft-4LG61lIQukeUOGRLNMVUSmAE
# with n_epochs 3
#
#
#
# ['ft-3Yr9977DJCGhJcATJjvpvBxO', 'ft-aIGwhqS7sH8Ri0TkdTXjWgf2', 'ft-4LG61lIQukeUOGRLNMVUSmAE']
# Initialized job ft-PLyUSYVXnebmJ4RPPvfdiiKd
# with n_epochs 4
#
#
#
# ['ft-3Yr9977DJCGhJcATJjvpvBxO', 'ft-aIGwhqS7sH8Ri0TkdTXjWgf2', 'ft-4LG61lIQukeUOGRLNMVUSmAE', 'ft-PLyUSYVXnebmJ4RPPvfdiiKd']

# %%
# !openai api fine_tunes.get -i "ft-3Yr9977DJCGhJcATJjvpvBxO"

# %%
finetuning_ids_hp_tuning = ['ft-3Yr9977DJCGhJcATJjvpvBxO', 'ft-aIGwhqS7sH8Ri0TkdTXjWgf2', 'ft-4LG61lIQukeUOGRLNMVUSmAE', 'ft-PLyUSYVXnebmJ4RPPvfdiiKd']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-3Yr9977DJCGhJcATJjvpvBxO ...
# [2022-12-27 13:48:10] Created fine-tune: ft-3Yr9977DJCGhJcATJjvpvBxO
# [2022-12-27 13:49:27] Fine-tune costs $3.56
# [2022-12-27 13:49:28] Fine-tune enqueued. Queue number: 0
# [2022-12-27 13:49:30] Fine-tune started
# [2022-12-27 13:53:56] Completed epoch 1/1
# [2022-12-27 13:54:46] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-n-epochs-2022-12-27-13-54-45
# [2022-12-27 13:54:47] Uploaded result file: file-wS3w4t9CcZoayS3rcEYOHyzL
# [2022-12-27 13:54:47] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-n-epochs-2022-12-27-13-54-45 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-aIGwhqS7sH8Ri0TkdTXjWgf2 ...
# [2022-12-27 13:48:10] Created fine-tune: ft-aIGwhqS7sH8Ri0TkdTXjWgf2
# [2022-12-27 13:55:15] Fine-tune costs $7.12
# [2022-12-27 13:55:20] Fine-tune enqueued. Queue number: 0
# [2022-12-27 14:02:43] Fine-tune started
# [2022-12-27 14:07:06] Completed epoch 1/2
# [2022-12-27 14:10:01] Completed epoch 2/2
# [2022-12-27 14:10:52] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-n-epochs-2022-12-27-14-10-51
# [2022-12-27 14:10:53] Uploaded result file: file-sGl8c4dFBA3cJblPB9odRgCT
# [2022-12-27 14:10:53] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-n-epochs-2022-12-27-14-10-51 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-4LG61lIQukeUOGRLNMVUSmAE ...
# [2022-12-27 13:48:10] Created fine-tune: ft-4LG61lIQukeUOGRLNMVUSmAE
# [2022-12-27 14:11:17] Fine-tune costs $10.68
# [2022-12-27 14:11:18] Fine-tune enqueued. Queue number: 1
# [2022-12-27 14:17:18] Fine-tune is in the queue. Queue number: 0
# [2022-12-27 14:18:46] Fine-tune started
# [2022-12-27 14:23:07] Completed epoch 1/3
# [2022-12-27 14:26:03] Completed epoch 2/3
# [2022-12-27 14:28:55] Completed epoch 3/3
# [2022-12-27 14:29:38] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-n-epochs-2022-12-27-14-29-38
# [2022-12-27 14:29:39] Uploaded result file: file-SAEluRcXoIHiNxWG52Hxkqa9
# [2022-12-27 14:29:40] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-n-epochs-2022-12-27-14-29-38 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-PLyUSYVXnebmJ4RPPvfdiiKd ...
# [2022-12-27 13:48:10] Created fine-tune: ft-PLyUSYVXnebmJ4RPPvfdiiKd
# [2022-12-27 14:30:15] Fine-tune costs $14.25
# [2022-12-27 14:30:15] Fine-tune enqueued. Queue number: 1
# [2022-12-27 14:32:37] Fine-tune is in the queue. Queue number: 0
# [2022-12-27 14:32:49] Fine-tune started
# [2022-12-27 14:37:49] Completed epoch 1/4
# [2022-12-27 14:40:42] Completed epoch 2/4
# [2022-12-27 14:43:36] Completed epoch 3/4
# [2022-12-27 14:46:33] Completed epoch 4/4
# [2022-12-27 14:47:24] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-n-epochs-2022-12-27-14-47-24
# [2022-12-27 14:47:25] Uploaded result file: file-gQvEoSWcCy2PxYYP2f6kv1ap
# [2022-12-27 14:47:25] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-n-epochs-2022-12-27-14-47-24 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-3Yr9977DJCGhJcATJjvpvBxO', 'ft-aIGwhqS7sH8Ri0TkdTXjWgf2', 'ft-4LG61lIQukeUOGRLNMVUSmAE', 'ft-PLyUSYVXnebmJ4RPPvfdiiKd']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_145006-ft-3Yr9977DJCGhJcATJjvpvBxO</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-3Yr9977DJCGhJcATJjvpvBxO" target="_blank">ft-3Yr9977DJCGhJcATJjvpvBxO</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.973 MB of 0.973 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▂▃▃▃▃▂█▂▂▂▄▃▂▃▄▃▂▂▄▂▃▂▂▃▂▂▂▂▂▂▂▁▁▂▂▃▂▁▃▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▃▄▄▅▂▅▄▂▅▂▅▄▄▅▃▅▁▅▃▅▃▃▃▄▇▃▅▅▄▄▄▆█▅▆▅▄▆▅▆</td></tr><tr><td>validation_loss</td><td>▄▃▂▃▃▃▄▄▂▂▆▄▄▆▃▃▃▃▃▄▅▃▅▃▄▄█▂█▂▃▆▄▅▁▃▃▃</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▄▃▆▄▅▂▄▄▅▄▁▆▃▄▅▄▄▅▃▅▄▅▅▂▅▃▂▅▄▆▄▄▅▃█▄▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>301.0</td></tr><tr><td>elapsed_tokens</td><td>120109.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.12623</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.72414</td></tr><tr><td>validation_loss</td><td>0.10747</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.70732</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-3Yr9977DJCGhJcATJjvpvBxO</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-3Yr9977DJCGhJcATJjvpvBxO" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-3Yr9977DJCGhJcATJjvpvBxO</a><br/>Synced 4 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_145006-ft-3Yr9977DJCGhJcATJjvpvBxO/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_145019-ft-aIGwhqS7sH8Ri0TkdTXjWgf2</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-aIGwhqS7sH8Ri0TkdTXjWgf2" target="_blank">ft-aIGwhqS7sH8Ri0TkdTXjWgf2</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▃▃▃█▂▂▂▁▂▂▃▂▂▂▃▄▃▃▂▂▂▂▂▁▂▂▁▁▂▂▂▁▁▂▂▁▂▁▁▁</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▄▂▅▅▁▄█▁▅▂▃▇▅▃▂▃▃▅▅▇▇▅▆▄▆▇▄▇▅▅██▆▇▆▄██▅</td></tr><tr><td>validation_loss</td><td>▄▃▂▃▃▂▄▆▂▃▄▃▃▄██▃▄▁▃▂▃▃▄▄▄▄▃█▆▆▃▃▂▆▅▄▃▃▅</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▅▄▅▂▄▄▆▅▄▆▅▆▁▃▂▄▄▅█▆▅▄▂▄▃▃▄▆▃▃▃▆▅▅▅▅▃▆▅▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>601.0</td></tr><tr><td>elapsed_tokens</td><td>239969.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.0335</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.95556</td></tr><tr><td>validation_loss</td><td>0.17928</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.66667</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-aIGwhqS7sH8Ri0TkdTXjWgf2</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-aIGwhqS7sH8Ri0TkdTXjWgf2" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-aIGwhqS7sH8Ri0TkdTXjWgf2</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_145019-ft-aIGwhqS7sH8Ri0TkdTXjWgf2/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_145030-ft-4LG61lIQukeUOGRLNMVUSmAE</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-4LG61lIQukeUOGRLNMVUSmAE" target="_blank">ft-4LG61lIQukeUOGRLNMVUSmAE</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▃▃▄▄▂▄▃▃▂▃▄▃▅█▂▁▃▄▃▁▂▂▃▃▃▂▃▂▂▁▁▃▁▂▁▁▂▁▂▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▅▃▄▂▅▃▅▃▅▄▄▅▁▆▅▇▂▄▃▇▆▆▅▅▃▄▅▆▅▆█▅▆▆▇█▇▇▇▆</td></tr><tr><td>validation_loss</td><td>▃▁▃▂▅▃▂▃▁▁█▂▁▂▃▄▁▂▂▂▁▄▄▁▂▆▂▁▃▅▄▁▁▁▅▂▃▃▂▅</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>██▇▆▄▅▁▆▄▆▅▇▅▅▄▄▇▃▅▆▆▄▅▆▆▄▆▆▅▄▅▆▆▅▅▆▃▅▄▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>902.0</td></tr><tr><td>elapsed_tokens</td><td>360014.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.04112</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.83333</td></tr><tr><td>validation_loss</td><td>0.23625</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.53846</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-4LG61lIQukeUOGRLNMVUSmAE</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-4LG61lIQukeUOGRLNMVUSmAE" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-4LG61lIQukeUOGRLNMVUSmAE</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_145030-ft-4LG61lIQukeUOGRLNMVUSmAE/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_145042-ft-PLyUSYVXnebmJ4RPPvfdiiKd</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-PLyUSYVXnebmJ4RPPvfdiiKd" target="_blank">ft-PLyUSYVXnebmJ4RPPvfdiiKd</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▄▄▃▂▃▃▃▂▃▄█▂▃▂▃▁▃▃▂▂▂▂▂▁▁▁▂▁▁▂▁▁▁▁▁▁▁▁▁▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁█▁▁█▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▃▃▅▅▄▄▁▃▅▃▆▅▃▂▄▆▆▄▅▅▆▆▅▆▆▆▇▇▇▆█▇██▇████▅</td></tr><tr><td>validation_loss</td><td>▃▄▂▅▁▃▃▃▃▂▂▃▂▃▂▂▃▃▄▃▅▄▄▃▂▃▄▃▂▂▃▃▃▂▄▄█▄▆▃</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▃▅▅▃▇▅▆▄▆█▅▅▆▁▆▆▅▄▃▆▄▆▄▅▅▄▅▃▅▆▆▆▃▅▁▃▄▅▅▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>1201.0</td></tr><tr><td>elapsed_tokens</td><td>479665.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.0272</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.96667</td></tr><tr><td>validation_loss</td><td>0.1495</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.61111</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-PLyUSYVXnebmJ4RPPvfdiiKd</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-PLyUSYVXnebmJ4RPPvfdiiKd" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-PLyUSYVXnebmJ4RPPvfdiiKd</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_145042-ft-PLyUSYVXnebmJ4RPPvfdiiKd/logs</code>

# %% [markdown]
# ## Prompt Loss Weight
# **Sweep**:
#
# n_epochs=1
#
# prompt_loss_weight = 0, 0.01, 0.05, 0.1
#
# **Results:**
#
#
# *   prompt_loss_weight 0 = 3.29
# *   prompt_loss_weight 0.01 = 3.30
# *   prompt_loss_weight 0.05 = 3.30
# *   prompt_loss_weight 0.1 = 3.31
#
# best promtp loss weight = 0

# %%
final_tag = "hp_tuning_refi_base_300_prompt_l_weight"
parameter_combinations = {
                "n_epochs":[1],
                "prompt_loss_weight": [0, 0.01, 0.05, 0.1]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
train_data_id = "file-HbtJxMykYTvJz8r3PRIYGMhM"
dev_data_id = "file-tFLYaioVGvwXZQEsNF0cXVuP"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-KDZYOYLS8j3scHJS7tFYfTCS
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-KDZYOYLS8j3scHJS7tFYfTCS']
# Initialized job ft-1iskuMsG69ljejKZ03WkDUZv
# with n_epochs 1
# with prompt_loss_weight:  0.01
#
#
#
# ['ft-KDZYOYLS8j3scHJS7tFYfTCS', 'ft-1iskuMsG69ljejKZ03WkDUZv']
# Initialized job ft-aXv15LtWFBBoDbxmiCboZVwS
# with n_epochs 1
# with prompt_loss_weight:  0.05
#
#
#
# ['ft-KDZYOYLS8j3scHJS7tFYfTCS', 'ft-1iskuMsG69ljejKZ03WkDUZv', 'ft-aXv15LtWFBBoDbxmiCboZVwS']
# Initialized job ft-lfwcGtpLsFR6kTukLfb1sgoz
# with n_epochs 1
# with prompt_loss_weight:  0.1
#
#
#
# ['ft-KDZYOYLS8j3scHJS7tFYfTCS', 'ft-1iskuMsG69ljejKZ03WkDUZv', 'ft-aXv15LtWFBBoDbxmiCboZVwS', 'ft-lfwcGtpLsFR6kTukLfb1sgoz']

# %%
# !openai api fine_tunes.get -i "ft-yb3GdQudccplAAtWo10Mwi0w"

# %%
finetuning_ids_hp_tuning = ['ft-KDZYOYLS8j3scHJS7tFYfTCS', 'ft-1iskuMsG69ljejKZ03WkDUZv', 'ft-aXv15LtWFBBoDbxmiCboZVwS', 'ft-lfwcGtpLsFR6kTukLfb1sgoz']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-KDZYOYLS8j3scHJS7tFYfTCS ...
# [2022-12-27 15:27:41] Created fine-tune: ft-KDZYOYLS8j3scHJS7tFYfTCS
# [2022-12-27 15:28:39] Fine-tune costs $3.56
# [2022-12-27 15:28:39] Fine-tune enqueued. Queue number: 0
# [2022-12-27 15:28:43] Fine-tune started
# [2022-12-27 15:33:12] Completed epoch 1/1
# [2022-12-27 15:33:49] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-prompt-l-weight-2022-12-27-15-33-49
# [2022-12-27 15:33:50] Uploaded result file: file-qUftVMQZ3izAW4uyJOlBxEvE
# [2022-12-27 15:33:50] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-prompt-l-weight-2022-12-27-15-33-49 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-1iskuMsG69ljejKZ03WkDUZv ...
# [2022-12-27 15:27:41] Created fine-tune: ft-1iskuMsG69ljejKZ03WkDUZv
# [2022-12-27 15:34:26] Fine-tune costs $3.56
# [2022-12-27 15:34:26] Fine-tune enqueued. Queue number: 0
# [2022-12-27 15:34:28] Fine-tune started
# [2022-12-27 15:38:50] Completed epoch 1/1
# [2022-12-27 15:39:35] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-prompt-l-weight-2022-12-27-15-39-34
# [2022-12-27 15:39:36] Uploaded result file: file-VU8kmy47NC24869ismhkyT9c
# [2022-12-27 15:39:36] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-prompt-l-weight-2022-12-27-15-39-34 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-aXv15LtWFBBoDbxmiCboZVwS ...
# [2022-12-27 15:27:41] Created fine-tune: ft-aXv15LtWFBBoDbxmiCboZVwS
# [2022-12-27 15:40:11] Fine-tune costs $3.56
# [2022-12-27 15:40:12] Fine-tune enqueued. Queue number: 0
# [2022-12-27 15:40:15] Fine-tune started
# [2022-12-27 15:44:35] Completed epoch 1/1
# [2022-12-27 15:45:22] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-prompt-l-weight-2022-12-27-15-45-21
# [2022-12-27 15:45:24] Uploaded result file: file-VzvZ6q3FAQUmjfntQIXW36pS
# [2022-12-27 15:45:24] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-prompt-l-weight-2022-12-27-15-45-21 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-lfwcGtpLsFR6kTukLfb1sgoz ...
# [2022-12-27 15:27:41] Created fine-tune: ft-lfwcGtpLsFR6kTukLfb1sgoz
# [2022-12-27 15:45:59] Fine-tune costs $3.56
# [2022-12-27 15:45:59] Fine-tune enqueued. Queue number: 0
# [2022-12-27 15:46:02] Fine-tune started
# [2022-12-27 15:50:26] Completed epoch 1/1
# [2022-12-27 15:51:08] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-prompt-l-weight-2022-12-27-15-51-08
# [2022-12-27 15:51:09] Uploaded result file: file-HTQw9STos5r0DSEX4nDl2tHD
# [2022-12-27 15:51:09] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-prompt-l-weight-2022-12-27-15-51-08 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-KDZYOYLS8j3scHJS7tFYfTCS', 'ft-1iskuMsG69ljejKZ03WkDUZv', 'ft-aXv15LtWFBBoDbxmiCboZVwS', 'ft-lfwcGtpLsFR6kTukLfb1sgoz']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_155953-ft-KDZYOYLS8j3scHJS7tFYfTCS</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-KDZYOYLS8j3scHJS7tFYfTCS" target="_blank">ft-KDZYOYLS8j3scHJS7tFYfTCS</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▂▂▁▁▂▂▂▂▂▂▂▂▂▅▃▃▁▃▂▂▂▂▂▂▂▃▂▁▁▄▃▃▃▃█▁▁▆▃▁</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▃▅▄▆▄▄▄▄▅▆▆▆▄▂▅▂▇▃▄▃▅▅▄▃█▂▂▅█▄▄▅▂▄▅▅▆▁▃▄</td></tr><tr><td>validation_loss</td><td>▆▆▆▅▄▅▁█▂▄▇▄▄▃▇▂▄▅▆▄▅▂▃▂▂▄▃█▅▆▃▄▃▇▅▄▄▇</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▅▄▅▇▆▄▇▁█▅▄▅▅▅▅▆▅▅▆▅▄▇▆▇▄▄▆▄▃▆▅▆▄▅▄▄▆▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>301.0</td></tr><tr><td>elapsed_tokens</td><td>120141.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.1683</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.6087</td></tr><tr><td>validation_loss</td><td>0.18065</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.625</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-KDZYOYLS8j3scHJS7tFYfTCS</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-KDZYOYLS8j3scHJS7tFYfTCS" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-KDZYOYLS8j3scHJS7tFYfTCS</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_155953-ft-KDZYOYLS8j3scHJS7tFYfTCS/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_160005-ft-1iskuMsG69ljejKZ03WkDUZv</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-1iskuMsG69ljejKZ03WkDUZv" target="_blank">ft-1iskuMsG69ljejKZ03WkDUZv</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▂▂▂▁▂▂▂▂▂▂▂▂▂▅▃▃▁▃▂▂▂▂▂▂▂▃▂▁▁▃▃▃▂▂█▂▁▆▃▁</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▃▆▃▆▄▅▅▄▅▅▆▇▄▃▅▃▆▃▄▃▅▅▄▃█▂▂▆█▅▅▅▃▃▄▄▅▁▃▄</td></tr><tr><td>validation_loss</td><td>▆▆▆▅▄▅▁█▂▄▇▄▄▃▇▂▄▅▆▄▆▂▃▂▃▄▄█▅▆▃▄▃█▅▄▄█</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▅▄▅▇▆▄▇▁█▅▄▅▅▅▅▆▅▄▆▅▄▇▆▇▄▄▆▄▃▆▅▆▄▄▄▄▅▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>301.0</td></tr><tr><td>elapsed_tokens</td><td>120141.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.18871</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.6087</td></tr><tr><td>validation_loss</td><td>0.20343</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.6</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-1iskuMsG69ljejKZ03WkDUZv</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-1iskuMsG69ljejKZ03WkDUZv" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-1iskuMsG69ljejKZ03WkDUZv</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_160005-ft-1iskuMsG69ljejKZ03WkDUZv/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_160019-ft-aXv15LtWFBBoDbxmiCboZVwS</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-aXv15LtWFBBoDbxmiCboZVwS" target="_blank">ft-aXv15LtWFBBoDbxmiCboZVwS</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▂▂▂▂▃▂▃▂▂▂▂▂▂▅▃▃▂▃▂▂▂▂▂▂▁▃▂▁▁▄▃▃▃▃█▂▁▆▃▁</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▆▄▆▄▅▅▅▅▅▅▇▅▄▅▃▇▄▄▄▆▅▆▅█▃▃▆█▅▅▅▃▅▄▅▆▁▅▄</td></tr><tr><td>validation_loss</td><td>▆▇▆▅▄▆▁█▂▅▇▃▄▃▇▂▅▅▆▃▆▂▃▂▄▄▄█▅▅▃▄▄█▇▅▅█</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▅▄▆█▆▄▆▁█▅▄▅▅▄▆▆▅▅▆▅▄▇▆▇▄▅▆▄▃▇▅▆▄▄▄▄▆▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>301.0</td></tr><tr><td>elapsed_tokens</td><td>120141.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.25935</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.6087</td></tr><tr><td>validation_loss</td><td>0.28474</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.65</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-aXv15LtWFBBoDbxmiCboZVwS</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-aXv15LtWFBBoDbxmiCboZVwS" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-aXv15LtWFBBoDbxmiCboZVwS</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_160019-ft-aXv15LtWFBBoDbxmiCboZVwS/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221227_160029-ft-lfwcGtpLsFR6kTukLfb1sgoz</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-lfwcGtpLsFR6kTukLfb1sgoz" target="_blank">ft-lfwcGtpLsFR6kTukLfb1sgoz</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▂▃▅▃▃▃█▂▂▂▄▃▂▃▄▂▃▂▄▂▂▃▂▃▂▂▃▂▃▂▂▁▁▁▂▃▃▁▃▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▄▄▄▃▅▄▁▆▄▅▄▅▆▃▄▂▅▄▆▄▃▄▅▆▄▇▆▄▄▅▆█▆▇▄▄▇▆▇</td></tr><tr><td>validation_loss</td><td>▅▃▂▂▃▄▃▄▃▂▇▃▄▅▃▃▃▂▄▄▄▂▃▃▄▄▇▂█▁▃▆▃▆▁▂▂▃</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▄▃▅▄▆▂▃▄▄▂▁▆▄▅▅▄▃▅▁▅▃▅▅▁▆▃▂▅▄▆▄▃▅▃█▄▅▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>301.0</td></tr><tr><td>elapsed_tokens</td><td>120109.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.33381</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.68966</td></tr><tr><td>validation_loss</td><td>0.29458</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.68293</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-lfwcGtpLsFR6kTukLfb1sgoz</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-lfwcGtpLsFR6kTukLfb1sgoz" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-lfwcGtpLsFR6kTukLfb1sgoz</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221227_160029-ft-lfwcGtpLsFR6kTukLfb1sgoz/logs</code>

# %% [markdown]
# ## Learning rate Multiplier
#
# n_epochs=1
#
# prompt_loss_weight = 0.0
#
# learning_rate_multiplier = 0.02, 0.05, 0.1, or 0.2
#
# **Results**:
#
# *   learning_rate_multiplier 0.02: 3.44
# *   learning_rate_multiplier 0.05: 3.29
# *   learning_rate_multiplier 0.1: 3.28
# *   learning_rate_multiplier 0.2: 3.27
#
# **Best lr**: 0.2

# %%
final_tag = "hp_tuning_refi_base_300_lr"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0],
                "learning_rate_multiplier": [0.02, 0.05, 0.1, 0.2]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
train_data_id = "file-HbtJxMykYTvJz8r3PRIYGMhM"
dev_data_id = "file-tFLYaioVGvwXZQEsNF0cXVuP"

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_with_n_epochs_and_prompt_loss_weight_and_lr(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, validation_dataset_id=dev_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-RtlsuwMTZCk9HqbBap0WZP0O
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-RtlsuwMTZCk9HqbBap0WZP0O']
# Initialized job ft-iMb8qBqQbS5v4W9uh7qXDTA6
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-RtlsuwMTZCk9HqbBap0WZP0O', 'ft-iMb8qBqQbS5v4W9uh7qXDTA6']
# Initialized job ft-gqwIDVBBzoYZdL7qbM3dZI9W
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-RtlsuwMTZCk9HqbBap0WZP0O', 'ft-iMb8qBqQbS5v4W9uh7qXDTA6', 'ft-gqwIDVBBzoYZdL7qbM3dZI9W']
# Initialized job ft-HnvIPz8jIoGjKXOFE1WHGz1d
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-RtlsuwMTZCk9HqbBap0WZP0O', 'ft-iMb8qBqQbS5v4W9uh7qXDTA6', 'ft-gqwIDVBBzoYZdL7qbM3dZI9W', 'ft-HnvIPz8jIoGjKXOFE1WHGz1d']

# %%
# !openai api fine_tunes.get -i "ft-RtlsuwMTZCk9HqbBap0WZP0O"
# Out:
# {
#   "created_at": 1672221787,
#   "events": [
#     {
#       "created_at": 1672221787,
#       "level": "info",
#       "message": "Created fine-tune: ft-RtlsuwMTZCk9HqbBap0WZP0O",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": null,
#     "learning_rate_multiplier": 0.02,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.0
#   },
#   "id": "ft-RtlsuwMTZCk9HqbBap0WZP0O",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 512092,
#       "created_at": 1672148871,
#       "filename": "file",
#       "id": "file-HbtJxMykYTvJz8r3PRIYGMhM",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1672221787,
#   "validation_files": [
#     {
#       "bytes": 332653,
#       "created_at": 1672148872,
#       "filename": "file",
#       "id": "file-tFLYaioVGvwXZQEsNF0cXVuP",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ]
# }

# %%
finetuning_ids_hp_tuning = ['ft-RtlsuwMTZCk9HqbBap0WZP0O', 'ft-iMb8qBqQbS5v4W9uh7qXDTA6', 'ft-gqwIDVBBzoYZdL7qbM3dZI9W', 'ft-HnvIPz8jIoGjKXOFE1WHGz1d']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-RtlsuwMTZCk9HqbBap0WZP0O ...
# [2022-12-28 10:03:07] Created fine-tune: ft-RtlsuwMTZCk9HqbBap0WZP0O
# [2022-12-28 10:04:29] Fine-tune costs $3.56
# [2022-12-28 10:04:30] Fine-tune enqueued. Queue number: 0
# [2022-12-28 10:04:32] Fine-tune started
# [2022-12-28 10:09:37] Completed epoch 1/1
# [2022-12-28 10:10:21] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-lr-2022-12-28-10-10-19
# [2022-12-28 10:10:24] Uploaded result file: file-A8CVBua90XadiMusi2mAs49P
# [2022-12-28 10:10:24] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-lr-2022-12-28-10-10-19 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-iMb8qBqQbS5v4W9uh7qXDTA6 ...
# [2022-12-28 10:03:07] Created fine-tune: ft-iMb8qBqQbS5v4W9uh7qXDTA6
# [2022-12-28 10:10:59] Fine-tune costs $3.56
# [2022-12-28 10:10:59] Fine-tune enqueued. Queue number: 0
# [2022-12-28 10:11:02] Fine-tune started
# [2022-12-28 10:15:28] Completed epoch 1/1
# [2022-12-28 10:16:08] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-lr-2022-12-28-10-16-07
# [2022-12-28 10:16:10] Uploaded result file: file-qxI591pGrAbyGm5YPMLdDE0W
# [2022-12-28 10:16:10] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-lr-2022-12-28-10-16-07 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-gqwIDVBBzoYZdL7qbM3dZI9W ...
# [2022-12-28 10:03:07] Created fine-tune: ft-gqwIDVBBzoYZdL7qbM3dZI9W
# [2022-12-28 10:16:49] Fine-tune costs $3.56
# [2022-12-28 10:16:49] Fine-tune enqueued. Queue number: 0
# [2022-12-28 10:16:54] Fine-tune started
# [2022-12-28 10:21:18] Completed epoch 1/1
# [2022-12-28 10:22:20] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-lr-2022-12-28-10-22-19
# [2022-12-28 10:22:21] Uploaded result file: file-OVtD8no39pPE0Dv83ipSPqlB
# [2022-12-28 10:22:21] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-lr-2022-12-28-10-22-19 -p <YOUR_PROMPT>
#
#
#
# Monitoring ft-HnvIPz8jIoGjKXOFE1WHGz1d ...
# [2022-12-28 10:03:07] Created fine-tune: ft-HnvIPz8jIoGjKXOFE1WHGz1d
# [2022-12-28 10:22:36] Fine-tune costs $3.56
# [2022-12-28 10:22:36] Fine-tune enqueued. Queue number: 0
# [2022-12-28 10:22:37] Fine-tune started
# [2022-12-28 10:26:57] Completed epoch 1/1
# [2022-12-28 10:27:43] Uploaded model: davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-lr-2022-12-28-10-27-42
# [2022-12-28 10:27:44] Uploaded result file: file-sdQ5MlI4Sw1yOmz4CfaQFqOJ
# [2022-12-28 10:27:44] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:hp-tuning-refi-base-300-lr-2022-12-28-10-27-42 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-RtlsuwMTZCk9HqbBap0WZP0O', 'ft-iMb8qBqQbS5v4W9uh7qXDTA6', 'ft-gqwIDVBBzoYZdL7qbM3dZI9W', 'ft-HnvIPz8jIoGjKXOFE1WHGz1d']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221228_102851-ft-RtlsuwMTZCk9HqbBap0WZP0O</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-RtlsuwMTZCk9HqbBap0WZP0O" target="_blank">ft-RtlsuwMTZCk9HqbBap0WZP0O</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▅▃▃█▄▄▃▄▂▂▆▂▁▃▄▃▅▂▂▃▂▃▅▄▂▃▂▁▁▃▂▃▂▂▅▂▂▃▄▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▆▅▅▁▄▁▇▄▅▂▅▂▇▄▃▅▄▅▅▃▅▄▃▄█▄▅█▅▃▅▄▅▆▃▇▇▃▅▅</td></tr><tr><td>validation_loss</td><td>▃▄█▂▅▂▁▆▅▅▂▃▃▃▂▃▃▂▂▃▄▆▁▂▄▂▆▃▁▁▃▅▃▁▅▄▂▃</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▄▂▆█▅▆▄▆▃▆▆▅▄▁▇▅▇▅▆▇▇▄▅▆▂▅▆▇█▇▃▇▅▇▅▅██</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>301.0</td></tr><tr><td>elapsed_tokens</td><td>120365.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.07894</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.69565</td></tr><tr><td>validation_loss</td><td>0.11927</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.74359</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-RtlsuwMTZCk9HqbBap0WZP0O</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-RtlsuwMTZCk9HqbBap0WZP0O" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-RtlsuwMTZCk9HqbBap0WZP0O</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221228_102851-ft-RtlsuwMTZCk9HqbBap0WZP0O/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221228_102900-ft-iMb8qBqQbS5v4W9uh7qXDTA6</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-iMb8qBqQbS5v4W9uh7qXDTA6" target="_blank">ft-iMb8qBqQbS5v4W9uh7qXDTA6</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▇▄▄▆▄▄▆▃▅▇▅▃▆▅▃█▅▁▆▂▄▃▄▄▃▄▅▅▆▃▄▇▃▃▆▄▆▃▃▄</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▃▃▅▃▁▅▄▃▄▃▃▅▃▅▄▃▆█▄▄▃▄▆▅▅▂▅▅▂▄▄▄▁▆▃▆▄▅▅▅</td></tr><tr><td>validation_loss</td><td>▃▃▄█▃▅▃▂▃▂▂▄▃▂▂▂▄▅▂▄▂▂▃▃▃▃▄▂▂▂▂▂▃▁▅▁▂▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▃▂▄▂▅▃▁▁▆▅▆▄▆▄▂▄▁▅▅▆▆▅▄▄▄▃▅▄▃▆▆▃▁▂▃█▅▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>301.0</td></tr><tr><td>elapsed_tokens</td><td>120285.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.0623</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.73529</td></tr><tr><td>validation_loss</td><td>0.06848</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.76316</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-iMb8qBqQbS5v4W9uh7qXDTA6</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-iMb8qBqQbS5v4W9uh7qXDTA6" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-iMb8qBqQbS5v4W9uh7qXDTA6</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221228_102900-ft-iMb8qBqQbS5v4W9uh7qXDTA6/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221228_102910-ft-gqwIDVBBzoYZdL7qbM3dZI9W</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-gqwIDVBBzoYZdL7qbM3dZI9W" target="_blank">ft-gqwIDVBBzoYZdL7qbM3dZI9W</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▆▄▄▆▄▃▅▃▅▇▅▃▆▅▃█▅▁▆▂▄▃▄▄▃▃▅▅▆▃▄▇▃▃▆▄▆▃▃▄</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▃▄▄▂▁▆▄▃▄▃▄▅▃▅▄▃▆█▅▄▃▃▆▃▅▂▅▅▁▄▄▅▂▆▃▆▄▆▅▄</td></tr><tr><td>validation_loss</td><td>▄▃▄█▃▅▃▂▃▂▂▄▄▂▂▃▄▅▂▄▂▃▃▃▄▃▅▂▂▃▂▂▃▂▅▁▂▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▄▃▃▂▆▃▂▁▅▆▆▄▅▄▄▃▁▇▅▆▇▆▄▄▄▄▅▂▄▆▇▂▁▂▃█▆▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>301.0</td></tr><tr><td>elapsed_tokens</td><td>120285.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.0542</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.79412</td></tr><tr><td>validation_loss</td><td>0.06608</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.73684</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-gqwIDVBBzoYZdL7qbM3dZI9W</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-gqwIDVBBzoYZdL7qbM3dZI9W" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-gqwIDVBBzoYZdL7qbM3dZI9W</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221228_102910-ft-gqwIDVBBzoYZdL7qbM3dZI9W/logs</code>
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221228_102920-ft-HnvIPz8jIoGjKXOFE1WHGz1d</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-HnvIPz8jIoGjKXOFE1WHGz1d" target="_blank">ft-HnvIPz8jIoGjKXOFE1WHGz1d</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▆▃▃▆▅▄▆▃▅▆▆▃▅▄▃█▅▁▇▂▄▃▄▅▃▃▅▅▆▃▄▇▂▃▆▄▆▃▃▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▅▆▅▄▁▆▅▄▆▅▅▆▅▆▆▄▇█▅▅▄▅▆▅▆▄▅▆▃▆▄▆▃▇▄▇▅▆▇▆</td></tr><tr><td>validation_loss</td><td>▄▄▄█▃▅▄▂▃▂▂▅▄▂▂▃▄▅▃▄▂▃▄▃▃▃▅▂▂▃▂▃▃▂▅▁▂▂</td></tr><tr><td>validation_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>validation_token_accuracy</td><td>▄▂▄▂▆▃▁▁▅█▇▄▆▄▄▃▁▆▅▅▇▆▅▃▄▅▅▄▄▆▆▁▂▄▃█▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>301.0</td></tr><tr><td>elapsed_tokens</td><td>120285.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.04613</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.82353</td></tr><tr><td>validation_loss</td><td>0.06075</td></tr><tr><td>validation_sequence_accuracy</td><td>0.0</td></tr><tr><td>validation_token_accuracy</td><td>0.84211</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-HnvIPz8jIoGjKXOFE1WHGz1d</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-HnvIPz8jIoGjKXOFE1WHGz1d" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-HnvIPz8jIoGjKXOFE1WHGz1d</a><br/>Synced 4 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221228_102920-ft-HnvIPz8jIoGjKXOFE1WHGz1d/logs</code>

# %% [markdown]
# # Iterative Finetuning

# %% [markdown]
# ## Further finetuning

# %% [markdown]
# ### Further finetunne on baseline refinements with 100 samples
#
# Went back to dez 17 of history and recreated the following cells

# %% [markdown]
# #### Round 1

# %%
final_tag = "finetuning_refinements_baseline_round_1"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0],
                "learning_rate_multiplier": [0.05],
                "model_name": ["davinci:ft-academicsnyuperez:final-run-100-refinements-2022-12-11-15-49-34"]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)
sweep_parameters
# Out:
# [{'n_epochs': 1,
#   'prompt_loss_weight': 0,
#   'learning_rate_multiplier': 0.05,
#   'model_name': 'davinci:ft-academicsnyuperez:final-run-100-refinements-2022-12-11-15-49-34'}]

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/iterative_finetuning/baseline_refinement_dataset_round_1.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
print("Train dataset id {}".format(train_data_id))
# Out:
# Train dataset id file-jfmpZzehIrs1ECrb8qryJwrJ

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  model_name = parameter["model_name"]
  print(model_name)
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_from_model(model_name=model_name, n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# davinci:ft-academicsnyuperez:final-run-100-refinements-2022-12-11-15-49-34
# Initialized job ft-3Wbo36LnWV9SctWn92xtKz3w
# with n_epochs 1
# with prompt_loss_weight:  0
# davinci:ft-academicsnyuperez:final-run-100-refinements-2022-12-11-15-49-34
# 0.05
#
#
#
# ['ft-3Wbo36LnWV9SctWn92xtKz3w']

# %%
# !openai api fine_tunes.get -i "ft-3Wbo36LnWV9SctWn92xtKz3w"
# Out:
# {
#   "created_at": 1671268826,
#   "events": [
#     {
#       "created_at": 1671268826,
#       "level": "info",
#       "message": "Created fine-tune: ft-3Wbo36LnWV9SctWn92xtKz3w",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1671268828,
#       "level": "info",
#       "message": "Fine-tune costs $1.17",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1671268828,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 0",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1671268831,
#       "level": "info",
#       "message": "Fine-tune started",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1671268970,
#       "level": "info",
#       "message": "Completed epoch 1/1",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1671269005,
#       "level": "info",
#       "message": "Uploaded model: davinci:ft-academicsnyuperez:finetuning-refinements-baseline-round-1-2022-12-17-09-23-25",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1671269006,
#       "level": "info",
#       "message": "Uploaded result file: file-6IlmrPVNwMXrx3taxHStsULe",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1671269006,
#       "level": "info",
#       "message": "Fine-tune succeeded",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": "davinci:ft-academicsnyuperez:finetuning-refinements-baseline-round-1-2022-12-17-09-23-25",
#   "hyperparams": {
#     "batch_size": 1,
#     "learning_rate_multiplier": 0.05,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.0
#   },
#   "id": "ft-3Wbo36LnWV9SctWn92xtKz3w",
#   "model": "davinci:ft-academicsnyuperez:final-run-100-refinements-2022-12-11-15-49-34",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [
#     {
#       "bytes": 5464,
#       "created_at": 1671269006,
#       "filename": "compiled_results.csv",
#       "id": "file-6IlmrPVNwMXrx3taxHStsULe",
#       "object": "file",
#       "purpose": "fine-tune-results",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "status": "succeeded",
#   "training_files": [
#     {
#       "bytes": 166428,
#       "created_at": 1671268825,
#       "filename": "file",
#       "id": "file-jfmpZzehIrs1ECrb8qryJwrJ",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1671269006,
#   "validation_files": []
# }

# %%
finetuning_ids_hp_tuning = ['ft-3Wbo36LnWV9SctWn92xtKz3w']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-3Wbo36LnWV9SctWn92xtKz3w ...
# [2022-12-17 09:20:26] Created fine-tune: ft-3Wbo36LnWV9SctWn92xtKz3w
# [2022-12-17 09:20:28] Fine-tune costs $1.17
# [2022-12-17 09:20:28] Fine-tune enqueued. Queue number: 0
# [2022-12-17 09:20:31] Fine-tune started
# [2022-12-17 09:22:50] Completed epoch 1/1
# [2022-12-17 09:23:25] Uploaded model: davinci:ft-academicsnyuperez:finetuning-refinements-baseline-round-1-2022-12-17-09-23-25
# [2022-12-17 09:23:26] Uploaded result file: file-6IlmrPVNwMXrx3taxHStsULe
# [2022-12-17 09:23:26] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:finetuning-refinements-baseline-round-1-2022-12-17-09-23-25 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-3Wbo36LnWV9SctWn92xtKz3w']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221217_092516-ft-3Wbo36LnWV9SctWn92xtKz3w</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-3Wbo36LnWV9SctWn92xtKz3w" target="_blank">ft-3Wbo36LnWV9SctWn92xtKz3w</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.317 MB of 0.317 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▂▂▃▁▂▃▁▄▂▂▃▂▂▂▂▂▂▁▃█▃▂▂▂▃▂▂▂▁▁▄▂▁▂▁▂▁▂▁▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▃▁▃▂▃▃▇▃▂▃▂▁▅▁▂▄▄▄▁▅▁▁▄▄▃▃▄▅▅▅▂▂█▄▆▂▁▄▆▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>102.0</td></tr><tr><td>elapsed_tokens</td><td>39782.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.11121</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.75</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-3Wbo36LnWV9SctWn92xtKz3w</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-3Wbo36LnWV9SctWn92xtKz3w" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-3Wbo36LnWV9SctWn92xtKz3w</a><br/>Synced 4 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221217_092516-ft-3Wbo36LnWV9SctWn92xtKz3w/logs</code>

# %% [markdown]
# #### Round 2

# %%
final_tag = "finetuning_refinements_baseline_round_2"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0],
                "learning_rate_multiplier": [0.05],
                "model_name": ["davinci:ft-academicsnyuperez:finetuning-refinements-baseline-round-1-2022-12-17-09-23-25"]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)
sweep_parameters
# Out:
# [{'n_epochs': 1,
#   'prompt_loss_weight': 0,
#   'learning_rate_multiplier': 0.05,
#   'model_name': 'davinci:ft-academicsnyuperez:finetuning-refinements-baseline-round-1-2022-12-17-09-23-25'}]

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/iterative_finetuning/baseline_refinement_dataset_round_2.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
print("Train dataset id {}".format(train_data_id))
# Out:
# Train dataset id file-YpqtBbM0kegi8uO5TnMJ9kX0

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  model_name = parameter["model_name"]
  print(model_name)
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_from_model(model_name=model_name, n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# davinci:ft-academicsnyuperez:finetuning-refinements-baseline-round-1-2022-12-17-09-23-25
# Initialized job ft-jyWTPlBmZlhktoPkve0ya2i2
# with n_epochs 1
# with prompt_loss_weight:  0
# davinci:ft-academicsnyuperez:finetuning-refinements-baseline-round-1-2022-12-17-09-23-25
# 0.05
#
#
#
# ['ft-jyWTPlBmZlhktoPkve0ya2i2']

# %%
# !openai api fine_tunes.get -i "ft-jyWTPlBmZlhktoPkve0ya2i2"
# Out:
# {
#   "created_at": 1671269171,
#   "events": [
#     {
#       "created_at": 1671269171,
#       "level": "info",
#       "message": "Created fine-tune: ft-jyWTPlBmZlhktoPkve0ya2i2",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1671269179,
#       "level": "info",
#       "message": "Fine-tune costs $1.25",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": null,
#     "learning_rate_multiplier": 0.05,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.0
#   },
#   "id": "ft-jyWTPlBmZlhktoPkve0ya2i2",
#   "model": "davinci:ft-academicsnyuperez:finetuning-refinements-baseline-round-1-2022-12-17-09-23-25",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 181217,
#       "created_at": 1671269170,
#       "filename": "file",
#       "id": "file-YpqtBbM0kegi8uO5TnMJ9kX0",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1671269179,
#   "validation_files": []
# }

# %%
finetuning_ids_hp_tuning = ['ft-jyWTPlBmZlhktoPkve0ya2i2']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-jyWTPlBmZlhktoPkve0ya2i2 ...
# [2022-12-17 09:26:11] Created fine-tune: ft-jyWTPlBmZlhktoPkve0ya2i2
# [2022-12-17 09:26:19] Fine-tune costs $1.25
# [2022-12-17 09:26:19] Fine-tune enqueued. Queue number: 0
# [2022-12-17 09:26:21] Fine-tune started
# [2022-12-17 09:29:08] Completed epoch 1/1
# [2022-12-17 09:29:47] Uploaded model: davinci:ft-academicsnyuperez:finetuning-refinements-baseline-round-2-2022-12-17-09-29-46
# [2022-12-17 09:29:48] Uploaded result file: file-UoqOA1hC3YqaBt0O2yO5Mh5L
# [2022-12-17 09:29:48] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:finetuning-refinements-baseline-round-2-2022-12-17-09-29-46 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-jyWTPlBmZlhktoPkve0ya2i2']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221217_094116-ft-jyWTPlBmZlhktoPkve0ya2i2</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-jyWTPlBmZlhktoPkve0ya2i2" target="_blank">ft-jyWTPlBmZlhktoPkve0ya2i2</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.346 MB of 0.346 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▁▂▂▇▇▄▂▂▅▃▇▄▂▂▂▃▆▂▁▃▂▆▇▁▂▂▂▆█▂▃▅▁▂▅▂▃▁▃▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▆█▆▄▄▆▇▅▅▅▁▂▄▆▅▆▄▃▇▆▆▃▃▅▆▆█▄▅▅▄▂█▆▃▅▅▆▅▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>102.0</td></tr><tr><td>elapsed_tokens</td><td>43046.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.07239</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.725</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-jyWTPlBmZlhktoPkve0ya2i2</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-jyWTPlBmZlhktoPkve0ya2i2" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-jyWTPlBmZlhktoPkve0ya2i2</a><br/>Synced 4 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221217_094116-ft-jyWTPlBmZlhktoPkve0ya2i2/logs</code>

# %% [markdown]
# ### Further iteratively finetune on datasets with 100 samples

# %%
def initialize_gpt3_finetuning_job_from_model(model_name: str, n_epochs: int, prompt_loss_weight: float, learning_rate_multiplier: float, train_dataset_id: str,  finetuning_summaries: List[str], finetuning_ids: List[str], suffix: str) -> None:
  finetuning_summary = openai.FineTune.create(
                        training_file=train_dataset_id, 
                        model=model_name,
                        n_epochs=n_epochs, 
                        prompt_loss_weight=prompt_loss_weight,
                        learning_rate_multiplier=learning_rate_multiplier,
                        compute_classification_metrics=False,
                        suffix=suffix)
  finetuning_summaries.append(finetuning_summary)
  finetuning_ids.append(finetuning_summary["id"])
  print("Initialized job", finetuning_summary['id'])
  print("with n_epochs", n_epochs)
  print("with prompt_loss_weight: ", prompt_loss_weight)
  print(model_name)
  print(learning_rate_multiplier)
  print("\n\n")
  return finetuning_summaries, finetuning_ids

# %% [markdown]
# #### Round 1

# %%
final_tag = "iterative_refinement_100_round_1_"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0],
                "learning_rate_multiplier": [0.05],
                "model_name": ["davinci:ft-academicsnyuperez:final-run-100-refinements-2022-12-11-15-49-34"]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/iterative_finetuning/iterative_refinement_round_1_100_finetuning.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
print("Train dataset id {}".format(train_data_id))
# Out:
# Train dataset id file-4U3DQ2hmAtqJEftQrDlyG6IJ

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  model_name = parameter["model_name"]
  print(model_name)
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_from_model(model_name=model_name, n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# davinci:ft-academicsnyuperez:final-run-100-refinements-2022-12-11-15-49-34
# Initialized job ft-HPjxocTQh7tgm6bt4hqV40P2
# with n_epochs 1
# with prompt_loss_weight:  0
# davinci:ft-academicsnyuperez:final-run-100-refinements-2022-12-11-15-49-34
# 0.05
#
#
#
# ['ft-HPjxocTQh7tgm6bt4hqV40P2']

# %%
# !openai api fine_tunes.get -i "ft-HPjxocTQh7tgm6bt4hqV40P2"
# Out:
# {
#   "created_at": 1671118445,
#   "events": [
#     {
#       "created_at": 1671118445,
#       "level": "info",
#       "message": "Created fine-tune: ft-HPjxocTQh7tgm6bt4hqV40P2",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": null,
#     "learning_rate_multiplier": 0.05,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.0
#   },
#   "id": "ft-HPjxocTQh7tgm6bt4hqV40P2",
#   "model": "davinci:ft-academicsnyuperez:final-run-100-refinements-2022-12-11-15-49-34",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 167043,
#       "created_at": 1671118444,
#       "filename": "file",
#       "id": "file-4U3DQ2hmAtqJEftQrDlyG6IJ",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1671118445,
#   "validation_files": []
# }

# %%
finetuning_ids_hp_tuning = ['ft-HPjxocTQh7tgm6bt4hqV40P2']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-HPjxocTQh7tgm6bt4hqV40P2 ...
# [2022-12-15 15:34:05] Created fine-tune: ft-HPjxocTQh7tgm6bt4hqV40P2
# [2022-12-15 15:34:14] Fine-tune costs $1.17
# [2022-12-15 15:34:14] Fine-tune enqueued. Queue number: 0
# [2022-12-15 15:34:18] Fine-tune started
# [2022-12-15 15:36:40] Completed epoch 1/1
# [2022-12-15 15:37:12] Uploaded model: davinci:ft-academicsnyuperez:iterative-refinement-100-round-1-2022-12-15-15-37-12
# [2022-12-15 15:37:14] Uploaded result file: file-OiWYPPBOKs79DbhfEJreVOdW
# [2022-12-15 15:37:14] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:iterative-refinement-100-round-1-2022-12-15-15-37-12 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-HPjxocTQh7tgm6bt4hqV40P2']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: jerry_crea. Use `wandb login --relogin` to force relogin
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221215_154100-ft-HPjxocTQh7tgm6bt4hqV40P2</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-HPjxocTQh7tgm6bt4hqV40P2" target="_blank">ft-HPjxocTQh7tgm6bt4hqV40P2</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.319 MB of 0.319 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▁▂▁▃▂▃▁▂▁▁█▂▂▂▁▂▂▂▁▃▃▂▁▂▂▃▃▁▃▃▂▃▄▂▂▁▃▁▂▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▅▃▄▅▃▄▃▅▄▁▅▅▂▄▄▃▄█▅▃▅▄▃▅▁▄▃▁▃▄▂▄▅▃▂▂▆▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>102.0</td></tr><tr><td>elapsed_tokens</td><td>40022.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.11301</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.6</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-HPjxocTQh7tgm6bt4hqV40P2</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-HPjxocTQh7tgm6bt4hqV40P2" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-HPjxocTQh7tgm6bt4hqV40P2</a><br/>Synced 4 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221215_154100-ft-HPjxocTQh7tgm6bt4hqV40P2/logs</code>

# %% [markdown]
# #### Round 2

# %%
final_tag = "iterative_refinement_100_round_2"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0],
                "learning_rate_multiplier": [0.05],
                "model_name": ["davinci:ft-academicsnyuperez:iterative-refinement-100-round-1-2022-12-15-15-37-12"]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)
sweep_parameters
# Out:
# [{'n_epochs': 1,
#   'prompt_loss_weight': 0,
#   'learning_rate_multiplier': 0.05,
#   'model_name': 'davinci:ft-academicsnyuperez:iterative-refinement-100-round-1-2022-12-15-15-37-12'}]

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/iterative_finetuning/iterative_refinement_round_2_100_finetuning.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
print("Train dataset id {}".format(train_data_id))
# Out:
# Train dataset id file-7NRut7Mn8ATuRyOQTpZXX3W4

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  model_name = parameter["model_name"]
  print(model_name)
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_from_model(model_name=model_name, n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# davinci:ft-academicsnyuperez:iterative-refinement-100-round-1-2022-12-15-15-37-12
# Initialized job ft-nAenK5ocQaIZG67dAvTtWEdc
# with n_epochs 1
# with prompt_loss_weight:  0
# davinci:ft-academicsnyuperez:iterative-refinement-100-round-1-2022-12-15-15-37-12
# 0.05
#
#
#
# ['ft-nAenK5ocQaIZG67dAvTtWEdc']

# %%
# !openai api fine_tunes.get -i "ft-nAenK5ocQaIZG67dAvTtWEdc"
# Out:
# {
#   "created_at": 1671268141,
#   "events": [
#     {
#       "created_at": 1671268141,
#       "level": "info",
#       "message": "Created fine-tune: ft-nAenK5ocQaIZG67dAvTtWEdc",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1671268147,
#       "level": "info",
#       "message": "Fine-tune costs $1.26",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1671268147,
#       "level": "info",
#       "message": "Fine-tune enqueued. Queue number: 0",
#       "object": "fine-tune-event"
#     },
#     {
#       "created_at": 1671268150,
#       "level": "info",
#       "message": "Fine-tune started",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": 1,
#     "learning_rate_multiplier": 0.05,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.0
#   },
#   "id": "ft-nAenK5ocQaIZG67dAvTtWEdc",
#   "model": "davinci:ft-academicsnyuperez:iterative-refinement-100-round-1-2022-12-15-15-37-12",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "running",
#   "training_files": [
#     {
#       "bytes": 182275,
#       "created_at": 1671268136,
#       "filename": "file",
#       "id": "file-7NRut7Mn8ATuRyOQTpZXX3W4",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1671268150,
#   "validation_files": []
# }

# %%
finetuning_ids_hp_tuning = ['ft-nAenK5ocQaIZG67dAvTtWEdc']
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-nAenK5ocQaIZG67dAvTtWEdc ...
# [2022-12-17 09:09:01] Created fine-tune: ft-nAenK5ocQaIZG67dAvTtWEdc
# [2022-12-17 09:09:07] Fine-tune costs $1.26
# [2022-12-17 09:09:07] Fine-tune enqueued. Queue number: 0
# [2022-12-17 09:09:10] Fine-tune started
# [2022-12-17 09:11:34] Completed epoch 1/1
# [2022-12-17 09:12:15] Uploaded model: davinci:ft-academicsnyuperez:iterative-refinement-100-round-2-2022-12-17-09-12-14
# [2022-12-17 09:12:16] Uploaded result file: file-ITs1sOpDNidZtgWqCk7qElIz
# [2022-12-17 09:12:16] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:iterative-refinement-100-round-2-2022-12-17-09-12-14 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-nAenK5ocQaIZG67dAvTtWEdc']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# ERROR:wandb.jupyter:Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: jerry_crea. Use `wandb login --relogin` to force relogin
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221217_091538-ft-nAenK5ocQaIZG67dAvTtWEdc</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-nAenK5ocQaIZG67dAvTtWEdc" target="_blank">ft-nAenK5ocQaIZG67dAvTtWEdc</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.348 MB of 0.348 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▁▁▃▂▃▃▂▂▃▅▇▃▅▃▂█▃▃▃█▃▃▁▂▂▄▇▂▂▂▆▃▃▂▆▃▄▄▁▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>██▆▇▅▆▇▅▂▂▂▄▄▅▄▁▂▇▆▂▅▄█▅█▄▃▇▇▇▄▆▂▆▁▅▄▂▇▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>102.0</td></tr><tr><td>elapsed_tokens</td><td>43110.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.08879</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.67391</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-nAenK5ocQaIZG67dAvTtWEdc</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-nAenK5ocQaIZG67dAvTtWEdc" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-nAenK5ocQaIZG67dAvTtWEdc</a><br/>Synced 4 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221217_091538-ft-nAenK5ocQaIZG67dAvTtWEdc/logs</code>

# %% [markdown]
# ## Finetune on iterative dataset with 200 and 300 samples

# %%
def initialize_gpt3_finetuning_job_all_params_no_valid(n_epochs: int, prompt_loss_weight: float, learning_rate_multiplier: float, train_dataset_id: str, finetuning_summaries: List[str], finetuning_ids: List[str], suffix: str) -> None:
  finetuning_summary = openai.FineTune.create(
                        training_file=train_dataset_id, 
                        model="davinci",
                        n_epochs=n_epochs, 
                        prompt_loss_weight=prompt_loss_weight,
                        learning_rate_multiplier=learning_rate_multiplier,
                        compute_classification_metrics=False,
                        suffix=suffix)
  finetuning_summaries.append(finetuning_summary)
  finetuning_ids.append(finetuning_summary["id"])
  print("Initialized job", finetuning_summary['id'])
  print("with n_epochs", n_epochs)
  print("with prompt_loss_weight: ", prompt_loss_weight)
  print("\n\n")
  return finetuning_summaries, finetuning_ids

# %% [markdown]
# ### Round 1 - 200

# %% [markdown]
# Hyperparameters:
#
# Epochs: 1
#
# prompt_loss_weight: 0.05
#
# learning_rate_multiplier: 0.1

# %%
final_tag = "iterative_finetuning_round_1_200"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0.05],
                "learning_rate_multiplier": [0.1]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/iterative_finetuning/iterative_refinement_round_1_with_initial_refinement_round_0_200_finetuning.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
print("Train dataset id {}".format(train_data_id))
# Out:
# Train dataset id file-OBPROPhHaZaf5h9ZhxSVCHDW

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_all_params_no_valid(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-ohH9rXo2xWWiAbiciCMLpPSX
# with n_epochs 1
# with prompt_loss_weight:  0.05
#
#
#
# ['ft-ohH9rXo2xWWiAbiciCMLpPSX']

# %%
# !openai api fine_tunes.get -i "ft-ohH9rXo2xWWiAbiciCMLpPSX"
# Out:
# {
#   "created_at": 1672218503,
#   "events": [
#     {
#       "created_at": 1672218503,
#       "level": "info",
#       "message": "Created fine-tune: ft-ohH9rXo2xWWiAbiciCMLpPSX",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": null,
#     "learning_rate_multiplier": 0.1,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.05
#   },
#   "id": "ft-ohH9rXo2xWWiAbiciCMLpPSX",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 331490,
#       "created_at": 1672218498,
#       "filename": "file",
#       "id": "file-OBPROPhHaZaf5h9ZhxSVCHDW",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1672218503,
#   "validation_files": []
# }

# %%
finetuning_ids_hp_tuning = ["ft-ohH9rXo2xWWiAbiciCMLpPSX"]
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-ohH9rXo2xWWiAbiciCMLpPSX ...
# [2022-12-28 09:08:23] Created fine-tune: ft-ohH9rXo2xWWiAbiciCMLpPSX
# [2022-12-28 09:09:32] Fine-tune costs $2.31
# [2022-12-28 09:09:32] Fine-tune enqueued. Queue number: 0
# [2022-12-28 09:09:35] Fine-tune started
# [2022-12-28 09:12:45] Completed epoch 1/1
# [2022-12-28 09:13:19] Uploaded model: davinci:ft-academicsnyuperez:iterative-finetuning-round-1-200-2022-12-28-09-13-19
# [2022-12-28 09:13:20] Uploaded result file: file-lwkvE163jGlgqMhrtxQlnebS
# [2022-12-28 09:13:20] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:iterative-finetuning-round-1-200-2022-12-28-09-13-19 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-ohH9rXo2xWWiAbiciCMLpPSX']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221228_095817-ft-ohH9rXo2xWWiAbiciCMLpPSX</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-ohH9rXo2xWWiAbiciCMLpPSX" target="_blank">ft-ohH9rXo2xWWiAbiciCMLpPSX</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.630 MB of 0.630 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▃▄▂▂▃▂▂█▃▂▂▄▂▃▃▂▂▃▂▂▄▃▂▂▂▃▂▂▂▃▂▂▂▂▃▁▂▃▂▂</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▄▄▃▆▅▅▅▁▅▆▅▄▄▆▅▅▆▆▅▅▅▅▄▄▅▅▅▅▆▆▇▅▅█▃▇▇▄▅▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>202.0</td></tr><tr><td>elapsed_tokens</td><td>78570.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.17597</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.725</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-ohH9rXo2xWWiAbiciCMLpPSX</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-ohH9rXo2xWWiAbiciCMLpPSX" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-ohH9rXo2xWWiAbiciCMLpPSX</a><br/>Synced 4 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221228_095817-ft-ohH9rXo2xWWiAbiciCMLpPSX/logs</code>

# %% [markdown]
# ### Round 2 - 300

# %% [markdown]
# Hyperparameters:
#
# Epochs: 1
#
# prompt_loss_weight: 0
#
# learning_rate_multiplier: 0.2

# %%
final_tag = "iterative_finetuning_round_2_300"
parameter_combinations = {
                "n_epochs":[1], 
                "prompt_loss_weight": [0],
                "learning_rate_multiplier": [0.2]
}

# %%
sweep_parameters = build_parameter_sets(parameter_combinations)

# %%
dataset_paths_to_ids = {}
train_data = "summarization_finetuning_datasets/iterative_finetuning/iterative_refinement_round_2_with_initial_refinement_round_0_and_1_300_finetuning.jsonl"
train_data_id = upload_dataset_to_openai(train_data)
print("Train dataset id {}".format(train_data_id))
# Out:
# Train dataset id file-7dXfbJPHUd9ZbmBCdT6kCuiv

# %%
finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = [], []
for parameter in sweep_parameters:
  n_epochs = parameter["n_epochs"]
  prompt_loss_weight = parameter["prompt_loss_weight"]
  learning_rate_multiplier = parameter["learning_rate_multiplier"]
  finetuning_summaries_hp_tuning, finetuning_ids_hp_tuning = initialize_gpt3_finetuning_job_all_params_no_valid(n_epochs=n_epochs,prompt_loss_weight=prompt_loss_weight,learning_rate_multiplier=learning_rate_multiplier, train_dataset_id=train_data_id, finetuning_summaries=finetuning_summaries_hp_tuning, finetuning_ids=finetuning_ids_hp_tuning, suffix=final_tag)
  print(finetuning_ids_hp_tuning)
# Out:
# Initialized job ft-DY72EmXFgqBP9jlbK58PcEMn
# with n_epochs 1
# with prompt_loss_weight:  0
#
#
#
# ['ft-DY72EmXFgqBP9jlbK58PcEMn']

# %%
# !openai api fine_tunes.get -i "ft-DY72EmXFgqBP9jlbK58PcEMn"
# Out:
# {
#   "created_at": 1672228678,
#   "events": [
#     {
#       "created_at": 1672228678,
#       "level": "info",
#       "message": "Created fine-tune: ft-DY72EmXFgqBP9jlbK58PcEMn",
#       "object": "fine-tune-event"
#     }
#   ],
#   "fine_tuned_model": null,
#   "hyperparams": {
#     "batch_size": null,
#     "learning_rate_multiplier": 0.2,
#     "n_epochs": 1,
#     "prompt_loss_weight": 0.0
#   },
#   "id": "ft-DY72EmXFgqBP9jlbK58PcEMn",
#   "model": "davinci",
#   "object": "fine-tune",
#   "organization_id": "org-rRALD2hkdlmLWNVCKk9PG5Xq",
#   "result_files": [],
#   "status": "pending",
#   "training_files": [
#     {
#       "bytes": 513765,
#       "created_at": 1672228672,
#       "filename": "file",
#       "id": "file-7dXfbJPHUd9ZbmBCdT6kCuiv",
#       "object": "file",
#       "purpose": "fine-tune",
#       "status": "processed",
#       "status_details": null
#     }
#   ],
#   "updated_at": 1672228678,
#   "validation_files": []
# }

# %%
finetuning_ids_hp_tuning = ["ft-DY72EmXFgqBP9jlbK58PcEMn"]
for finetuning_id in finetuning_ids_hp_tuning:
  print(f"Monitoring {finetuning_id} ...")
  # !openai api fine_tunes.follow -i {finetuning_id}
  print("\n\n")
# Out:
# Monitoring ft-DY72EmXFgqBP9jlbK58PcEMn ...
# [2022-12-28 11:57:58] Created fine-tune: ft-DY72EmXFgqBP9jlbK58PcEMn
# [2022-12-28 11:58:47] Fine-tune costs $3.57
# [2022-12-28 11:58:47] Fine-tune enqueued. Queue number: 0
# [2022-12-28 11:58:52] Fine-tune started
# [2022-12-28 12:03:00] Completed epoch 1/1
# [2022-12-28 12:03:47] Uploaded model: davinci:ft-academicsnyuperez:iterative-finetuning-round-2-300-2022-12-28-12-03-47
# [2022-12-28 12:03:48] Uploaded result file: file-hHyOLawXgPbtmcn9oiwZdS3Z
# [2022-12-28 12:03:48] Fine-tune succeeded
#
# Job complete! Status: succeeded 🎉
# Try out your fine-tuned model:
#
# openai api completions.create -m davinci:ft-academicsnyuperez:iterative-finetuning-round-2-300-2022-12-28-12-03-47 -p <YOUR_PROMPT>

# %%
finetuning_ids_hp_tuning = ['ft-DY72EmXFgqBP9jlbK58PcEMn']
for finetuning_id in finetuning_ids_hp_tuning:
  WandbLogger.sync(finetuning_id, project="training_language_models_with_langauge_feedback", entity="jerry_crea", tags=[final_tag])
# Out:
# wandb version 0.13.7 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/content/wandb/run-20221228_131615-ft-DY72EmXFgqBP9jlbK58PcEMn</code>
# Syncing run <strong><a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-DY72EmXFgqBP9jlbK58PcEMn" target="_blank">ft-DY72EmXFgqBP9jlbK58PcEMn</a></strong> to <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.976 MB of 0.976 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>elapsed_tokens</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>training_loss</td><td>▂▄▃▃▂▂▄▆█▃▆▃▄▃▄▃▅▆▅▂▅▂▂▃▁▆▆▃▄▃▂▂▁▃▄▄▄▃▃▃</td></tr><tr><td>training_sequence_accuracy</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>training_token_accuracy</td><td>▆▃▅▄▄█▃▄▁▄▃▄▅▅▁▃▂▂▃▇▃▅▇▃▅▁▂▅▂▃▄▂▇▃▄▃▃▅▆▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>elapsed_examples</td><td>301.0</td></tr><tr><td>elapsed_tokens</td><td>120421.0</td></tr><tr><td>fine_tuned_model</td><td>davinci:ft-academics...</td></tr><tr><td>status</td><td>succeeded</td></tr><tr><td>training_loss</td><td>0.07306</td></tr><tr><td>training_sequence_accuracy</td><td>0.0</td></tr><tr><td>training_token_accuracy</td><td>0.75</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">ft-DY72EmXFgqBP9jlbK58PcEMn</strong>: <a href="https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-DY72EmXFgqBP9jlbK58PcEMn" target="_blank">https://wandb.ai/jerry_crea/training_language_models_with_langauge_feedback/runs/ft-DY72EmXFgqBP9jlbK58PcEMn</a><br/>Synced 4 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20221228_131615-ft-DY72EmXFgqBP9jlbK58PcEMn/logs</code>
